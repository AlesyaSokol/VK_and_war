# %%
import numpy as np
import pickle
from matplotlib import pyplot as plt
import pandas as pd

# %%
import datetime

# %%
import random

# %%
# !pip install bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.22.4)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (4.65.0)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (5.13.1)
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 47.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.34)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 48.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.1+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 100.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3580416 sha256=213c833be52ec50d58c78ed7c84ee2b60087b18e04c87b944d11983496e53c82
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=b42f5fd9a1c7aa6a47f60ece107647ce25bd89cd269906613630adba4035d57a
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=6547d8ad05493b6cf3349ae3e1fe6d3d2d7367934ae22ffc2df10004ab8aceef
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55640 sha256=a5aa116a88cd823caca8a84b6c8b0f54b97b1fd97b617de81b61fc8354c031c0
#   Stored in directory: /root/.cache/pip/wheels/12/f9/4d/ec5ad1c823c710fcc4473669fdcffc8891f4bc398c841af22e
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 huggingface-hub-0.14.1 pynndescent-0.5.10 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.28.1 umap-learn-0.5.3

# %%
from bertopic import BERTopic

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install pymorphy2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 2.9 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 67.8 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13721 sha256=406dc07cf353bb211836404acdd617ee130fe7ed5b5e9496e8077d50210f6727
#   Stored in directory: /root/.cache/pip/wheels/70/4a/46/1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
# !python --version
# Out:
# Python 3.9.16

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# alabaster==0.7.13
# albumentations==1.2.1
# altair==4.2.2
# anyio==3.6.2
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arviz==0.15.1
# astropy==5.2.2
# astunparse==1.6.3
# attrs==23.1.0
# audioread==3.0.0
# autograd==1.5
# Babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.11.2
# bertopic==0.14.1
# bleach==6.0.0
# blis==0.7.9
# blosc2==2.0.0
# bokeh==2.4.3
# branca==0.6.0
# CacheControl==0.12.11
# cached-property==1.5.2
# cachetools==5.3.0
# catalogue==2.0.8
# certifi==2022.12.7
# cffi==1.15.1
# chardet==4.0.0
# charset-normalizer==2.0.12
# chex==0.1.7
# click==8.1.3
# cloudpickle==2.2.1
# cmake==3.25.2
# cmdstanpy==1.1.0
# colorcet==3.0.1
# colorlover==0.3.0
# community==1.0.0b1
# confection==0.0.4
# cons==0.4.5
# contextlib2==0.6.0.post1
# contourpy==1.0.7
# convertdate==2.4.0
# cryptography==40.0.2
# cufflinks==0.17.3
# cupy-cuda11x==11.0.0
# cvxopt==1.3.0
# cvxpy==1.3.1
# cycler==0.11.0
# cymem==2.0.7
# Cython==0.29.34
# dask==2022.12.1
# datascience==0.17.6
# DAWG-Python==0.7.2
# db-dtypes==1.1.1
# dbus-python==1.2.16
# debugpy==1.6.6
# decorator==4.4.2
# defusedxml==0.7.1
# distributed==2022.12.1
# dlib==19.24.1
# dm-tree==0.1.8
# docopt==0.6.2
# docutils==0.16
# dopamine-rl==4.0.6
# duckdb==0.7.1
# earthengine-api==0.1.349
# easydict==1.10
# ecos==2.0.12
# editdistance==0.6.2
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl
# entrypoints==0.4
# ephem==4.1.4
# et-xmlfile==1.1.0
# etils==1.2.0
# etuples==0.3.8
# exceptiongroup==1.1.1
# fastai==2.7.12
# fastcore==1.5.29
# fastdownload==0.0.7
# fastjsonschema==2.16.3
# fastprogress==1.0.3
# fastrlock==0.8.1
# filelock==3.11.0
# firebase-admin==5.3.0
# Flask==2.2.3
# flatbuffers==23.3.3
# flax==0.6.8
# folium==0.14.0
# fonttools==4.39.3
# frozendict==2.3.7
# fsspec==2023.4.0
# future==0.18.3
# gast==0.4.0
# GDAL==3.3.2
# gdown==4.6.6
# gensim==4.3.1
# geographiclib==2.0
# geopy==2.3.0
# gin-config==0.5.0
# glob2==0.7
# google==2.0.3
# google-api-core==2.11.0
# google-api-python-client==2.84.0
# google-auth==2.17.3
# google-auth-httplib2==0.1.0
# google-auth-oauthlib==1.0.0
# google-cloud-bigquery==3.9.0
# google-cloud-bigquery-storage==2.19.1
# google-cloud-core==2.3.2
# google-cloud-datastore==2.15.1
# google-cloud-firestore==2.11.0
# google-cloud-language==2.9.1
# google-cloud-storage==2.8.0
# google-cloud-translate==3.11.1
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz
# google-crc32c==1.5.0
# google-pasta==0.2.0
# google-resumable-media==2.4.1
# googleapis-common-protos==1.59.0
# googledrivedownloader==0.4
# graphviz==0.20.1
# greenlet==2.0.2
# grpcio==1.53.0
# grpcio-status==1.48.2
# gspread==3.4.2
# gspread-dataframe==3.0.8
# gym==0.25.2
# gym-notices==0.0.8
# h5netcdf==1.1.0
# h5py==3.8.0
# hdbscan==0.8.29
# HeapDict==1.0.1
# hijri-converter==2.2.4
# holidays==0.22
# holoviews==1.15.4
# html5lib==1.1
# httpimport==1.3.0
# httplib2==0.21.0
# huggingface-hub==0.14.1
# humanize==4.6.0
# hyperopt==0.2.7
# idna==3.4
# imageio==2.25.1
# imageio-ffmpeg==0.4.8
# imagesize==1.4.1
# imbalanced-learn==0.10.1
# imgaug==0.4.0
# importlib-metadata==6.4.1
# importlib-resources==5.12.0
# imutils==0.5.4
# inflect==6.0.4
# iniconfig==2.0.0
# intel-openmp==2023.1.0
# ipykernel==5.5.6
# ipython==7.34.0
# ipython-genutils==0.2.0
# ipython-sql==0.4.1
# ipywidgets==7.7.1
# itsdangerous==2.1.2
# jax==0.4.8
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.4.7+cuda11.cudnn86-cp39-cp39-manylinux2014_x86_64.whl
# jieba==0.42.1
# Jinja2==3.1.2
# joblib==1.2.0
# jsonpickle==3.0.1
# jsonschema==4.3.3
# jupyter-client==6.1.12
# jupyter-console==6.1.0
# jupyter-server==1.24.0
# jupyter_core==5.3.0
# jupyterlab-pygments==0.2.2
# jupyterlab-widgets==3.0.7
# kaggle==1.5.13
# keras==2.12.0
# keras-vis==0.4.1
# kiwisolver==1.4.4
# korean-lunar-calendar==0.3.1
# langcodes==3.3.0
# lazy_loader==0.2
# libclang==16.0.0
# librosa==0.10.0.post2
# lightgbm==3.3.5
# lit==16.0.1
# llvmlite==0.39.1
# locket==1.0.0
# logical-unification==0.4.5
# LunarCalendar==0.0.9
# lxml==4.9.2
# Markdown==3.4.3
# markdown-it-py==2.2.0
# MarkupSafe==2.1.2
# matplotlib==3.7.1
# matplotlib-inline==0.1.6
# matplotlib-venn==0.11.9
# mdurl==0.1.2
# miniKanren==1.0.3
# missingno==0.5.2
# mistune==0.8.4
# mizani==0.8.1
# mkl==2019.0
# ml-dtypes==0.1.0
# mlxtend==0.14.0
# more-itertools==9.1.0
# moviepy==1.0.3
# mpmath==1.3.0
# msgpack==1.0.5
# multipledispatch==0.6.0
# multitasking==0.0.11
# murmurhash==1.0.9
# music21==8.1.0
# natsort==8.3.1
# nbclient==0.7.3
# nbconvert==6.5.4
# nbformat==5.8.0
# nest-asyncio==1.5.6
# networkx==3.1
# nibabel==3.0.2
# nltk==3.8.1
# notebook==6.4.8
# numba==0.56.4
# numexpr==2.8.4
# numpy==1.22.4
# oauth2client==4.1.3
# oauthlib==3.2.2
# opencv-contrib-python==4.7.0.72
# opencv-python==4.7.0.72
# opencv-python-headless==4.7.0.72
# openpyxl==3.0.10
# opt-einsum==3.3.0
# optax==0.1.4
# orbax==0.1.7
# osqp==0.6.2.post0
# packaging==23.1
# palettable==3.3.2
# pandas==1.5.3
# pandas-datareader==0.10.0
# pandas-gbq==0.17.9
# pandocfilters==1.5.0
# panel==0.14.4
# param==1.13.0
# parso==0.8.3
# partd==1.4.0
# pathlib==1.0.1
# pathy==0.10.1
# patsy==0.5.3
# pep517==0.13.0
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==8.4.0
# pip-tools==6.6.2
# platformdirs==3.2.0
# plotly==5.13.1
# plotnine==0.10.1
# pluggy==1.0.0
# polars==0.17.3
# pooch==1.6.0
# portpicker==1.3.9
# prefetch-generator==1.0.3
# preshed==3.0.8
# prettytable==0.7.2
# proglog==0.1.10
# progressbar2==4.2.0
# prometheus-client==0.16.0
# promise==2.3
# prompt-toolkit==3.0.38
# prophet==1.1.2
# proto-plus==1.22.2
# protobuf==3.20.3
# psutil==5.9.5
# psycopg2==2.9.6
# ptyprocess==0.7.0
# py-cpuinfo==9.0.0
# py4j==0.10.9.7
# pyarrow==9.0.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycocotools==2.0.6
# pycparser==2.21
# pyct==0.5.0
# pydantic==1.10.7
# pydata-google-auth==1.7.0
# pydot==1.4.2
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyerfa==2.0.0.3
# pygame==2.3.0
# Pygments==2.14.0
# PyGObject==3.36.0
# pymc==5.1.2
# PyMeeus==0.5.12
# pymorphy2==0.9.1
# pymorphy2-dicts-ru==2.4.417127.4579844
# pymystem3==0.2.0
# pynndescent==0.5.10
# PyOpenGL==3.1.6
# pyparsing==3.0.9
# pyrsistent==0.19.3
# PySocks==1.7.1
# pytensor==2.10.1
# pytest==7.2.2
# python-apt==0.0.0
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==8.0.1
# python-utils==3.5.2
# pytz==2022.7.1
# pytz-deprecation-shim==0.1.0.post0
# pyviz-comms==2.2.1
# PyWavelets==1.4.1
# PyYAML==6.0
# pyzmq==23.2.1
# qdldl==0.1.7
# qudida==0.0.4
# regex==2022.10.31
# requests==2.27.1
# requests-oauthlib==1.3.1
# requests-unixsocket==0.2.0
# rich==13.3.4
# rpy2==3.5.5
# rsa==4.9
# scikit-image==0.19.3
# scikit-learn==1.2.2
# scipy==1.10.1
# scs==3.2.3
# seaborn==0.12.2
# Send2Trash==1.8.0
# sentence-transformers==2.2.2
# sentencepiece==0.1.99
# shapely==2.0.1
# six==1.16.0
# sklearn-pandas==2.2.0
# smart-open==6.3.0
# sniffio==1.3.0
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# soundfile==0.12.1
# soupsieve==2.4.1
# soxr==0.3.5
# spacy==3.5.2
# spacy-legacy==3.0.12
# spacy-loggers==1.0.4
# Sphinx==3.5.4
# sphinxcontrib-applehelp==1.0.4
# sphinxcontrib-devhelp==1.0.2
# sphinxcontrib-htmlhelp==2.0.1
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.3
# sphinxcontrib-serializinghtml==1.1.5
# SQLAlchemy==2.0.9
# sqlparse==0.4.3
# srsly==2.4.6
# statsmodels==0.13.5
# sympy==1.11.1
# tables==3.8.0
# tabulate==0.8.10
# tblib==1.7.0
# tenacity==8.2.2
# tensorboard==2.12.2
# tensorboard-data-server==0.7.0
# tensorboard-plugin-wit==1.8.1
# tensorflow==2.12.0
# tensorflow-datasets==4.8.3
# tensorflow-estimator==2.12.0
# tensorflow-gcs-config==2.12.0
# tensorflow-hub==0.13.0
# tensorflow-io-gcs-filesystem==0.32.0
# tensorflow-metadata==1.13.1
# tensorflow-probability==0.19.0
# tensorstore==0.1.35
# termcolor==2.2.0
# terminado==0.17.1
# text-unidecode==1.3
# textblob==0.17.1
# tf-slim==1.1.0
# thinc==8.1.9
# threadpoolctl==3.1.0
# tifffile==2023.4.12
# tinycss2==1.2.1
# tokenizers==0.13.3
# toml==0.10.2
# tomli==2.0.1
# toolz==0.12.0
# torch @ https://download.pytorch.org/whl/cu118/torch-2.0.0%2Bcu118-cp39-cp39-linux_x86_64.whl
# torchaudio @ https://download.pytorch.org/whl/cu118/torchaudio-2.0.1%2Bcu118-cp39-cp39-linux_x86_64.whl
# torchdata==0.6.0
# torchsummary==1.5.1
# torchtext==0.15.1
# torchvision @ https://download.pytorch.org/whl/cu118/torchvision-0.15.1%2Bcu118-cp39-cp39-linux_x86_64.whl
# tornado==6.2
# tqdm==4.65.0
# traitlets==5.7.1
# transformers==4.28.1
# triton==2.0.0
# tweepy==4.13.0
# typer==0.7.0
# typing_extensions==4.5.0
# tzdata==2023.3
# tzlocal==4.3
# umap-learn==0.5.3
# uritemplate==4.1.1
# urllib3==1.26.15
# vega-datasets==0.9.0
# wasabi==1.1.1
# wcwidth==0.2.6
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.5.1
# Werkzeug==2.2.3
# widgetsnbextension==3.6.4
# wordcloud==1.8.2.2
# wrapt==1.14.1
# xarray==2022.12.0
# xarray-einstats==0.5.1
# xgboost==1.7.5
# xlrd==2.0.1
# yellowbrick==1.5
# yfinance==0.2.18
# zict==2.2.0
# zipp==3.15.0

# %%
import pymorphy2

# %%
# !pip install -U textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2022.10.31)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.3)

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
from textblob import TextBlob

# %% [markdown]
# # Compare Z and nowar

# %%
f = open('./drive/MyDrive/Hackathon/posts_nowar_users_russia_clean.pkl', 'rb')
posts_nowar = pickle.load(f)
f.close()

posts_nowar_clean = []

for post in posts_nowar:
    text = post['text']
    text.replace('\n','')
    posts_nowar_clean.append(text)

len(posts_nowar_clean)
# Out:
# 20448

# %%
f = open('./drive/MyDrive/Hackathon/posts_z_users_russia_clean.pkl', 'rb')
posts_z = pickle.load(f)
f.close()

# %%
random.seed(42)
random.shuffle(posts_z)
posts_z = posts_z[:len(posts_nowar_clean)]

# %%
posts_z_clean = []

for post in posts_z:
    text = post['text']
    text.replace('\n','')
    posts_z_clean.append(text)

len(posts_z_clean)
# Out:
# 20448

# %%
model = BERTopic(verbose=True, language = 'multilingual', min_topic_size = 10)
topics, probabilities = model.fit_transform(posts_nowar_clean+posts_z_clean)
model.get_topic_info()
# Out:
# Batches:   0%|          | 0/1278 [00:00<?, ?it/s]
# 2023-04-07 15:46:49,096 - BERTopic - Transformed documents to Embeddings
# 2023-04-07 15:47:33,769 - BERTopic - Reduced dimensionality
# 2023-04-07 15:47:39,342 - BERTopic - Clustered reduced embeddings
#      Topic  Count                                               Name
# 0       -1  25469                                  -1_не_что_на_быть
# 1        0    782                                0_не_ты_февраль_мир
# 2        1    572                                  1_путин_он_что_не
# 3        2    531                                 2_война_не_это_что
# 4        3    294                 3_вертолет_ракета_беспилотник_дрон
# ..     ...    ...                                                ...
# 199    198     23  198_размещение_беженец_временный_временный раз...
# 200    199     23       199_ребенок погибать_погибать_ребенок_ранить
# 201    200     21  200_сталинградский_сталинградский битва_битва_...
# 202    201     21  201_танкист_танковый_танковый войско_день танкист
# 203    202     21  202_изнасиловать_изнасилование_сексуальный_жен...
#
# [204 rows x 3 columns]

# %%
model.save("./drive/MyDrive/Hackathon/compare_z_nowar_now")
# Out:
# /usr/local/lib/python3.9/dist-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %% [markdown]
# # Merge topics

# %%
model = BERTopic.load("./drive/MyDrive/Hackathon/compare_z_nowar_now")

# %%
model.merge_topics(posts_nowar_clean + posts_z_clean, [[44,301,29],
                                                       [21,413,393,119,402],
                                                       [410,57],
                                                       [97,262],
                                                       [96,171,92,37,83,22,406,470],
                                                       [289,297],
                                                       [256,153,282,351,246],
                                                       [111,332],
                                                       [360,453],
                                                       [345,86],
                                                       [182,325],
                                                       [195,205,10,133,221,85,353,31,40],
                                                       [317,143,270,311],
                                                       [450,166,172,190,149,147,455],
                                                       [362,337,454,43,109],
                                                       [71,9,107],
                                                       [132,49],
                                                       [134,354],
                                                       [183,193,397],
                                                       [217,379],
                                                       [425,206],
                                                       [280,466,439],
                                                       [1918,118],
                                                       [167,251,284],
                                                       [330,378],
                                                       [179,361],
                                                       [290,389],
                                                       [452,365],
                                                       [210,17,126,380,291],
                                                       [415,261],
                                                       [391,137],
                                                       [78,89],
                                                       [385,255],
                                                       [18,216,438],
                                                       [163,268],
                                                       [74,392],
                                                       [175,145,13,100,458,235],
                                                       [3,38,140],
                                                       [24,469],
                                                       [81,60],
                                                       [56,16,20],
                                                       [176,113,375],
                                                       [105,120,197,108],
                                                       [6,249],
                                                       [110,72,269],
                                                       [266,229],
                                                       [208,161],
                                                       [370,309],
                                                       [160,15,2,59],
                                                       [214,285],
                                                       [260,27],
                                                       [48,236],
                                                       [345,464,136],
                                                       [314,234],
                                                       [387,215,174],
                                                       [250,124,273,277,407],
                                                       [159,76,33,213],
                                                       [241,82,35,7],
                                                       [442,346],
                                                       [91,253],
                                                       [64,373,307],
                                                       [192,306,98,343,139,95]
                                                       ])

# %%
model.merge_topics(posts_nowar_clean + posts_z_clean, [[169,12],
                                                       [42,35],
                                                       [82,242,214],
                                                       [99,2,87],
                                                       [243,103],
                                                       [137,40],
                                                       [34,305],
                                                       [16,20],
                                                       [318,44],
                                                       [194,144],
                                                       [26,64],
                                                       [3,67],
                                                       [7,138],
                                                       [197,37],
                                                       [337,158],
                                                       [92,332],
                                                       [11,270],
                                                       [108,315],
                                                       [129,281],
                                                       [292,10],
                                                       [178,109],
                                                       [18,65,81],
                                                       [245,260]
                                                       ])

# %%
model.merge_topics(posts_nowar_clean + posts_z_clean, [10,79])

# %%
model.merge_topics(posts_nowar_clean + posts_z_clean, [[16,80],
                                                       [66,109],
                                                       [65,110]
                                                       ])

# %%
model.merge_topics(posts_nowar_clean + posts_z_clean, [[66,70]
                                                       ])

# %%
model.merge_topics(posts_nowar_clean + posts_z_clean, [[6,18]
                                                       ])

# %%
model.merge_topics(posts_nowar_clean + posts_z_clean, [[61,75]
                                                       ])

# %%
model.merge_topics(posts_nowar_clean + posts_z_clean, [[45,61]
                                                       ])

# %%
model.merge_topics(posts_nowar_clean + posts_z_clean, [[64,79]
                                                       ])

# %%
hierarchical_topics = model.hierarchical_topics(posts_nowar_clean+posts_z_clean)
tree = model.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# 100%|██████████| 311/311 [00:03<00:00, 90.02it/s]
# .
# ├─не_война_что_это_страна
# │    ├─война_не_путин_это_что
# │    │    ├─русский_бог_церковь_православный_ты
# │         │    │         │    └─■──запад_бжезинский_украина_политика_евразийский ── Topic: 147
# │         │    │         └─зеленский_переговоры_украина_ес_заявлять
# │         │    │              ├─зеленский_переговоры_украина_ес_заявлять
# │         │    │              │    ├─■──германия_leopard_украина_польша_поставка ── Topic: 40
# │         │    │              │    └─зеленский_переговоры_ес_украина_президент
# │         │    │              │         ├─зеленский_переговоры_ес_украина_президент
# │         │    │              │         │    ├─■──зеленский_ес_вступление_членство_президент ── Topic: 26
# │         │    │              │         │    └─■──переговоры_оон_сша_конфликт_переговорный ── Topic: 54
# │         │    │              │         └─■──операция_цель_спецоперация_президент_решение ── Topic: 83
# │         │    │              └─■──оружие_солдатосвободитель_жарить_хаос_застреливать ── Topic: 183
# │         │    └─фашизм_нацизм_победа_фашист_украина
# │         │         ├─последователь_мужественно_украина_военный_рассекречивать
# │         │         │    ├─■──евромайдан_антимайдан_антимайданщик_киев_украина ── Topic: 170
# │         │         │    └─мужественно_последователь_рассекречивать_расправлять_героически
# │         │         │         ├─■──последователь_мужественно_рассекречивать_расправлять_героически ── Topic: 98
# │         │         │         └─■──кларк_тактика_ожесточенный_денацификация_убыток ── Topic: 178
# │         │         └─фашизм_нацизм_победа_фашист_фашистский
# │         │              ├─фашизм_нацизм_фашист_победа_концлагерь
# │         │              │    ├─■──фильм_чаплин_нелаев_ремарк_нечисть ── Topic: 129
# │         │              │    └─■──фашизм_нацизм_фашист_победа_над ── Topic: 7
# │         │              └─■──парад_освобождение_мероприятие_победа_бессмертный ── Topic: 137
# │         └─во_мобилизация_государство_действующий_власть
# │              ├─во_мобилизация_государство_действующий_нато
# │              │    ├─мобилизация_частичный_нато_во_ордло
# │              │    │    ├─мобилизация_частичный_во_ордло_нато
# │              │    │    │    ├─■──мобилизация_частичный_ордло_433_внешний ── Topic: 172
# │              │    │    │    └─■──мобилизация_германия_нато_во_частичный ── Topic: 28
# │              │    │    └─■──нато_000_рф_отходы_радиоактивный ── Topic: 230
# │              │    └─■──лес_власть_действующий_во_радоваться ── Topic: 149
# │              └─патриотизм_ребенок_забор_закон_родитель
# │                   ├─ребенок_забор_закон_родитель_либо
# │                   │    ├─■──закон_ребенок_либо_тайга_2000 ── Topic: 291
# │                   │    └─■──забор_родитель_ребенок_сад_детсад ── Topic: 132
# │                   └─■──патриотизм_родина_любовь_патриот_чувство ── Topic: 115
# └─сталинградский_год_единый_битва_наш
#      ├─ктото_страшно_брат_сохранять_ода
#      │    ├─ктото_страшно_брат_сохранять_ода
#      │    │    ├─ода_флот_флаг_военноморский_мариуполь
#      │    │    │    ├─ода_tanks_systems_were_2402
#      │    │    │    │    ├─■──ода_tanks_systems_were_2402 ── Topic: 86
#      │    │    │    │    └─■──ед_ббм_пмм_2402_цистерна ── Topic: 176
#      │    │    │    └─флот_флаг_военноморский_мариуполь_город
#      │    │    │         ├─флот_флаг_военноморский_морской_корабль
#      │    │    │         │    ├─флот_военноморский_морской_корабль_моряк
#      │    │    │         │    │    ├─■──змеиный_остров_ракетнопушечный_дюльгер_змеебаевка ── Topic: 269
#      │    │    │         │    │    └─флот_военноморский_морской_корабль_моряк
#      │    │    │         │    │         ├─■──флот_военноморский_вмф_моряк_морской ── Topic: 46
#      │    │    │         │    │         └─судно_зерно_корабль_порт_тонна
#      │    │    │         │    │              ├─■──корабль_судно_яхта_море_лодка ── Topic: 99
#      │    │    │         │    │              └─■──зерно_порт_судно_тонна_авиакомпания ── Topic: 66
#      │    │    │         │    └─флаг_бабушка_знамя_символ_старушка
#      │    │    │         │         ├─■──флаг_государственный_символ_поднятие_триколор ── Topic: 42
#      │    │    │         │         └─■──бабушка_флаг_знамя_старушка_топтать ── Topic: 69
#      │    │    │         └─мариуполь_хреновость_выпуск_город_петиция
#      │    │    │              ├─мариуполь_хреновость_выпуск_город_петиция
#      │    │    │              │    ├─мариуполь_хреновость_выпуск_петиция_город
#      │    │    │              │    │    ├─хреновость_выпуск_петиция_hовости_воз
#      │    │    │              │    │    │    ├─трудовой_сотрудник_работодатель_рабочий_zа
#      │    │    │              │    │    │    │    ├─zа_осинниковец_куzбасс_термаль_родина
#      │    │    │              │    │    │    │    │    ├─■──zа_осинниковец_куzбасс_родина_куzбассосинники ── Topic: 234
#      │    │    │              │    │    │    │    │    └─■──термаль_унывать_осташко_костян_мотивация ── Topic: 131
#      │    │    │              │    │    │    │    └─трудовой_сотрудник_работодатель_рабочий_стаж
#      │    │    │              │    │    │    │         ├─■──mma_емельяненко_единоборство_смешать_федор ── Topic: 295
#      │    │    │              │    │    │    │         └─трудовой_сотрудник_работодатель_рабочий_стаж
#      │    │    │              │    │    │    │              ├─полуслово_участвовать_смирнов_командовать_специальный
#      │    │    │              │    │    │    │              │    ├─■──полуслово_смирнов_командовать_сержант_галушта ── Topic: 191
#      │    │    │              │    │    │    │              │    └─■──ракетнокосмический_роскосмос_сотрудник_промышленность_саратовский ── Topic: 263
#      │    │    │              │    │    │    │              └─■──трудовой_работодатель_рабочий_сотрудник_стаж ── Topic: 122
#      │    │    │              │    │    │    └─хреновость_выпуск_петиция_hовости_воз
#      │    │    │              │    │    │         ├─путин_байден_джо_штат_владимир
#      │    │    │              │    │    │         │    ├─байден_джо_штат_мэриленд_полуфашизм
#      │    │    │              │    │    │         │    │    ├─■──полуфашизм_мэриленд_борисовский_освистывать_ассоциировать ── Topic: 226
#      │    │    │              │    │    │         │    │    └─■──байден_поздороваться_оглядываться_джо_соединенный ── Topic: 250
#      │    │    │              │    │    │         │    └─путин_владимир_храм_благовещенский_семья
#      │    │    │              │    │    │         │         ├─■──обзываться_путин_ой_хуйло_эвфемизовать ── Topic: 232
#      │    │    │              │    │    │         │         └─владимир_путин_храм_благовещенский_семья
#      │    │    │              │    │    │         │              ├─■──путин_храм_владимир_благовещенский_собор ── Topic: 142
#      │    │    │              │    │    │         │              └─■──важность_рутин_краснодарский_семья_владимир ── Topic: 272
#      │    │    │              │    │    │         └─хреновость_выпуск_петиция_hовости_воз
#      │    │    │              │    │    │              ├─хреновость_выпуск_петиция_hовости_вечерний
#      │    │    │              │    │    │              │    ├─хреновость_выпуск_hовости_вечерний_утренний
#      │    │    │              │    │    │              │    │    ├─хреновость_выпуск_hовости_вечерний_утренний
#      │    │    │              │    │    │              │    │    │    ├─новинка_eng_supernova_supernovasuperstar_engsub
#      │    │    │              │    │    │              │    │    │    │    ├─■──новинка_supernovasuperstar_supernova_extended_yustasgroup ── Topic: 283
#      │    │    │              │    │    │              │    │    │    │    └─■──eng_engsub_episode_season_uk ── Topic: 284
#      │    │    │              │    │    │              │    │    │    └─■──хреновость_выпуск_hовости_вечерний_утренний ── Topic: 45
#      │    │    │              │    │    │              │    │    └─граффити_прогулка_starlink_татуировка_шоколад
#      │    │    │              │    │    │              │    │         ├─граффити_прогулка_татуировка_праворадикальный_мальтийский
#      │    │    │              │    │    │              │    │         │    ├─■──прогулка_плленин_часть_центр_поддержка ── Topic: 105
#      │    │    │              │    │    │              │    │         │    └─граффити_татуировка_праворадикальный_мальтийский_гитлер
#      │    │    │              │    │    │              │    │         │         ├─■──граффити_мясник_амурский_надпись_пригожин ── Topic: 167
#      │    │    │              │    │    │              │    │         │         └─■──татуировка_праворадикальный_мальтийский_гитлер_череп ── Topic: 209
#      │    │    │              │    │    │              │    │         └─starlink_шоколад_маск_заказ_торт
#      │    │    │              │    │    │              │    │              ├─starlink_маск_илона_spacex_спутниковый
#      │    │    │              │    │    │              │    │              │    ├─■──билборд_плакат_разъяснять_доступный_устанавливать ── Topic: 241
#      │    │    │              │    │    │              │    │              │    └─■──starlink_маск_илона_spacex_спутниковый ── Topic: 300
#      │    │    │              │    │    │              │    │              └─■──шоколад_заказ_торт_алешка_чизкейка ── Topic: 171
#      │    │    │              │    │    │              │    └─петиция_подписывать_подпись_сухоруков_актер
#      │    │    │              │    │    │              │         ├─петиция_подписывать_подпись_сухоруков_актер
#      │    │    │              │    │    │              │         │    ├─сухоруков_актер_фидар_ято_артист
#      │    │    │              │    │    │              │         │    │    ├─■──грозный_дорожный_позитивчик_verpissen_аяз ── Topic: 71
#      │    │    │              │    │    │              │         │    │    └─■──сухоруков_актер_фидар_ято_артист ── Topic: 144
#      │    │    │              │    │    │              │         │    └─петиция_подпись_подписывать_требование_changeorg
#      │    │    │              │    │    │              │         │         ├─■──петиция_подпись_подписывать_требование_changeorg ── Topic: 48
#      │    │    │              │    │    │              │         │         └─■──pda_хештег_kissin_ждемс_поцелуй ── Topic: 186
#      │    │    │              │    │    │              │         └─юмор_комик_троцо_дно_шутка
#      │    │    │              │    │    │              │              ├─юмор_комик_дно_шутка_мордор
#      │    │    │              │    │    │              │              │    ├─■──юмор_комик_шутка_мордор_смех ── Topic: 296
#      │    │    │              │    │    │              │              │    └─■──passo_mule_duca_delle_дон ── Topic: 130
#      │    │    │              │    │    │              │              └─троцо_стикер_заправка_клеить_таблетница
#      │    │    │              │    │    │              │                   ├─■──стикер_заправка_клеить_таблетница_стул ── Topic: 168
#      │    │    │              │    │    │              │                   └─■──троцо_снипаразуа_презумция_медоуз_нуччо ── Topic: 214
#      │    │    │              │    │    │              └─воз_навязывать_аргентина_мексика_незаконный
#      │    │    │              │    │    │                   ├─чайковский_балет_вперед_двигаться_8000
#      │    │    │              │    │    │                   │    ├─чайковский_балет_гибридный_театр_справка
#      │    │    │              │    │    │                   │    │    ├─■──чайковский_балет_театр_ведение_туалетный ── Topic: 97
#      │    │    │              │    │    │                   │    │    └─гибридный_справка_замедление_союз21а_обусловливать
#      │    │    │              │    │    │                   │    │         ├─■──гибридный_справка_замедление_обусловливать_минимизировать ── Topic: 204
#      │    │    │              │    │    │                   │    │         └─■──союз21а_бригада_гвардейский_ракетаноситель_zнай ── Topic: 181
#      │    │    │              │    │    │                   │    └─вперед_двигаться_8000_победный_уверенно
#      │    │    │              │    │    │                   │         ├─■──вперед_8000_победный_уверенно_1500 ── Topic: 298
#      │    │    │              │    │    │                   │         └─■──самораспад_уничтожение_прогнивать_неповинный_тридцать ── Topic: 238
#      │    │    │              │    │    │                   └─воз_навязывать_аргентина_мексика_незаконный
#      │    │    │              │    │    │                        ├─аргентина_мексика_незаконный_навязывать_бразилия
#      │    │    │              │    │    │                        │    ├─аргентина_мексика_навязывать_бразилия_ноша
#      │    │    │              │    │    │                        │    │    ├─■──ноша_исторически_усиление_навязывать_приобретение ── Topic: 286
#      │    │    │              │    │    │                        │    │    └─■──аргентина_мексика_бразилия_спровоцировать_незаконный ── Topic: 243
#      │    │    │              │    │    │                        │    └─корпеть_головоломка_недружественный_стратег_блестящий
#      │    │    │              │    │    │                        │         ├─■──корпеть_головоломка_недружественный_стратег_блестящий ── Topic: 246
#      │    │    │              │    │    │                        │         └─■──шанхайский_самарканд_партнерский_безуспешно_содружество ── Topic: 282
#      │    │    │              │    │    │                        └─воз_выход_оспа_здравоохранение_организация
#      │    │    │              │    │    │                             ├─■──воз_выход_здравоохранение_организация_health ── Topic: 244
#      │    │    │              │    │    │                             └─■──оспа_комар_обезьяна_комаров_газон ── Topic: 288
#      │    │    │              │    │    └─мариуполь_азовский_город_море_центр
#      │    │    │              │    │         ├─мариуполь_азовский_город_море_центр
#      │    │    │              │    │         │    ├─■──азовцев_своевременность_пятно_комбинат_заложник ── Topic: 266
#      │    │    │              │    │         │    └─мариуполь_азовский_город_море_центр
#      │    │    │              │    │         │         ├─■──мариуполь_азовский_город_море_центр ── Topic: 89
#      │    │    │              │    │         │         └─■──средневековье_грабеж_погружаться_мародерство_город ── Topic: 268
#      │    │    │              │    │         └─■──квартира_военностроительный_278_ключ_построить ── Topic: 299
#      │    │    │              │    └─паспорт_венгрия_ес_терроризм_гражданство
#      │    │    │              │         ├─терроризм_спонсор_государствомспонсор_резолюция_европарламент
#      │    │    │              │         │    ├─■──терроризм_киевлянин_расстрел_метка_град ── Topic: 304
#      │    │    │              │         │    └─■──терроризм_спонсор_государствомспонсор_резолюция_европарламент ── Topic: 252
#      │    │    │              │         └─паспорт_венгрия_ес_гражданство_виза
#      │    │    │              │              ├─венгрия_ес_виза_санкция_выдача
#      │    │    │              │              │    ├─■──чичерина_расторгуев_газманов_издержки_чашка ── Topic: 271
#      │    │    │              │              │    └─венгрия_виза_ес_выдача_латвия
#      │    │    │              │              │         ├─■──венгрия_сийярто_петер_ес_европа ── Topic: 180
#      │    │    │              │              │         └─■──виза_выдача_латвия_россиянин_шенгенский ── Topic: 141
#      │    │    │              │              └─■──паспорт_гражданство_отбывание_макичян_лишение ── Topic: 104
#      │    │    │              └─die_und_check_covid19_der
#      │    │    │                   ├─■──covid19_вакцина_check_вакцинация_pfizer ── Topic: 117
#      │    │    │                   └─■──die_und_der_das_noch ── Topic: 153
#      │    │    └─ктото_страшно_брат_тропа_сохранять
#      │    │         ├─погибать_обстрел_удар_сообщать_всу
#      │    │         │    ├─аэс_запорожский_всу_войско_энергоблок
#      │    │         │    │    ├─северодонецкий_войско_снабжаться_сосредотачивать_всу
#      │    │         │    │    │    ├─северодонецкий_снабжаться_сосредотачивать_войско_артемовсксеверск
#      │    │         │    │    │    │    ├─■──снабжаться_северодонецкий_артемовсксеверск_негативно_уменьшать ── Topic: 236
#      │    │         │    │    │    │    └─■──северск_перемещаться_отодвигать_милиция_народный ── Topic: 253
#      │    │         │    │    │    └─■──британский_этап_дисциплинировать_опасный_telegraph ── Topic: 292
#      │    │         │    │    └─аэс_запорожский_энергоблок_станция_всу
#      │    │         │    │         ├─аэс_запорожский_энергоблок_станция_видео
#      │    │         │    │         │    ├─■──аэс_запорожский_энергоблок_станция_заэс ── Topic: 92
#      │    │         │    │         │    └─■──видео_пулеметчик_процедура_орк_плен ── Topic: 143
#      │    │         │    │         └─■──текиваться_бандеромобиль_танк_сука_хоча ── Topic: 198
#      │    │         │    └─погибать_сообщать_обстрел_жилой_удар
#      │    │         │         ├─погибать_сообщать_погибший_пожар_удар
#      │    │         │         │    ├─■──мальчик_хлопчик_5ти_розстріляли_генпрокурор ── Topic: 254
#      │    │         │         │    └─погибать_сообщать_погибший_пожар_удар
#      │    │         │         │         ├─погибать_сообщать_погибший_пожар_удар
#      │    │         │         │         │    ├─■──буча_радиосообщение_122мм_местный_убийство ── Topic: 220
#      │    │         │         │         │    └─погибать_сообщать_пожар_погибший_потеря
#      │    │         │         │         │         ├─■──погибать_потеря_погибший_захоронение_могила ── Topic: 17
#      │    │         │         │         │         └─■──пожар_взрыв_жилой_повреждать_окт ── Topic: 19
#      │    │         │         │         └─■──решка_варварство_кулеб_орел_лукашенковский ── Topic: 308
#      │    │         │         └─донецк_террорист_восемь_замечать_15022015
#      │    │         │              ├─донецк_авг_роддом_ukraine_артобстрел
#      │    │         │              │    ├─■──авг_ukraine_последствие_донецк_жилой ── Topic: 161
#      │    │         │              │    └─■──донецк_роддом_нетайлово_куйбышевский_роженица ── Topic: 145
#      │    │         │              └─террорист_восемь_замечать_молчать_донецк
#      │    │         │                   ├─■──террорист_восемь_15022015_замечать_донецк ── Topic: 185
#      │    │         │                   └─■──молчать_жечь_позвонить_везти_вы ── Topic: 273
#      │    │         └─ктото_страшно_брат_тропа_сохранять
#      │    │              ├─крым_мост_воссоединение_крымский_севастополь
#      │    │              │    ├─фильм_видео_эфир_украина_журналист
#      │    │              │              │    ├─беларусь_беженец_польша_агрэсіі_тэрыторыі
#      │    │              │              │    │    ├─■──беларусь_агрэсіі_тэрыторыі_рэспублікі_супраць ── Topic: 72
#      │    │              │              │    │    └─беженец_польша_украина_украинец_европа
#      │    │              │              │    │         ├─■──ja_voit_myös_частичка_tilanteesta ── Topic: 146
#      │    │              │              │    │         └─беженец_польша_украинец_европа_украина
#      │    │              │              │    │              ├─■──украина_слава_стинг_ukraine_вы ── Topic: 25
#      │    │              │              │    │              └─■──беженец_польша_европа_нидерланды_украинец ── Topic: 60
#      │    │              │              │    └─изнасиловать_изнасилование_сексуальный_женщина_насилие
#      │    │              │              │         ├─эслин_хасигов_пленный_ссылать_буча
#      │    │              │              │         │    ├─■──эслин_хасигов_ссылать_пленный_ури ── Topic: 200
#      │    │              │              │         │    └─■──герцог_рашистский_буча_пыточный_тело ── Topic: 279
#      │    │              │              │         └─изнасиловать_изнасилование_сексуальный_женщина_насилие
#      │    │              │              │              ├─изнасиловать_изнасилование_сексуальный_женщина_насилие
#      │    │              │              │              │    ├─■──изнасиловать_изнасилование_сексуальный_насилие_женщина ── Topic: 135
#      │    │              │              │              │    └─■──як_що_лягушка_ми_вы ── Topic: 190
#      │    │              │              │              └─■──вы_загребать_репродуктивный_тогда_полегать ── Topic: 277
#      │    │              │              └─учитель_язык_москва_русский_математика
#      │    │              │                   ├─учитель_язык_москва_математика_литература
#      │    │              │                   │    ├─■──учитель_москва_язык_математика_литература ── Topic: 203
#      │    │              │                   │    └─русофобия_русский_усср_чело_мэр
#      │    │              │                   │         ├─русофобия_русский_т34_дискриминация_техобслуживание
#      │    │              │                   │         │    ├─■──т34_техобслуживание_наизнанку_постамент_хватать ── Topic: 260
#      │    │              │                   │         │    └─■──русофобия_дискриминация_русский_язык_пидорас ── Topic: 136
#      │    │              │                   │         └─усср_чело_мэр_ройзман_мвд
#      │    │              │                   │              ├─■──усср_чело_подполье_грек_обрусение ── Topic: 213
#      │    │              │                   │              └─■──мэр_ройзман_савлученко_мвд_медведчук ── Topic: 235
#      │    │              │                   └─русский_обращение_айтуган_подполковник_послушать
#      │    │              │                        ├─русский_айтуган_обращение_подполковник_послушать
#      │    │              │                        │    ├─■──айтуган_левкин_соцсеть_русня_русский ── Topic: 57
#      │    │              │                        │    └─послушать_лысюк_подполковник_русский_солдат
#      │    │              │                        │         ├─■──лысюк_послушать_генералмайор_подполковник_орк ── Topic: 100
#      │    │              │                        │         └─■──солдат_автобус_русский_чать_обращение ── Topic: 119
#      │    │              │                        └─■──сартан_мов_грек_белорус_гребец ── Topic: 210
#      │    │              └─ктото_страшно_брат_тропа_сохранять
#      │    │                   ├─ктото_страшно_брат_тропа_прикасаться
#      │    │                   │    ├─ктото_страшно_брат_тропа_прикасаться
#      │    │                   │    │    ├─ктото_страшно_брат_тропа_прикасаться
#      │    │                   │    │    │    ├─милосердие_кулак_достоинство_жемчуг_милосердный
#      │    │                   │    │    │    │    ├─■──милосердие_кулак_жемчуг_милосердный_нереально ── Topic: 199
#      │    │                   │    │    │    │    └─■──удовлетворение_достоинство_опасаться_анисимов_человеческий ── Topic: 280
#      │    │                   │    │    │    └─ктото_страшно_брат_тропа_прикасаться
#      │    │                   │    │    │         ├─дурак_оскорблять_ты_высказывать_высказываться
#      │    │                   │    │    │         │    ├─■──пословица_родитель_людской_переговорщик_слышать ── Topic: 184
#      │    │                   │    │    │         │    └─дурак_оскорблять_ты_высказывать_высказываться
#      │    │                   │    │    │         │         ├─■──оскорблять_дурак_высказывать_высказываться_истинность ── Topic: 187
#      │    │                   │    │    │         │         └─■──полоса_морок_безумствовать_америкос_ты ── Topic: 222
#      │    │                   │    │    │         └─■──ктото_страшно_брат_тропа_прикасаться ── Topic: 14
#      │    │                   │    │    └─лидер_че_очевидец_да_ты
#      │    │                   │    │         ├─лидер_че_очевидец_да_ты
#      │    │                   │    │         │    ├─■──просыпаться_сон_сниться_кошмар_мамочка ── Topic: 276
#      │    │                   │    │         │    └─лидер_че_очевидец_да_артуганов
#      │    │                   │    │         │         ├─лидер_че_очевидец_да_ты
#      │    │                   │    │         │         │    ├─■──темнота_ад_воскресать_че_христос ── Topic: 293
#      │    │                   │    │         │         │    └─■──лидер_че_очевидец_да_артуганов ── Topic: 9
#      │    │                   │    │         │         └─■──собака_пес_кот_корова_животное ── Topic: 61
#      │    │                   │    │         └─стрелять_little_kimi_derdinde_видеть
#      │    │                   │    │              ├─■──little_derdinde_kimi_добавлять_видеть ── Topic: 79
#      │    │                   │    │              └─■──стрелять_откуда_харьков_дневник_бомбить ── Topic: 152
#      │    │                   │    └─затевать_мир_мужчина_доставаться_бы
#      │    │                   │         ├─затевать_мужчина_доставаться_бы_даваться
#      │    │                   │         │    ├─■──затевать_мужчина_доставаться_бы_даваться ── Topic: 251
#      │    │                   │         │    └─■──блаженный_плодовый_путлеркапут_пролитие_пынь ── Topic: 52
#      │    │                   │         └─мир_пусть_peace_sulh_небо
#      │    │                   │              ├─■──мир_peace_sulh_пусть_во ── Topic: 124
#      │    │                   │              └─■──пусть_id75915720максим_photographer_бытьпросто_прекрасеннужно ── Topic: 302
#      │    │                   └─no_we_is_want_more
#      │    │                        ├─■──we_кристина_алена_583_ивановна ── Topic: 194
#      │    │                        └─no_we_is_want_more
#      │    │                             ├─■──is_we_are_to_here ── Topic: 287
#      │    │                             └─■──no_want_war_dont_oh ── Topic: 219
#      │    └─противник_уничтожать_подразделение_оборона_войско
#      │         ├─противник_уничтожать_подразделение_населенный_националист
#      │         │    ├─противник_уничтожать_населенный_подразделение_националист
#      │         │    │    ├─■──суняйкин_руднев_варяг_аксенов_всеволод ── Topic: 310
#      │         │    │    └─противник_уничтожать_националист_подразделение_населенный
#      │         │    │         ├─противник_уничтожать_населенный_подразделение_националист
#      │         │    │         │    ├─■──уничтожать_всу_район_направление_населенный ── Topic: 11
#      │         │    │         │    └─■──противник_националист_сержант_старший_подразделение ── Topic: 18
#      │         │    │         └─■──завадский_противник_лейтенант_имам_ищенко ── Topic: 261
#      │         │    └─вручать_награда_медаль_мужество_награждать
#      │         │         ├─■──герой_товарищ_вошок_лейтенант_сержант ── Topic: 138
#      │         │         └─■──вручать_награда_медаль_награждать_мужество ── Topic: 39
#      │         └─пво_противовоздушный_вертолет_ракета_войско
#      │              ├─пво_противовоздушный_войско_оборона_небо
#      │              │    ├─■──пво_противовоздушный_войско_оборона_небо ── Topic: 84
#      │              │    └─■──су25_самолет_пво_пилот_штурмовик ── Topic: 249
#      │              └─вертолет_ракета_дрон_беспилотник_сбивать
#      │                   ├─■──вертолет_дрон_беспилотник_ракета_дронов ── Topic: 21
#      │                   └─■──ракета_кассетный_155мм_боеприпасы_himars ── Topic: 123
#      └─сталинградский_битва_единый_помощь_наш
#           ├─единый_помощь_гуманитарный_партия_область
#           │    ├─производство_рубль_правительство_объясняемрф_выплата
#           │    │    ├─производство_производитель_компания_импортозамещение_продукция
#           │    │    │    ├─препарат_лекарство_биологический_лаборатория_заболевание
#           │    │    │    │    ├─■──биологический_лаборатория_биолаборатория_metabiota_инфекционный ── Topic: 125
#           │    │    │    │    └─■──препарат_лекарство_дефицит_аптека_производство ── Topic: 85
#           │    │    │    └─производство_производитель_импортозамещение_продукция_компания
#           │    │    │         ├─хлеб_производство_продукция_посевной_обеспечивать
#           │    │    │         │    ├─■──аграрий_посевной_продовольственный_хозяйство_производитель ── Topic: 212
#           │    │    │         │    └─■──хлеб_производство_продукция_хлебобулочный_пекарня ── Topic: 140
#           │    │    │         └─производство_производитель_импортозамещение_компания_рынок
#           │    │    │              ├─производство_импортозамещение_производитель_предприятие_рынок
#           │    │    │              │    ├─■──шоколад_ппс_десерт_достоверный_поставщик ── Topic: 306
#           │    │    │              │    └─■──производство_импортозамещение_производитель_рынок_компания ── Topic: 50
#           │    │    │              └─■──компания_бренд_москвич_рынок_renault ── Topic: 107
#           │    │    └─рубль_выплата_правительство_кредит_доход
#           │    │         ├─рубль_выплата_правительство_кредит_доход
#           │    │         │    ├─рубль_выплата_кредит_доход_правительство
#           │    │         │    │    ├─■──раздел_сервис_мера_госуслуга_портал ── Topic: 188
#           │    │         │    │    └─рубль_выплата_доход_кредит_правительство
#           │    │         │    │         ├─■──кредит_льготный_ставка_рубль_правительство ── Topic: 32
#           │    │         │    │         └─■──выплата_доход_пособие_пенсия_размер ── Topic: 36
#           │    │         │    └─строительство_жилье_регион_новосибирский_дорога
#           │    │         │         ├─■──жилье_детейсирота_служебный_эксплуатация_кв ── Topic: 265
#           │    │         │         └─■──строительство_дорога_домрф_развитие_планирование ── Topic: 158
#           │    │         └─лагерь_отдых_оздоровительный_летний_туризм
#           │    │              ├─■──туризм_турист_грант_сезон_агротуризм ── Topic: 87
#           │    │              └─■──лагерь_оздоровительный_отдых_летний_отдыхать ── Topic: 192
#           │    └─единый_помощь_гуманитарный_партия_житель
#           │         ├─референдум_запорожский_херсонский_область_республика
#           │         │    ├─признание_независимость_лнр_днр_сотрудничество
#           │         │    │    ├─■──сотрудничество_подписывать_взаимный_договор_дружба ── Topic: 225
#           │         │    │    └─■──независимость_признание_лнр_днр_признавать ── Topic: 93
#           │         │    └─референдум_запорожский_херсонский_область_республика
#           │         │         ├─референдум_запорожский_херсонский_вхождение_область
#           │         │         │    ├─льгота_доброволец_строитель_строительный_единый
#           │         │         │    │    ├─■──строитель_строительный_студенческий_отряд_восстановление ── Topic: 90
#           │         │         │    │    └─льгота_ветеран_бесплатный_статус_доброволец
#           │         │         │    │         ├─■──экономический_предприниматель_интеграция_налоговый_мрот ── Topic: 223
#           │         │         │    │         └─■──льгота_ветеран_бесплатный_статус_доброволец ── Topic: 78
#           │         │         │    └─референдум_запорожский_херсонский_вхождение_область
#           │         │         │         ├─референдум_запорожский_херсонский_вхождение_область
#           │         │         │         │    ├─■──референдум_запорожский_херсонский_вхождение_голосование ── Topic: 6
#           │         │         │         │    └─■──отделение_региональный_партия_единый_секретарь ── Topic: 24
#           │         │         │         └─■──догазификация_депутат_новосибирский_подавать_заявка ── Topic: 257
#           │         │         └─спорт_спортивный_соревнование_спортсмен_книга
#           │         │              ├─книга_библиотека_школа_литература_учебник
#           │         │              │    ├─■──вуз_экзамен_егэ_абитуриент_образование ── Topic: 91
#           │         │              │    └─книга_библиотека_литература_учебник_школа
#           │         │              │         ├─■──школа_учебный_школьный_малообеспеченный_многодетный ── Topic: 96
#           │         │              │         └─■──книга_библиотека_литература_учебник_язык ── Topic: 30
#           │         │              └─спорт_спортивный_соревнование_спортсмен_болельщик
#           │         │                   ├─■──досуговый_центр_настольный_творческий_спортинвентарь ── Topic: 160
#           │         │                   └─■──спорт_спортивный_соревнование_спортсмен_болельщик ── Topic: 13
#           │         └─помощь_единый_гуманитарный_волонтер_центр
#           │              ├─помощь_гуманитарный_единый_волонтер_центр
#           │              │    ├─обогрев_мариуполь_пункт_пропадать_poiskmariupolru
#           │              │    │    ├─обогрев_пункт_readovka_развертывать_мариуполь
#           │              │    │    │    ├─■──каша_кухня_полевой_чай_горячий ── Topic: 177
#           │              │    │    │    └─■──обогрев_пункт_readovka_развертывать_мариуполь ── Topic: 37
#           │              │    │    └─■──пропадать_poiskmariupolru_поиск_заявка_сайт ── Topic: 121
#           │              │    └─помощь_гуманитарный_единый_центр_волонтер
#           │              │         ├─помощь_гуманитарный_единый_центр_волонтер
#           │              │         │    ├─■──семья_мобилизовать_заявка_помощь_штаб ── Topic: 34
#           │              │         │    └─гуманитарный_помощь_единый_центр_житель
#           │              │         │         ├─гуманитарный_помощь_единый_центр_житель
#           │              │         │         │    ├─■──волонтер_лекарство_сахалин_житель_волонтерский ── Topic: 73
#           │              │         │         │    └─гуманитарный_помощь_единый_центр_груз
#           │              │         │         │         ├─■──гуманитарный_помощь_центр_единый_груз ── Topic: 4
#           │              │         │         │         └─■──эвакуация_эвакуировать_размещение_волонтер_временный ── Topic: 31
#           │              │         │         └─■──врач_пациент_медицинский_медик_единый ── Topic: 5
#           │              │         └─пожилой_доставлять_подробность_престарелый_частично
#           │              │              ├─■──возвращаться_подробность_распределительный_налаживаться_тепло ── Topic: 274
#           │              │              └─■──пожилой_престарелый_доставлять_частично_многодетный ── Topic: 163
#           │              └─тактический_аптечка_жгут_медицина_военнополевый
#           │                   ├─военнополевый_хубез_хирургия_госпиталь_медик
#           │                   │    ├─■──выздоровление_реабилитация_госпиталь_навещать_пожелание ── Topic: 247
#           │                   │    └─■──военнополевый_хубез_хирургия_интерактивный_медик ── Topic: 113
#           │                   └─тактический_аптечка_жгут_медицина_валуев
#           │                        ├─■──тактический_медицина_обучать_курсы_мгер ── Topic: 95
#           │                        └─■──валуев_якубовский_привозить_термобелье_жгут ── Topic: 139
#           └─сталинградский_битва_неонацист_армия_наш
#                ├─сталинградский_битва_неонацист_герой_год
#                │    ├─песня_письмо_акция_поддержка_концерт
#                │    │    ├─митинг_поддержка_флешмоб_акция_антивоенный
#                │    │    │    ├─флешмоб_поддержка_автопробег_знак_буква
#                │    │    │    │    ├─автопробег_буква_великолукский_знак_повязка
#                │    │    │    │    │    ├─■──великолукский_буква_гсха_колонный_автопробег ── Topic: 211
#                │    │    │    │    │    └─■──автопробег_повязка_буква_символ_автомобиль ── Topic: 134
#                │    │    │    │    └─■──флешмоб_поддержка_участвовать_присоединяться_флэшмоб ── Topic: 82
#                │    │    │    └─митинг_антивоенный_протест_против_акция
#                │    │    │         ├─■──митинг_антивоенный_протест_против_акция ── Topic: 23
#                │    │    │         └─■──алеппо_сирийский_хомс_сирия_дамаск ── Topic: 290
#                │    │    └─песня_письмо_акция_концерт_памятник
#                │    │         ├─письмо_акция_ребята_посылка_рисунок
#                │    │         │    ├─храбрость_акция_коробка_открытка_адрес
#                │    │         │    │    ├─■──храбрость_коробка_акция_игрушка_игрушкуподарок ── Topic: 275
#                │    │         │    │    └─■──открытка_акция_лицей_ротонда_заруцкий ── Topic: 156
#                │    │         │    └─письмо_ребята_акция_посылка_рисунок
#                │    │         │         ├─письмо_ребята_акция_посылка_рисунок
#                │    │         │         │    ├─■──поблагодарить_видео_благодарность_росгвардеец_ленинградский ── Topic: 164
#                │    │         │         │    └─письмо_ребята_акция_посылка_рисунок
#                │    │         │         │         ├─письмо_акция_ребята_посылка_рисунок
#                │    │         │         │         │    ├─■──проект_передовая_народный_вещь_боец ── Topic: 151
#                │    │         │         │         │    └─письмо_акция_ребята_рисунок_посылка
#                │    │         │         │         │         ├─■──тепло_посылка_маскировочный_шить_теплый ── Topic: 51
#                │    │         │         │         │         └─■──письмо_акция_рисунок_написать_солдат ── Topic: 15
#                │    │         │         │         └─■──карта_руб_спасибо_катетер_оплачивать ── Topic: 108
#                │    │         │         └─■──больничный_электронный_психологический_кабинет_гайковерт ── Topic: 174
#                │    │         └─песня_концерт_памятник_автор_свеча
#                │    │              ├─памятник_монумент_мемориал_свеча_саурмогила
#                │    │              │    ├─свеча_зажигать_память_деньпамятирф_вечный
#                │    │              │    │    ├─■──свеча_окопный_блиндажный_изготовление_тепло ── Topic: 166
#                │    │              │    │    └─■──свеча_зажигать_память_деньпамятирф_вечный ── Topic: 110
#                │    │              │    └─памятник_монумент_мемориал_саурмогила_снос
#                │    │              │         ├─■──мемориал_саурмогила_монумент_памятник_мемориальный ── Topic: 59
#                │    │              │         └─■──памятник_снос_рига_монумент_демонтировать ── Topic: 68
#                │    │              └─песня_концерт_автор_конкурс_музыка
#                │    │                   ├─песня_концерт_автор_конкурс_музыка
#                │    │                   │    ├─песня_концерт_музыка_артист_исполнять
#                │    │                   │    │    ├─■──собчак_extended_песня_бунин_хоровой ── Topic: 154
#                │    │                   │    │    └─песня_концерт_музыка_артист_исполнять
#                │    │                   │    │         ├─■──песня_музыка_клип_исполнять_певец ── Topic: 8
#                │    │                   │    │         └─■──концерт_благотворительный_марафон_музыкальный_состояться ── Topic: 33
#                │    │                   │    └─конкурс_автор_художник_фирменный_награждение
#                │    │                   │         ├─конкурс_автор_художник_фирменный_проект
#                │    │                   │         │    ├─конкурс_автор_фирменный_мерч_церемония
#                │    │                   │         │    │    ├─■──конкурс_автор_фирменный_мерч_церемония ── Topic: 103
#                │    │                   │         │    │    └─■──стихотворение_стих_поэт_поэзия_поэтический ── Topic: 81
#                │    │                   │         │    └─■──художник_картина_кузбасский_полотно_искусство ── Topic: 126
#                │    │                   │         └─карабет_кузбасс_качура_коммуницировать_женщинакомандир
#                │    │                   │              ├─■──карабет_качура_коммуницировать_антипова_женщинакомандир ── Topic: 256
#                │    │                   │              └─■──неделя_кузбасс_главное_цивилев_блокадный ── Topic: 208
#                │    │                   └─горловка_медиамарафон_куzбасс_средство_счет
#                │    │                        ├─■──медиамарафон_куzбасс_горловка_эфир_0500 ── Topic: 305
#                │    │                        └─■──горловка_счет_40703810326000001325_30101810200000000612_043207612 ── Topic: 221
#                │    └─сталинградский_битва_неонацист_герой_эстафета
#                │         ├─сталинградский_битва_неонацист_эстафета_притесняться
#                │         │    ├─сталинградский_битва_неонацист_эстафета_притесняться
#                │         │    │    ├─■──кубань_труженик_склонять_память_нерехтский ── Topic: 215
#                │         │    │    └─■──сталинградский_битва_неонацист_эстафета_притесняться ── Topic: 3
#                │         │    └─праздник_калашников_государственность_оборонный_автомат
#                │         │         ├─калашников_государственность_оборонный_автомат_конструктор
#                │         │         │    ├─■──калашников_оборонный_автомат_конструктор_оружейник ── Topic: 44
#                │         │         │    └─государственность_ссср_1918_независимость_государство
#                │         │         │         ├─■──танкист_танковый_праздник_отметаться_танкостроитель ── Topic: 216
#                │         │         │         └─■──государственность_1918_ссср_независимость_государство ── Topic: 77
#                │         │         └─праздник_поздравлять_новогодний_вдв_день
#                │         │              ├─праздник_вдв_поздравлять_день_десантник
#                │         │              │    ├─■──вдв_десантник_воздушнодесантный_войско_являть ── Topic: 76
#                │         │              │    └─праздник_отечество_день_защитник_афганистан
#                │         │              │         ├─праздник_отечество_поздравлять_защитник_день
#                │         │              │         │    ├─■──праздник_здоровье_день_поздравлять_крепкий ── Topic: 120
#                │         │              │         │    └─■──праздник_отечество_защитник_поздравлять_день ── Topic: 67
#                │         │              │         └─■──афганистан_предел_дата_долг_праздник ── Topic: 112
#                │         │              └─■──новогодний_подарок_елка_праздник_семья ── Topic: 58
#                │         └─наш_солдат_гордиться_вы_герой
#                │              ├─наш_солдат_гордиться_армия_герой
#                │              │    ├─■──равнодушие_ананин_воспитатель_205_кемерово ── Topic: 189
#                │              │    └─наш_солдат_гордиться_армия_герой
#                │              │         ├─наш_солдат_армия_гордиться_спасибо
#                │              │         │    ├─■──спасибо_вы_благодарить_благодарность_ребята ── Topic: 70
#                │              │         │    └─наш_армия_солдат_гордиться_поддерживать
#                │              │         │         ├─■──наш_армия_солдат_гордиться_мужество ── Topic: 10
#                │              │         │         └─■──спецоперация_наш_поддерживать_защищать_поддержка ── Topic: 88
#                │              │         └─■──герой_парень_гордиться_рисковать_он ── Topic: 38
#                │              └─домой_ждать_воин_вы_кемерово
#                │                   ├─воин_домой_вы_ждать_кемерово
#                │                   │    ├─■──воин_мисько_окаменевать_желать_кемерово ── Topic: 206
#                │                   │    └─■──домой_vыполняйте_ждать_zадачи_вы ── Topic: 63
#                │                   └─■──удача_зубр_богомолов_пожелать_кемеровский ── Topic: 202
#                └─президент_наш_решение_спецоперация_поддерживать
#                     ├─наш_армия_оружие_гордость_запад
#                     │    ├─наемник_оружие_поставлять_армия_запад
#                     │    │    ├─агония_героически_противостоять_четко_поставлять
#                     │    │    │    ├─■──вынашивать_разоружать_неприкрытый_ослабление_запад ── Topic: 278
#                     │    │    │    └─■──агония_героически_четко_противостоять_поставлять ── Topic: 127
#                     │    │    └─наемник_горевояк_оснащать_остужать_западный
#                     │    │         ├─горевояк_остужать_пыл_пострелять_масть
#                     │    │         │    ├─■──горевояк_остужать_пыл_пострелять_масть ── Topic: 128
#                     │    │         │    └─вооруженный_выполнять_поставлять_наш_поддерживать
#                     │    │         │         ├─■──оснащать_армия_затрагивать_вооруженный_интерес ── Topic: 255
#                     │    │         │         └─■──важно_поддерживать_поставлять_наш_перед ── Topic: 242
#                     │    │         └─оснащать_превосходство_недоученность_накапливать_профессиональный
#                     │    │              ├─■──недоученность_накапливать_профессиональный_интерес_западный ── Topic: 109
#                     │    │              └─■──численный_оснащать_реалия_наемник_доля ── Topic: 228
#                     │    └─гордость_народ_наш_очевидный_российский
#                     │         ├─народ_очевидный_сплачиваться_нацизм_бороться
#                     │         │    ├─внутри_обороноспособность_суверенитет_наш_богатство
#                     │         │    │    ├─■──сомоотверженный_опякина_крутота_тельмановский_стихотворный ── Topic: 307
#                     │         │    │    └─внутри_обороноспособность_суверенитет_богатство_завистник
#                     │         │    │         ├─■──внутри_обороноспособность_природный_богатство_традиция ── Topic: 262
#                     │         │    │         └─■──суверенитет_завистник_ресурс_мощи_крупномасштабный ── Topic: 224
#                     │         │    └─очевидный_сплачиваться_народ_нацизм_бороться
#                     │         │         ├─очевидный_сплачиваться_нацизм_экстремальный_народ
#                     │         │         │    ├─очевидный_экстремальный_невиданный_справедливость_народ
#                     │         │         │    │    ├─■──произвол_духовно_народ_бросать_право ── Topic: 248
#                     │         │         │    │    └─■──очевидный_экстремальный_невиданный_консолидация_справедливость ── Topic: 133
#                     │         │         │    └─■──сплачиваться_заключаться_оставлять_особенно_натравлять ── Topic: 102
#                     │         │         └─самообладание_переживать_благополучие_желать_воздух
#                     │         │              ├─■──самообладание_воздух_благополучие_всячески_держать ── Topic: 173
#                     │         │              └─■──вскоре_переживать_спокойствие_исход_искренне ── Topic: 239
#                     │         └─гордость_местный_благословление_кислота_ценность
#                     │              ├─■──заколдовывать_жить_пронзать_сражать_стрела ── Topic: 294
#                     │              └─гордость_местный_благословление_кислота_ценность
#                     │                   ├─■──гордость_благословление_кислота_ценность_одобрение ── Topic: 118
#                     │                   └─■──примечательно_разгрузка_правоохранитель_распределение_впечатлять ── Topic: 195
#                     └─президент_решение_спецоперация_наш_правильный
#                          ├─президент_решение_правильный_наш_владимир
#                          │    ├─президент_решение_правильный_доверие_доверять
#                          │    │    ├─доверие_доверять_вциом_президент_давление
#                          │    │    │    ├─■──давление_беспрерывный_огульный_сплоченность_конструктивно ── Topic: 303
#                          │    │    │    └─доверие_доверять_вциом_президент_одобрять
#                          │    │    │         ├─■──вциом_доверие_доверять_одобрять_опрос ── Topic: 62
#                          │    │    │         └─■──правильный_индекс_точечный_решение_полтора ── Topic: 217
#                          │    │    └─диктовать_будущее_решение_напрямую_угрожать
#                          │    │         ├─диктовать_будущее_напрямую_угрожать_решение
#                          │    │         │    ├─■──бесконтрольный_своевременность_накачивать_удивительно_явно ── Topic: 193
#                          │    │         │    └─будущее_диктовать_напрямую_угрожать_позволять
#                          │    │         │         ├─■──будущее_диктовать_напрямую_угрожать_позволять ── Topic: 101
#                          │    │         │         └─■──решение_русскоязычный_президент_единственно_безоговорочно ── Topic: 240
#                          │    │         └─■──неделимый_упреждающий_отпор_справедливо_заговаривать ── Topic: 157
#                          │    └─президент_владимир_наш_владимирович_путин
#                          │         ├─президент_владимир_владимирович_наш_путин
#                          │         │    ├─президент_наш_поддерживать_гордиться_решение
#                          │         │    │    ├─■──решение_президент_петро_густаво_колумбия ── Topic: 162
#                          │         │    │    └─президент_поддерживать_гордиться_наш_владимирович
#                          │         │    │         ├─президент_гордиться_поддерживать_владимирович_наш
#                          │         │    │         │    ├─■──владимирович_президент_вместе_владимир_независимость ── Topic: 148
#                          │         │    │         │    └─■──президент_гордиться_поддерживать_наш_решение ── Topic: 27
#                          │         │    │         └─■──отстаивать_будущее_интерес_кромчанин_настоящее ── Topic: 169
#                          │         │    └─президент_владимир_путин_четкость_характеризовать
#                          │         │         ├─■──владимир_путин_поблагодарить_президент_владимирович ── Topic: 114
#                          │         │         └─■──четкость_президент_характеризовать_пмэф2022_тысячелетний ── Topic: 94
#                          │         └─единство_здорово_сильный_победа_активно
#                          │              ├─■──здорово_единство_сильный_активно_прийти ── Topic: 233
#                          │              └─■──победа_правый_фотография_правда_fall ── Topic: 201
#                          └─спецоперация_поддержка_выступать_кемерово_президент
#                               ├─спецоперация_кемерово_донбасс_высказывать_мнение
#                               │    ├─■──тычинин_50летия_игнорирование_терпеть_диктовать ── Topic: 285
#                               │    └─спецоперация_кемерово_донбасс_мнение_высказывать
#                               │         ├─спецоперация_кемерово_донбасс_мнение_поддерживать
#                               │         │    ├─■──горнева_ютиться_счастливый_акимов_кемерово ── Topic: 301
#                               │         │    └─спецоперация_кемерово_мнение_поддерживать_заведующий
#                               │         │         ├─спецоперация_кемерово_мнение_заведующий_поддерживать
#                               │         │         │    ├─спецоперация_заведующий_спортсооружение_поддерживать_нацизм
#                               │         │         │    │    ├─■──спортсооружение_нацизм_синицын_спецоперация_правильно ── Topic: 179
#                               │         │         │    │    └─■──спецоперация_острие_ягуновский_пристально_волошина ── Topic: 175
#                               │         │         │    └─■──музей_кемерово_янченко_шахтерский_спецоперация ── Topic: 229
#                               │         │         └─■──югатова_исключительный_импульс_окружной_капустина ── Topic: 270
#                               │         └─■──прасковья_крупская_высказывать_погреб_врачмузыкант ── Topic: 267
#                               └─директор_городской_поддержка_округ_спецоперация
#                                    ├─директор_вв_анжеросудженск_президент_специальный
#                                    │    ├─■──вв_пушкарева_методист_киселевский_федерация ── Topic: 196
#                                    │    └─■──анжеросудженск_директор_учительлогопед_поддержка_мбу ── Topic: 111
#                                    └─■──городской_выступать_калтанский_кольчугино_округ ── Topic: 159

# %%
model.save("./drive/MyDrive/Hackathon/compare_z_nowar_now_merged")

# %%
model.get_topic_info()
# Out:
#      Topic  Count                                               Name
# 0       -1  23288                                 -1_не_что_быть_это
# 1        0    696                             0_путин_он_ядерный_что
# 2        1    650                                 1_война_не_это_мир
# 3        2    596                       2_санкция_газ_экономика_цена
# 4        3    571          3_сталинградский_битва_неонацист_эстафета
# ..     ...    ...                                                ...
# 308    307     10  307_сомоотверженный_опякина_крутота_тельмановский
# 309    308     10                    308_решка_варварство_кулеб_орел
# 310    309     10                       309_маша_артем_краматорск_жд
# 311    310     10                  310_суняйкин_руднев_варяг_аксенов
# 312    311     10                  311_журналист_леттерман_петрэ_дэа
#
# [313 rows x 3 columns]

# %% [markdown]
# # Check topics of posts

# %%
model = BERTopic.load("./drive/MyDrive/Hackathon/compare_z_nowar_now_merged")

# %%
np.array(model.get_topic_info())[:96]
# Out:
# array([[-1, 23288, '-1_не_что_быть_это'],
#        [0, 696, '0_путин_он_ядерный_что'],
#        [1, 650, '1_война_не_это_мир'],
#        [2, 596, '2_санкция_газ_экономика_цена'],
#        [3, 571, '3_сталинградский_битва_неонацист_эстафета'],
#        [4, 531, '4_гуманитарный_помощь_центр_единый'],
#        [5, 389, '5_врач_пациент_медицинский_медик'],
#        [6, 383, '6_референдум_запорожский_херсонский_вхождение'],
#        [7, 334, '7_фашизм_нацизм_фашист_победа'],
#        [8, 332, '8_песня_музыка_клип_исполнять'],
#        [9, 325, '9_лидер_че_очевидец_да'],
#        [10, 289, '10_наш_армия_солдат_гордиться'],
#        [11, 259, '11_уничтожать_всу_район_направление'],
#        [12, 242, '12_информационный_информация_фейк_сеть'],
#        [13, 232, '13_спорт_спортивный_соревнование_спортсмен'],
#        [14, 218, '14_ктото_страшно_брат_тропа'],
#        [15, 213, '15_письмо_акция_рисунок_написать'],
#        [16, 199, '16_любовь_мир_ты_себя'],
#        [17, 189, '17_погибать_потеря_погибший_захоронение'],
#        [18, 186, '18_противник_националист_сержант_старший'],
#        [19, 180, '19_пожар_взрыв_жилой_повреждать'],
#        [20, 160, '20_русский_любить_ты_мы'],
#        [21, 159, '21_вертолет_дрон_беспилотник_ракета'],
#        [22, 156, '22_суд_лишение_штраф_уголовный'],
#        [23, 156, '23_митинг_антивоенный_протест_против'],
#        [24, 137, '24_отделение_региональный_партия_единый'],
#        [25, 135, '25_украина_слава_стинг_ukraine'],
#        [26, 129, '26_зеленский_ес_вступление_членство'],
#        [27, 128, '27_президент_гордиться_поддерживать_наш'],
#        [28, 128, '28_мобилизация_германия_нато_во'],
#        [29, 127, '29_твой_бог_млрд_молитва'],
#        [30, 124, '30_книга_библиотека_литература_учебник'],
#        [31, 121, '31_эвакуация_эвакуировать_размещение_волонтер'],
#        [32, 118, '32_кредит_льготный_ставка_рубль'],
#        [33, 118, '33_концерт_благотворительный_марафон_музыкальный'],
#        [34, 118, '34_семья_мобилизовать_заявка_помощь'],
#        [35, 117, '35_крым_воссоединение_севастополь_крымский'],
#        [36, 116, '36_выплата_доход_пособие_пенсия'],
#        [37, 111, '37_обогрев_пункт_readovka_развертывать'],
#        [38, 111, '38_герой_парень_гордиться_рисковать'],
#        [39, 110, '39_вручать_награда_медаль_награждать'],
#        [40, 106, '40_германия_leopard_украина_польша'],
#        [41, 103, '41_видео_фильм_евромайдан_зверь'],
#        [42, 103, '42_флаг_государственный_символ_поднятие'],
#        [43, 101, '43_мать_ваш_убивать_мама'],
#        [44, 98, '44_калашников_оборонный_автомат_конструктор'],
#        [45, 97, '45_хреновость_выпуск_hовости_вечерний'],
#        [46, 93, '46_флот_военноморский_вмф_моряк'],
#        [47, 87, '47_страх_стресс_тревога_психолог'],
#        [48, 85, '48_петиция_подпись_подписывать_требование'],
#        [49, 84, '49_мост_антоновский_крымский_переправа'],
#        [50, 82, '50_производство_импортозамещение_производитель_рынок'],
#        [51, 79, '51_тепло_посылка_маскировочный_шить'],
#        [52, 79, '52_блаженный_плодовый_путлеркапут_пролитие'],
#        [53, 77, '53_церковь_православный_патриарх_молитва'],
#        [54, 77, '54_переговоры_оон_сша_конфликт'],
#        [55, 76, '55_политика_не_вы_что'],
#        [56, 75, '56_юрист_пенсионер_адвокат_елена'],
#        [57, 75, '57_айтуган_левкин_соцсеть_русня'],
#        [58, 73, '58_новогодний_подарок_елка_праздник'],
#        [59, 71, '59_мемориал_саурмогила_монумент_памятник'],
#        [60, 71, '60_беженец_польша_европа_нидерланды'],
#        [61, 71, '61_собака_пес_кот_корова'],
#        [62, 70, '62_вциом_доверие_доверять_одобрять'],
#        [63, 68, '63_домой_vыполняйте_ждать_zадачи'],
#        [64, 68, '64_мой_жить_больно_любить'],
#        [65, 65, '65_весна_грач_зима_погода'],
#        [66, 63, '66_зерно_порт_судно_тонна'],
#        [67, 63, '67_праздник_отечество_защитник_поздравлять'],
#        [68, 62, '68_памятник_снос_рига_монумент'],
#        [69, 60, '69_бабушка_флаг_знамя_старушка'],
#        [70, 59, '70_спасибо_вы_благодарить_благодарность'],
#        [71, 59, '71_грозный_дорожный_позитивчик_verpissen'],
#        [72, 58, '72_беларусь_агрэсіі_тэрыторыі_рэспублікі'],
#        [73, 58, '73_волонтер_лекарство_сахалин_житель'],
#        [74, 58, '74_китай_сша_си_китайский'],
#        [75, 54, '75_эфир_прямой_телемарафон_телеканал'],
#        [76, 52, '76_вдв_десантник_воздушнодесантный_войско'],
#        [77, 51, '77_государственность_1918_ссср_независимость'],
#        [78, 51, '78_льгота_ветеран_бесплатный_статус'],
#        [79, 49, '79_little_derdinde_kimi_добавлять'],
#        [80, 49, '80_почему_варвар_теракт_митинг'],
#        [81, 49, '81_стихотворение_стих_поэт_поэзия'],
#        [82, 48, '82_флешмоб_поддержка_участвовать_присоединяться'],
#        [83, 47, '83_операция_цель_спецоперация_президент'],
#        [84, 47, '84_пво_противовоздушный_войско_оборона'],
#        [85, 46, '85_препарат_лекарство_дефицит_аптека'],
#        [86, 45, '86_ода_tanks_systems_were'],
#        [87, 45, '87_туризм_турист_грант_сезон'],
#        [88, 45, '88_спецоперация_наш_поддерживать_защищать'],
#        [89, 45, '89_мариуполь_азовский_город_море'],
#        [90, 44, '90_строитель_строительный_студенческий_отряд'],
#        [91, 43, '91_вуз_экзамен_егэ_абитуриент'],
#        [92, 43, '92_аэс_запорожский_энергоблок_станция'],
#        [93, 42, '93_независимость_признание_лнр_днр'],
#        [94, 41, '94_четкость_президент_характеризовать_пмэф2022']],
#       dtype=object)

# %%
topics = model.topics_

# %%
def find_indices(list_to_check, item_to_find):
    indices = []
    for idx, value in enumerate(list_to_check):
        if value == item_to_find:
            indices.append(idx)
    return indices

# %%
f = open("./drive/MyDrive/Hackathon/stop_words_russian.txt", "r", encoding="utf-8")
stop_words = f.read()
f.close()
stop_words = stop_words.split("\n")

# %%
new_topics = model.reduce_outliers(posts_nowar_clean+posts_z_clean, topics, threshold = 0.3)
# Out:
# 100%|██████████| 24/24 [00:29<00:00,  1.25s/it]

# %%
f = open('./drive/MyDrive/Hackathon/new_topics.pkl', 'wb')
pickle.dump(new_topics, f)
f.close()

# %%
f = open('./drive/MyDrive/Hackathon/new_topics.pkl', 'rb')
new_topics = pickle.load(f)
f.close()

# %%
def remove_suspicious_users(topic_n, posts, topics = new_topics):
  users_ids = []
  inds = find_indices(topics, topic_n)
  users_ids = [posts[j]['owner_id'] for j in inds]
  u, c = np.unique(np.array(users_ids), return_counts=True)

  n_posts = len(inds)

  users_ok = []

  for i in range(len(c)):
    if c[i]/n_posts < 0.15:
      users_ok.append(u[i])

  inds_ok = []
  for ind in inds:
    if posts[ind]['owner_id'] in users_ok:
      inds_ok.append(ind)

  return inds_ok

# %%
posts_topic = []

for i in range(100):
  inds = remove_suspicious_users(i, posts_nowar + posts_z)
  posts_topic.append(' '.join([(posts_nowar_clean + posts_z_clean)[j] for j in inds]))

additional_stop_words = ['украина', 'россия', 'российский', 'украинский']

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(stop_words=stop_words, ngram_range = (1,2))
tfidf_matrix = tfidf_vectorizer.fit_transform(posts_topic)
feature_names = tfidf_vectorizer.get_feature_names_out()

morph = pymorphy2.MorphAnalyzer()

# %%
def correct_phrase(phrase):
  words = phrase.split()
  nouns = [word for word in words if 'NOUN' in morph.parse(word)[0].tag]
  adjs = [word for word in words if 'ADJF' in morph.parse(word)[0].tag]
  nums = [word for word in words if 'NUMB' in morph.parse(word)[0].tag]
  if (len(nouns) == 1) and (len(adjs) == 1):
    try:
      parsed_noun = morph.parse(nouns[0])[0]
      gender = parsed_noun.tag.gender
      number = parsed_noun.tag.number
      case = 'nomn'
      parsed_adj = morph.parse(adjs[0])[0]
      corrected_adj = parsed_adj.inflect({case, number, gender}).word
      corrected_words = corrected_adj + ' ' + parsed_noun.word
      return corrected_words
    except:
      return phrase
  elif (len(nums) == 1) and (len(nouns) == 1):
    try:
      parsed_noun = morph.parse(nouns[0])[0]
      corrected_noun = parsed_noun.inflect({'gent', 'sing'}).word
      corrected_words = nums[0] + ' ' + corrected_noun
      return corrected_words
    except:
      return phrase
  elif (len(nouns) == 2):
    parsed_noun = morph.parse(nouns[1])[0]
    corrected_noun = parsed_noun.inflect({'gent', 'sing'}).word
    corrected_words = nouns[0] + ' ' + corrected_noun
    return corrected_words
  else:
    return phrase

def get_topic_keywords(topic_num, n_cut):
  tfidf_scores = zip(feature_names, tfidf_matrix.toarray()[topic_num])
  tfidf_scores = sorted(tfidf_scores, key=lambda x: x[1], reverse=True)
  top_tfidf_scores = tfidf_scores[:n_cut*2]
  words_initial = [top_tfidf_scores[i][0] for i in range(len(top_tfidf_scores))]
  scores = [top_tfidf_scores[i][1] for i in range(len(top_tfidf_scores))]
  # print(scores)
  words = words_initial[:2]
  for i in range(2,n_cut*2):
    if scores[i]>0.1:
      words.append(words_initial[i])

  words_remove = []

  for i in range(1,len(words)):
    if words[i] in additional_stop_words:
      words_remove.append(words[i])

  for i in range(len(words)):
    if ' ' in words[i]:
      w = words[i].split()
      for j in range(1,len(words)):
        if (words[j] in w):
          if not(words[j] in words_remove):
            words_remove.append(words[j])

  for w in words_remove:
    words.remove(w)


  words = words[:n_cut]

  for i in range(len(words)):
    if ' ' in words[i]:
      words[i] = correct_phrase(words[i])

  return words

def define_topic_params(topic_ind, topics = topics, n_cut = 6):
  # words = [item[0] for item in model.get_topic(topic_ind)]
  # words = [x for x in words if x not in stop_words]
  # if n_cut != -1:
  #   words = ' '.join(words[:n_cut])
  # else:
  #   words = ' '.join(words)
  words = get_topic_keywords(topic_ind, n_cut = n_cut)
  words = ', '.join(words)
  inds = remove_suspicious_users(topic_ind, posts_nowar + posts_z)
  count_nowar = 0
  count_z = 0
  for i in inds:
    if i<len(posts_nowar_clean):
      count_nowar += 1
    else:
      count_z += 1
  portion_nowar = count_nowar/len(posts_nowar_clean)
  # print(portion_nowar)
  portion_z = count_z/len(posts_z_clean)
  # print(portion_z)
  total_popularity = (portion_nowar + portion_z)/2
  nowar_prevalence = portion_nowar/(portion_nowar+portion_z)
  return words, total_popularity, nowar_prevalence, portion_nowar, portion_z

# %%
nowar_prevs = []
total_pops = []
portions_nowar = []
portions_z = []
names = []
for i in range(96):
  words, total_popularity, nowar_prevalence, portion_nowar, portion_z = define_topic_params(i, new_topics, n_cut = 5)
  nowar_prevs.append(nowar_prevalence)
  total_pops.append(total_popularity)
  portions_nowar.append(portion_nowar)
  portions_z.append(portion_z)
  names.append(words)
  print(i, words)
# Out:
# 0 путин, война, мир
# 1 война, мир, друг
# 2 россия, санкция, газ, экономика, запад
# 3 сталинградский, сталинградская битва, сталинградская победа, 70 отца, дед сделать
# 4 помощь, гуманитарная помощь, единая россия, житель, центр
# 5 россия, единая россия, пациент, врач, помощь
# 6 референдум, херсонский запорожский, херсонская область, вхождение состава, запорожский херсонский
# 7 фашизм, война, нацизм, мир, фашист
# 8 песня, война, музыка, клип
# 9 лидер
# 10 армия, солдат, поддерживать, военный, поддержка
# 11 уничтожать, всу, район населенный, населенный пункт, военный
# 12 россия, информация, фейк, информационная война
# 13 соревнование, спортивный, болельщик, спортсмен, турнир
# 14 страшно бессильный, прикасаться душа, тропа, друг брата
# 15 письмо, поддержка, письмо солдата, акция письма, рисунок
# 16 мир, война, любовь, жизнь, друг
# 17 погибать, потеря, война
# 18 противник, националист, сержант, лейтенант, подразделение
# 19 окт 22, владимир заклада, исключительно жилой
# 20 русский, русский мир, война
# 21 вертолет, дрон, беспилотник, поц
# 22 суд, свобода срока, лишение свободы, штраф, уголовный
# 23 митинг, война, выходить митинг, протест, антивоенный
# 24 единая россия, региональное отделение, отделение партии, единая партия, помощь
# 25 украина, помощь
# 26 зеленский, зеленский владимир, война, президент
# 27 президент, поддерживать президент, гордиться, решение президента, спецоперация
# 28 украина, мобилизация
# 29 бог, молитва, святой
# 30 книга, библиотека, литература, учебник, русский
# 31 россия, временное размещение, временный пункт, единая россия, волонтер
# 32 ставка, кредит, льготный, ипотека, правительство
# 33 концерт, благотворительный концерт
# 34 семья, семья мобилизовать, помощь семьи, заявка, поддержка
# 35 крым, крым россии, воссоединение крыма, крым севастополя, 18 марта
# 36 выплата, доход, семья, пособие, рубль
# 37 пункт обогрева, россия readovka, обогрев жителя, единая россия, местное число
# 38 герой, военный гордиться, народ региона, солдат
# 39 медаль, вручать, медаль отваги, военный, государственная награда
# 40 украина, военный
# 41 видео, фильм
# 42 флаг, взрыв территории, нарушение режима, режим прекращения, прекращение огня
# 43 мать, ребенок, война, убивать, солдат
# 44 калашников, оборонная промышленность, автомат, михаил калашникова, конструктор создавать
# 45 выпуск, новость хреновости, вечерний выпуск, утренний выпуск, остановка
# 46 флот, военноморский флот, вмф, флот россии, андреевский флага
# 47 страх, стресс, помогать, страшно
# 48 петиция, подписывать петиция, петиция войны, подпись
# 49 мост, крымский мост
# 50 производство, производитель, информация импортозамещения, рынок, предприятие
# 51 посылка, тепло родной, шить, маскировочный, теплый
# 52 мир, блаженный
# 53 православный, патриарх, православная церковь, русский православный, война
# 54 переговоры, война, военный
# 55 политика, друг, война
# 56 юрист, пенсионер, война, стыдно, адвокат
# 57 россия, айтуган, русский, бросать отличный, отличный ролик
# 58 новогодний, новогодняя ёлка, ребенок, новогодний подарок, новый
# 59 саурмогила, мемориал, монумент, мемориальный комплекс, масалов
# 60 беженец, украинский беженец, помогать, война, беженец донбасса
# 61 собака, дом разрушать, корова, пес, кошка
# 62 вциом, президент, опрос, доверие владимира, положительно отвечать
# 63 домой, вернуться домой, ждать домой, победа, воин защищать
# 64 украина, война, жить, мир, друг
# 65 весна, война, мир
# 66 зерно, порт, авиакомпания
# 67 защитник отечества, праздник, поздравлять
# 68 памятник, советский памятник
# 69 бабушка, флаг, война, знамя
# 70 спасибо, помощь, ребята
# 71 линия огня, дорожный
# 72 беларусь, беларусі, тэрыторыі, агрэсіі, супраць
# 73 волонтер, помощь, единая россия, единый волонтёр, житель
# 74 китай, война, россия китая
# 75 эфир, прямой эфир, война, телемарафон
# 76 вдв, воздушнодесантное войско, вдв самый, войско являть, десантник протяжения
# 77 государственность, 1918, государство, состав ссср, государственность сформировывать
# 78 льгота, статус ветерана, боевой ветеран, доброволец, сво
# 79 little, by little, derdinde, kimi, little by
# 80 война, считать варвар
# 81 стихотворение, поэт, стих, патриотическое стихотворение
# 82 флешмоб, флешмоб поддержки, российская поддержка, присоединяться
# 83 россия, операция, президент, спецоперация, военный
# 84 пво, противовоздушная оборона, противовоздушное войско, войско пво, зенитный
# 85 препарат, лекарство, лекарственный препарат
# 86 ода, 60 бпло, цистерна
# 87 турист, туризм, грант, агротуризм, белоруссия лета
# 88 украина, спецоперация, поддерживать, выступать поддержка, военный
# 89 мариуполь, город, азовское море, освобождение мариуполя, донбасский ход
# 90 строитель, студенческий отряд, донбасс, строительная отрасль, российский студенческий
# 91 вуз, абитуриент, егэ, экзамен, школа
# 92 аэс, запорожская аэс, энергоблок, чернобыльский, атомная электростанция
# 93 россия, независимость, днр лнр, война, донбасс
# 94 президент, говорить тысячелетний, должный настоящий, история слова, огромная перспектива
# 95 тактическая медицина, медицина военнослужащего, тактическая аптечка, тактический курс, военнослужащий донбасса

# %%
define_topic_params(19, new_topics, n_cut = 5)
# Out:
# ('российский, окт 22, владимир заклада, исключительно жилой',
#  0.002738654147104851,
#  0.7857142857142858,
#  0.004303599374021909,
#  0.0011737089201877935)

# %%
def get_random_post_topic(topic_ind, topics = topics):
  inds = remove_suspicious_users(topic_ind, posts_nowar + posts_z)
  random.shuffle(inds)
  texts = []
  if inds[0]<len(posts_nowar_clean):
    cl = 'nowar'
  else:
    cl = 'z'
  text = (posts_nowar + posts_z)[inds[0]]['initial_text']
  return cl, text, inds[0]

# %%
results_nowar = []
for i in range(96):
  res = {}
  res['keywords'] = names[i]
  res['popularity'] = total_pops[i]
  ex1 = get_random_post_topic(i, topics = new_topics)
  ex2 = get_random_post_topic(i, topics = new_topics)
  ex3 = get_random_post_topic(i, topics = new_topics)
  res['example1'] = ex1[0] + ' ' + ex1[1]
  res['example2'] = ex2[0] + ' ' + ex2[1]
  res['example3'] = ex3[0] + ' ' + ex3[1]
  results_nowar.append(res)

# %%
df = pd.DataFrame(data = results_nowar)
df.to_csv('./drive/MyDrive/Hackathon/posts_compare.csv')

# %%
df = pd.DataFrame(data = {'total_popularity': total_pops, 'nowar_prevalence': nowar_prevs, 'keywords': names})

# %%
df.to_csv('./drive/MyDrive/Hackathon/topics_diagram.csv')

# %%
df = pd.DataFrame(data = {'portions_nowar': portions_nowar, 'portions_z': portions_z, 'keywords': names})

# %%
df.to_csv('./drive/MyDrive/Hackathon/topics_portions.csv')

# %%
print('Популярность,', 'Доля антивоенных,', 'Ключевые слова')
for i in np.nonzero(np.array(nowar_prevs)>0.75)[0][:10]:
  print(np.round(total_pops[i],3), np.round(nowar_prevs[i],3), names[i])
# Out:
# Популярность, Доля антивоенных, Ключевые слова
# 0.02 0.831 путин, война, мир
# 0.016 0.954 война, мир, друг
# 0.002 0.819 лидер
# 0.005 0.982 страшно бессильный, прикасаться душа, тропа, друг брата
# 0.005 0.864 мир, война, любовь, жизнь, друг
# 0.003 0.894 погибать, потеря, война
# 0.003 0.786 российский, окт 22, владимир заклада, исключительно жилой
# 0.004 0.821 суд, свобода срока, лишение свободы, штраф, уголовный
# 0.008 0.765 митинг, война, выходить митинг, протест, антивоенный
# 0.003 0.884 украина, помощь

# %%
print('Популярность,', 'Доля антивоенных,', 'Ключевые слова')
for i in np.nonzero(np.array(nowar_prevs)<0.25)[0][:10]:
  print(np.round(total_pops[i],3), np.round(nowar_prevs[i],3), names[i])
# Out:
# Популярность, Доля антивоенных, Ключевые слова
# 0.01 0.027 сталинградский, сталинградская битва, сталинградская победа, 70 отца, дед сделать
# 0.021 0.028 помощь, гуманитарная помощь, единая россия, житель, сбор
# 0.01 0.09 россия, единая россия, пациент, врач, помощь
# 0.013 0.172 референдум, херсонский запорожский, херсонская область, вхождение состава, запорожский херсонский
# 0.008 0.021 армия, солдат, поддерживать, военный, поддержка
# 0.006 0.199 спорт, соревнование, спортивный, болельщик, спортсмен
# 0.011 0.177 письмо, поддержка, письмо солдата, акция письма, рисунок
# 0.005 0.142 противник, националист, сержант, лейтенант, подразделение
# 0.006 0.02 единая россия, региональное отделение, отделение партии, единая партия, помощь
# 0.01 0.064 президент, поддерживать президент, гордиться, решение президента, спецоперация

# %%
print('Популярность,', 'Доля антивоенных,', 'Ключевые слова')
for i in np.nonzero([b>0.4 and b<0.6 for b in np.array(nowar_prevs)])[0][:10]:
  print(np.round(total_pops[i],3), np.round(nowar_prevs[i],3), names[i])
# Out:
# Популярность, Доля антивоенных, Ключевые слова
# 0.009 0.413 фашизм, война, нацизм, фашист, мир
# 0.012 0.504 песня, война, музыка, клип
# 0.005 0.41 уничтожать, всу, район населенный, населенный пункт, военный
# 0.006 0.463 россия, информация, фейк, информационная война
# 0.006 0.526 русский, русский мир, война
# 0.003 0.591 вертолет, дрон, беспилотник, поц
# 0.005 0.529 зеленский, зеленский владимир, война, президент
# 0.003 0.516 украина, мобилизация
# 0.003 0.521 мост, крымский мост
# 0.001 0.542 зерно, порт, авиакомпания

# %%
def remove_hashtags(text):
  words_initial = text.split()
  words = []
  for item in words_initial:
    if not (item.startswith('#') or '@' in item or 'http' in item):
      words.append(item)
  text1 = ' '.join(words)
  return text1

# %%
from IPython.display import clear_output

# %%
correct_nowar = 0
wrong_nowar = 0

# %%
your_guess = ''

# %%
inds = []

# %%
while 1:
  clear_output()
  try:
    print('Your guess: ',your_guess,', it was: '+cl,'\n New text:\n')
  except:
    pass
  cl, text, ind = get_random_post_topic(7, topics = new_topics)
  while (ind in inds) or (cl == 'z'):
    cl, text, ind = get_random_post_topic(7, topics = new_topics)
  inds.append(ind)
  print(text)
  guess = input()
  if guess == 'z':
    your_guess = 'z'
    wrong_nowar += 1
  else:
    your_guess = 'nowar'
    correct_nowar += 1
# Out:
# Your guess:  nowar , it was: nowar
#  New text:
#
# ❗ ОТ НАЦИЗМА К «КУЛЬТУРЕ ГОСТЕПРИИМСТВА». КАК ПРОХОДИЛА ДЕНАЦИФИКАЦИЯ ФАШИСТСКОЙ ГЕРМАНИИ
#
# Денацификация фашистской Германии была долгой и сложной: даже спустя 5 лет после падения режима Гитлера все еще поддерживали 10% населения, а доля нацистов в МИД была даже выше, чем при Гитлере. Пока пособников режима судили на международном уровне, плодов это не принесло - покаяние за преступления нацизма пришло только с внутренними процессами над нацистскими преступниками, объясняет историк-германист, исследователь эпохи Третьего рейха Олег Пленков, при этом неонацисты с их реставрационными идеями стали со временем никому не интересны, и Германия, пусть и долгим путем, пришла к демократии.
#
# Инерция режима
# В 1945 году практически все немцы были так или иначе связаны с рухнувшим режимом, а ведь стояла задача создать работающую демократию, но сделать это вопреки большинству было невозможно. Историк Ойген Когон, автор первой работы о нацистских концлагерях, точно сформулировал проблему демократического строительства с участием бывших нацистов: «Нужно либо всех их убить, либо привлечь на свою сторону». Канцлеру Конраду Аденауэру удалось — даже его критики признавали, что интеграция 8,5 млн членов НСДПГ и примыкающих организаций является важнейшей предпосылкой к умиротворению страны.
#
# Поэтому в первые десятилетия своего существования ФРГ представляла собой не сообщество памяти, а сообщество, по выражению Германа Люббе, «коммуникативного умалчивания». Характерной чертой немецкой послевоенной истории являлось не исключение нацизма из индивидуального сознания, а исключение индивидуального и политического прошлого из общественной коммуникации. Другими словами, нацистский режим не был предан забвению, а рассматривался как политически нерелевантный. Таким образом, дальнейшие дебаты просто считались излишними, и так продолжалось довольно долго.
#
# Понятно, что такое положение было возможно только при условии ликвидации всех институтов государства. Правительство Карла Деница, которого Гитлер назначил своим преемником, было арестовано, и власть взяли на себя оккупационные власти держав-победительниц. Шел процесс над главными нацистскими преступниками в Нюрнберге, был введен запрет нацистской партии (а также примыкающих к ней организаций), преступными были объявлены все подразделения СС, включая и фронтовые части.
#
# Американские власти провели 12 Нюрнбергских военных трибуналов по делам врачей, юристов, дипломатов, опергрупп полиции безопасности и СД, по делу ОКВ, по делу химического концерна IG Farben. Требование СССР признать Вермахт преступной организацией было отвергнуто — в противном случае практически все взрослое население Германии стало бы преступниками.
#
#
# В России своего «68-го» не было, поэтому и пересмотр тоталитарного прошлого был неполным, если он вообще имел место. К тому же, в отличие от нацистского режима, разгромленного в войну, советский режим сам рухнул под тяжестью маразма, и нас никто не принуждал к пересмотру отношения к собственной истории, как к этому принудили немцев. Поэтому и создать устойчивую демократическую политическую культуру, как это сделали немцы, упорно искоренявшие всякие признаки национальной, расовой, имперской, социальной, культурной или иной нетерпимости, нам так и не удалось.
#
# Но для современных немцев есть другая опасность. Слишком настойчивая морализация (особенно в отношении холокоста) безраздельно царит в дискурсе сейчас. Иными словами, политическая коммуникация превратилась в позу. При этом, конечно, в послевоенной Германии национализм не исчез вовсе. Его просто старательно игнорируют, а на первый план доминирующие в общественном дискурсе немецкие левые выдвигают образцовую немецкую Willkommenskultur <«Культура гостеприимства» означает ряд мер, которые люди принимают, основываясь на положительном отношении к мигрантам, чтобы они чувствовали себя комфортно в обществе и смогли скорее освоится в нем — The Insider> и используют ее как обязательный элемент немецкой идентичности. В этом, наверное, и главный итог немецкого 68-го.
#
# Олег Пленков
#
# #НетВойне #NoWar #украина #россия #путин #война
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-175-ada85977715b> in <cell line: 2>()
#      10   inds.append(ind)
#      11   print(text)
# ---> 12   guess = input()
#      13   if guess == 'z':
#      14     your_guess = 'z'
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
correct_nowar
# Out:
# 43

# %%
wrong_nowar
# Out:
# 30

# %%
get_random_post_topic(79, topics = new_topics)[1]
# Out:
# 'Продолжаем поддерживать тесную связь с семьями мобилизованных. Пока мужчины защищают интересы страны, дома хранят очаг и тыл их семьи - матери, жены, дети. Сейчас, когда идут обильные снегопады, нехватка сильной мужской руки, особенно в частных домах, ощущается острее - необходимо и снег почистить и обеспечить топливом. На помощь семьям мобилизованных в этой ситуации приходят волонтеры, социальные работники, Администрация КГО, руководители предприятий. \nНа этой недели двум семьям мобилизованных, у которых не хватит запасов топлива до весны, привезли уголь. Жене мобилизованного помогли скинуть снег с крыши. \nСоциальные работники переодически связываются с семьями и узнают о возникших проблемах. Обращаемся с возникшими вопросами в Администрацию города и по мере возможности решаем поставленные задачи. \n#ЕР42 #Мывместе #Своихнебросаем #Депутат42'

# %%
cl, text = get_random_post_topic(7, topics = new_topics)
text
# Out:
# 'Известный краевед\u200b и историк, автор публикаций и эксперт по истории города Петр Лизогуб об исторических предпосылках сложившейся \u200b ситуации на Украине и разрушительной идеологии нацизма.\n\n#ZаРоссию, #ZаНаших, #ZаПутина, #СвоихНеБросаем'

# %%
text_r = remove_hashtags(text)
print(cl, text_r)
# Out:
# nowar Чё то карта стран поддерживающих фашисткий концлагерь Украину все больше напоминает карту стран поддерживающих фашисткую Германию. На первой карте, страны поддерживающие фашистов Гитлера, на второй карте, страны поддержавшие фашиста Зеленского, и запретивший полеты, нашим самолётам.

# %%
res = ts.translate_text(text_r)

# %%
print(res)
# Out:
# Somehow, the map of countries supporting the fascist concentration camp Ukraine increasingly resembles a map of countries supporting fascist Germany. On the first map, the countries supporting Hitler's fascists, on the second map, the countries that supported the fascist Zelensky, and who banned flights, our planes.

# %%
text_eng = TextBlob(res)
text_eng.sentiment
# Out:
# Sentiment(polarity=0.2, subjectivity=0.21666666666666665)

# %% [markdown]
# # Z posts

# %%
f = open('./drive/MyDrive/Hackathon/posts_z_users_russia_clean_full.pkl', 'rb')
posts = pickle.load(f)
f.close()

# %%
posts_clean = []

for post in posts:
    text = post['text']
    text.replace('\n','')
    posts_clean.append(text)

# %%
model = BERTopic(verbose=True, language = 'multilingual', min_topic_size = 100, low_memory = True)
topics, probabilities = model.fit_transform(posts_clean)
model.get_topic_info()[:10]
# Out:
# Downloading (…)0fe39/.gitattributes:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)83e900fe39/README.md:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading (…)e900fe39/config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading unigram.json:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading (…)900fe39/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/7760 [00:00<?, ?it/s]
# 2023-03-29 13:15:33,922 - BERTopic - Transformed documents to Embeddings
# 2023-03-29 14:01:35,811 - BERTopic - Reduced dimensionality
# 2023-03-29 14:03:01,735 - BERTopic - Clustered reduced embeddings
#    Topic   Count                                             Name
# 0     -1  138732                                  -1_наш_мы_не_на
# 1      0   22853                              0_не_украина_что_мы
# 2      1    4997               1_сбор_гуманитарный_помощь_продукт
# 3      2    4962           2_уничтожать_противник_всу_националист
# 4      3    3778                3_сталинградский_орден_битва_1942
# 5      4    3734  4_референдум_запорожский_херсонский_голосование
# 6      5    2822        5_крым_воссоединение_севастополь_крымский
# 7      6    2618                         6_вы_солдат_мужество_наш
# 8      7    2157                 7_день_память_праздник_отечество
# 9      8    2044                    8_войско_десантник_вдв_летчик

# %%
model.save("./drive/MyDrive/Hackathon/model_z_full")
# Out:
# /usr/local/lib/python3.9/dist-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
model = BERTopic.load("./drive/MyDrive/Hackathon/model_z_full")

# %%
model.merge_topics(posts_clean, [[68,169],
                                                       [13,103,39,49,93,12,87,119,3],
                                                       [104,86,22,130,66,73,67,126,111,144],
                                                       [44,180],
                                                       [19,142],
                                                       [37,65],
                                                       [57,116],
                                                       [115,70],
                                                       [114,41],
                                                       [1,47],
                                                       [101,134],
                                                       [96,63],
                                                       [24,54],
                                                       [51,40],
                                                       [179,35,34],
                                                       [21,118,141,124,117],
                                                       [7,36],
                                                       [45,6,83,148],
                                                       [132,85],
                                                       [98,106],
                                                       [122,2],
                                                       [8,157],
                                                       [137,88,33],
                                                       [69,43],
                                                       [29,61],
                                                       [102,79],
                                                       [182,170],
                                                       [175,123],
                                                       [109,136],
                                                       [23,146,154,138],
                                                       [31,158]
                                                       ])

# %%
model.get_topic_info()
# Out:
#      Topic   Count                                               Name
# 0       -1  138732                                    -1_наш_на_мы_не
# 1        0   22853                                0_не_украина_мы_что
# 2        1    8202               1_сталинградский_битва_неонацист_год
# 3        2    5475                     2_помощь_гуманитарный_сбор_для
# 4        3    5123             3_уничтожать_противник_всу_националист
# ..     ...     ...                                                ...
# 124    123     106       123_ведение_ковровый_сверхточный_современный
# 125    124     105          124_профессионал_благородный_профессия_вы
# 126    125     105  125_северск_перемещаться_отодвигать_судостроит...
# 127    126     103  126_свинокомплекс_чистогорский_суховский_куzба...
# 128    127     102  127_правоохранитель_примечательно_разгрузка_вп...
#
# [129 rows x 3 columns]

# %%
model.merge_topics(posts_clean, [[127,109],
                                 [40,21],
                                 [16,114],
                                 [20,51],
                                 [35,91],
                                 [5,80]])

# %%
model.merge_topics(posts_clean, [[40,37],
                                 [1,61],
                                 [48,5],
                                 [39,2,63],
                                 [9,90]])

# %%
hierarchical_topics = model.hierarchical_topics(posts_clean)
tree = model.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# 100%|██████████| 111/111 [00:02<00:00, 37.07it/s]
# .
# ├─год_сталинградский_на_украина_битва
# │    ├─сталинградский_битва_год_неонацист_армия
# │    │    ├─сталинградский_битва_год_неонацист_население
# │    │    │    ├─мариуполь_город_фашист_освобождение_год
# │    │    │    │    ├─мариуполь_город_азовский_фашист_освобождение
# │    │    │    │    │    ├─■──пятно_азовцев_сберегать_комбинат_своевременность ── Topic: 97
# │    │    │    │    │    └─мариуполь_город_азовский_фашист_освобождение
# │    │    │    │    │         ├─■──мариуполь_освобождение_город_фашист_79 ── Topic: 40
# │    │    │    │    │         └─■──мариуполь_город_азовский_море_центр ── Topic: 37
# │    │    │    │    └─памятник_танковый_танкист_саурмогила_советский
# │    │    │    │         ├─■──танковый_танкист_войско_танк_праздник ── Topic: 61
# │    │    │    │         └─памятник_саурмогила_мемориальный_комплекс_мемориал
# │    │    │    │              ├─памятник_вечный_огонь_снести_советский
# │    │    │    │              │    ├─■──памятник_снести_советский_снос_монумент ── Topic: 47
# │    │    │    │              │    └─■──вечный_огонь_зажигать_мариуполь_зажигаться ── Topic: 72
# │    │    │    │              └─■──саурмогила_мемориальный_комплекс_79летия_курган ── Topic: 65
# │    │    │    └─сталинградский_битва_год_неонацист_население
# │    │    │         ├─сталинградский_битва_год_неонацист_население
# │    │    │         │    ├─■──склонять_труженик_вов_неонацист_вспоминать ── Topic: 35
# │    │    │         │    └─■──сталинградский_битва_год_неонацист_население ── Topic: 1
# │    │    │         └─■──ждать_правый_безопасный_магазин_наш ── Topic: 58
# │    │    └─уничтожать_противник_российский_украинский_всу
# │    │         ├─санкция_газ_запад_страна_что
# │    │         │    ├─газ_санкция_рубль_сша_экономика
# │    │         │    │    ├─■──недоученность_современный_профессиональный_лондонский_высокопарный ── Topic: 80
# │    │         │    │    └─газ_санкция_рубль_экономика_сша
# │    │         │    │         ├─китай_биологический_сша_лаборатория_биолаборатория
# │    │         │    │         │    ├─■──биологический_лаборатория_биолаборатория_сша_патоген ── Topic: 67
# │    │         │    │         │    └─■──китай_кнр_китайский_сша_тайвань ── Topic: 51
# │    │         │    │         └─газ_санкция_рубль_экономика_страна
# │    │         │    │              ├─■──газ_санкция_рубль_экономика_доллар ── Topic: 13
# │    │         │    │              └─■──корпеть_головоломка_экономист_общемто_стратег ── Topic: 89
# │    │         │    └─президент_запад_доверие_россиянин_рейтинг
# │    │         │         ├─план_будущее_запад_своевременный_противостоять
# │    │         │         │    ├─■──будущее_своевременный_правильный_неделимый_упреждающий ── Topic: 70
# │    │         │         │    └─противостоять_агония_запад_сильно_героически
# │    │         │         │         ├─■──вынашивать_запад_ослабление_неприкрытый_выключать ── Topic: 100
# │    │         │         │         └─■──агония_героически_противостоять_четко_сильно ── Topic: 102
# │    │         │         └─президент_доверие_рейтинг_вциом_доверять
# │    │         │              ├─доверие_президент_вциом_рейтинг_доверять
# │    │         │              │    ├─■──очевидный_никакой_невиданный_оправдываться_экстремальный ── Topic: 78
# │    │         │              │    └─■──доверие_вциом_рейтинг_доверять_президент ── Topic: 33
# │    │         │              └─■──козни_силуэт_кепка_guardian_удивляться ── Topic: 99
# │    │         └─уничтожать_противник_украинский_всу_военный
# │    │              ├─уничтожать_противник_всу_украинский_националист
# │    │              │    ├─уничтожать_противник_всу_украинский_националист
# │    │              │    │    ├─гордость_жить_они_российский_армия
# │    │              │    │    │    ├─гордость_жить_они_российский_местный
# │    │              │    │    │    │    ├─■──жить_они_заколдовывать_пронзать_сражать ── Topic: 101
# │    │              │    │    │    │    └─гордость_российский_местный_армия_ценность
# │    │              │    │    │    │         ├─■──самообладание_всячески_терять_воздух_держать ── Topic: 91
# │    │              │    │    │    │         └─российский_местный_ценность_лекарство_гордость
# │    │              │    │    │    │              ├─■──ценность_гордость_кислота_цистерна_благословление ── Topic: 94
# │    │              │    │    │    │              └─■──правоохранитель_разгрузка_примечательно_тонна_местный ── Topic: 68
# │    │              │    │    │    └─ведение_хватать_техобслуживание_наизнанку_выворачивать
# │    │              │    │    │         ├─ведение_хватать_техобслуживание_наизнанку_выворачивать
# │    │              │    │    │         │    ├─■──ведение_ковровый_сверхточный_современный_освобождение ── Topic: 108
# │    │              │    │    │         │    └─■──хватать_техобслуживание_наизнанку_выворачивать_повертывать ── Topic: 96
# │    │              │    │    │         └─■──порноактер_рассматривать_накачка_билли_геррингтон ── Topic: 87
# │    │              │    │    └─уничтожать_противник_всу_националист_украинский
# │    │              │    │         ├─уничтожать_противник_всу_националист_украинский
# │    │              │    │         │    ├─уничтожать_противник_всу_националист_украинский
# │    │              │    │         │    │    ├─■──северск_перемещаться_отодвигать_судостроительный_диверсант ── Topic: 110
# │    │              │    │         │    │    └─■──уничтожать_противник_всу_националист_украинский ── Topic: 3
# │    │              │    │         │    └─■──обмен_плен_пленный_военнослужащий_украинский ── Topic: 92
# │    │              │    │         └─гитлер_татуировка_нацизм_праворадикальный_мальтийский
# │    │              │    │              ├─■──емельяненко_mma_смешать_единоборство_наклейка ── Topic: 84
# │    │              │    │              └─■──гитлер_татуировка_праворадикальный_мальтийский_череп ── Topic: 77
# │    │              │    └─vыполняйте_zадачи_неизгладимый_домой_точность
# │    │              │         ├─■──профессионал_благородный_профессия_вы_мастер ── Topic: 109
# │    │              │         └─vыполняйте_zадачи_неизгладимый_высокопоставленный_горевояк
# │    │              │              ├─■──домой_возвращаться_vыполняйте_zадачи_вы ── Topic: 48
# │    │              │              └─■──неизгладимый_высокопоставленный_горевояк_остужать_пострелять ── Topic: 66
# │    │              └─свеча_государственность_кровь_донор_трудовой
# │    │                   ├─тактический_аптечка_жгут_медицина_курс
# │    │                   │    ├─■──валуев_якубовский_привозить_костюм_термобелье ── Topic: 64
# │    │                   │    └─тактический_медицина_курс_курсы_аптечка
# │    │                   │         ├─■──тактический_медицина_курсы_курс_аптечка ── Topic: 55
# │    │                   │         └─■──подготовка_навык_боевой_полигон_инструктор ── Topic: 103
# │    │                   └─свеча_государственность_кровь_донор_трудовой
# │    │                        ├─свеча_государственность_кровь_донор_зарождение
# │    │                        │    ├─сербия_беженец_сербский_украинец_серб
# │    │                        │    │    ├─■──сербия_сербский_серб_брат_навек ── Topic: 42
# │    │                        │    │    └─беженец_украинец_польша_европа_украинский
# │    │                        │    │         ├─■──православный_церковь_храм_патриарх_вера ── Topic: 106
# │    │                        │    │         └─беженец_украинец_польша_европа_правомерность
# │    │                        │    │              ├─беженец_украинец_польша_европа_правомерность
# │    │                        │    │              │    ├─■──беженец_польша_украинец_европа_правомерность ── Topic: 46
# │    │                        │    │              │    └─■──ни_денисенко_вырываться_наследница_пить ── Topic: 105
# │    │                        │    │              └─■──видео_ролик_посмотреть_куzбас_очень ── Topic: 88
# │    │                        │    └─свеча_государственность_кровь_донор_зарождение
# │    │                        │         ├─государственность_зарождение_21_1160_1150летия
# │    │                        │         │    ├─друг_сплачиваться_отстаивать_натравлять_пытаться
# │    │                        │         │    │    ├─■──друг_сплачиваться_отстаивать_натравлять_пытаться ── Topic: 59
# │    │                        │         │    │    └─■──будущий_рисковать_действительно_ради_разный ── Topic: 104
# │    │                        │         │    └─государственность_зарождение_21_1160_1150летия
# │    │                        │         │         ├─■──государственность_зарождение_21_1160_1150летия ── Topic: 38
# │    │                        │         │         └─■──космос_космический_космонавтика_космонавт_полет ── Topic: 82
# │    │                        │         └─свеча_кровь_донор_окопный_блиндажный
# │    │                        │              ├─свеча_окопный_блиндажный_парафин_изготовление
# │    │                        │              │    ├─■──свеча_окопный_блиндажный_парафин_изготовление ── Topic: 39
# │    │                        │              │    └─■──животное_собака_приют_пес_бездомный ── Topic: 81
# │    │                        │              └─■──кровь_донор_сдавать_переливание_сдача ── Topic: 63
# │    │                        └─трудовой_работодатель_рабочий_сотрудник_стаж
# │    │                             ├─трудовой_работодатель_рабочий_сотрудник_стаж
# │    │                             │    ├─■──бардаш_окончание_юрий_контракт_экспродюсер ── Topic: 86
# │    │                             │    └─■──трудовой_работодатель_рабочий_сотрудник_стаж ── Topic: 62
# │    │                             └─золотостепский_ск_свинокомплекс_чистогорский_суховский
# │    │                                  ├─■──свинокомплекс_чистогорский_суховский_куzбассарена_помеха ── Topic: 111
# │    │                                  └─■──золотостепский_ск_бросать_акция_поддерживать ── Topic: 93
# │    └─не_мы_наш_что_украина
# │         ├─не_мы_что_наш_украина
# │         │    ├─не_мы_украина_что_это
# │         │    │    ├─■──мир_родина_мы_патриотизм_страна ── Topic: 25
# │         │    │    └─не_украина_мы_что_это
# │         │    │         ├─не_украина_мы_что_это
# │         │    │         │    ├─■──не_украина_мы_что_это ── Topic: 0
# │         │    │         │    └─■──война_не_что_это_мир ── Topic: 60
# │         │    │         └─■──ты_не_мы_бог_как ── Topic: 11
# │         │    └─вы_наш_мы_солдат_поддерживать
# │         │         ├─вы_наш_мы_солдат_мужество
# │         │         │    ├─■──нацизм_фашизм_мы_наш_вы ── Topic: 17
# │         │         │    └─■──вы_наш_солдат_мужество_мы ── Topic: 5
# │         │         └─■──президент_поддерживать_наш_мы_решение ── Topic: 24
# │         └─конкурс_проект_автор_церемония_награждение
# │              ├─награда_вручать_медаль_герой_мужество
# │              │    ├─■──награда_вручать_медаль_мужество_отвага ── Topic: 50
# │              │    └─■──путин_владимир_президент_поблагодарить_поздравлять ── Topic: 79
# │              └─конкурс_проект_автор_мерч_награждение
# │                   ├─■──здорово_единство_так_активно_только ── Topic: 107
# │                   └─■──конкурс_проект_автор_мерч_награждение ── Topic: 19
# └─единый_помощь_россия_житель_для
#      ├─единый_помощь_россия_житель_гуманитарный
#      │    ├─единый_помощь_центр_волонтер_гуманитарный
#      │    │    ├─единый_помощь_центр_гуманитарный_партия
#      │    │    │    ├─■──досуговый_центр_спортинвентарь_настольный_купянск ── Topic: 98
#      │    │    │    └─единый_помощь_центр_гуманитарный_врач
#      │    │    │         ├─единый_центр_гуманитарный_помощь_врач
#      │    │    │         │    ├─единый_центр_гуманитарный_помощь_врач
#      │    │    │         │    │    ├─■──врач_медицинский_пациент_лечение_единый ── Topic: 7
#      │    │    │         │    │    └─■──центр_гуманитарный_единый_помощь_открывать ── Topic: 10
#      │    │    │         │    └─■──штаб_сотрудничество_генсовет_доставка_логистический ── Topic: 75
#      │    │    │         └─семья_заявка_мобилизовать_помощь_штаб
#      │    │    │              ├─■──семья_заявка_мобилизовать_штаб_помощь ── Topic: 21
#      │    │    │              └─■──юридический_приемный_обращение_соцвыплата_центр ── Topic: 90
#      │    │    └─волонтер_обогрев_пропадать_мариуполь_волонтерский
#      │    │         ├─обогрев_пункт_развертывать_readovka_волонтер
#      │    │         │    ├─■──маломобильный_эвакуация_выезжать_волонтер_развертывать ── Topic: 49
#      │    │         │    └─■──обогрев_пункт_readovka_развертывать_согреваться ── Topic: 28
#      │    │         └─пропадать_поиск_волонтерский_заявка_волонтер
#      │    │              ├─■──волонтер_волонтерский_обучение_рота_гвардия ── Topic: 32
#      │    │              └─■──пропадать_поиск_заявка_сайт_мариуполь ── Topic: 30
#      │    └─референдум_республика_россия_крым_область
#      │         ├─референдум_запорожский_область_республика_херсонский
#      │         │    ├─референдум_запорожский_херсонский_область_республика
#      │         │    │    ├─■──паспорт_гражданство_выдача_полмиллиона_получать ── Topic: 52
#      │         │    │    └─референдум_запорожский_херсонский_область_вхождение
#      │         │    │         ├─референдум_запорожский_херсонский_вхождение_область
#      │         │    │         │    ├─■──признание_независимость_республика_лнр_днр ── Topic: 20
#      │         │    │         │    └─■──референдум_запорожский_херсонский_вхождение_состав ── Topic: 4
#      │         │    │         └─■──отделение_региональный_партия_единый_запорожский ── Topic: 22
#      │         │    └─помощь_гуманитарный_сбор_для_акция
#      │         │         ├─помощь_гуманитарный_сбор_для_акция
#      │         │         │    ├─письмо_новогодний_акция_солдат_подарок
#      │         │         │    │    ├─■──новогодний_подарок_елка_праздник_сладкий ── Topic: 27
#      │         │         │    │    └─письмо_акция_солдат_рисунок_написать
#      │         │         │    │         ├─■──тепло_женский_посылка_родной_акция ── Topic: 53
#      │         │         │    │         └─■──письмо_солдат_акция_рисунок_написать ── Topic: 15
#      │         │         │    └─помощь_гуманитарный_сбор_для_партия
#      │         │         │         ├─помощь_гуманитарный_сбор_для_партия
#      │         │         │         │    ├─■──школа_учебный_ребенок_школьный_малообеспеченный ── Topic: 45
#      │         │         │         │    └─помощь_гуманитарный_сбор_для_житель
#      │         │         │         │         ├─помощь_гуманитарный_сбор_для_житель
#      │         │         │         │         │    ├─помощь_гуманитарный_сбор_для_продукт
#      │         │         │         │         │    │    ├─■──помощь_гуманитарный_сбор_для_продукт ── Topic: 2
#      │         │         │         │         │    │    └─■──акция_флешмоб_поддержка_участие_присоединяться ── Topic: 6
#      │         │         │         │         │    └─■──депутат_встреча_совет_обсуждать_округ ── Topic: 26
#      │         │         │         │         └─■──строитель_строительный_восстановление_отряд_студенческий ── Topic: 12
#      │         │         │         └─■──храбрость_игрушка_коробка_акция_ребенок ── Topic: 83
#      │         │         └─книга_учебник_литература_история_библиотека
#      │         │              ├─■──книга_литература_библиотека_язык_учебник ── Topic: 41
#      │         │              └─■──учебник_история_книга_искажение_литература ── Topic: 44
#      │         └─крым_воссоединение_флаг_севастополь_март
#      │              ├─крым_воссоединение_севастополь_крымский_18
#      │              │    ├─крым_воссоединение_севастополь_крымский_18
#      │              │    │    ├─■──соревнование_спорт_спортсмен_спортивный_игра ── Topic: 18
#      │              │    │    └─крым_воссоединение_севастополь_крымский_18
#      │              │    │         ├─концерт_песня_благотворительный_состояться_поддержка
#      │              │    │         │    ├─■──музей_выставка_экспозиция_история_посещать ── Topic: 74
#      │              │    │         │    └─концерт_песня_благотворительный_поддержка_состояться
#      │              │    │         │         ├─■──концерт_песня_благотворительный_поддержка_состояться ── Topic: 14
#      │              │    │         │         └─■──патриотический_воспитание_школа_патриотизм_кадет ── Topic: 95
#      │              │    │         └─■──крым_воссоединение_севастополь_крымский_18 ── Topic: 8
#      │              │    └─стихотворение_библиотека_читать_патриотический_акция
#      │              │         ├─■──библиотека_акция_сельский_книга_присоединяться ── Topic: 29
#      │              │         └─■──стихотворение_читать_поэт_поэтический_патриотический ── Topic: 23
#      │              └─флаг_бабушка_знамя_символ_автопробег
#      │                   ├─флаг_автопробег_символ_государственный_триколор
#      │                   │    ├─■──автопробег_буква_автомобиль_символ_поддержка ── Topic: 31
#      │                   │    └─■──флаг_государственный_триколор_символ_поднятие ── Topic: 34
#      │                   └─■──бабушка_знамя_флаг_она_топтать ── Topic: 16
#      └─выплата_рубль_мера_программа_до
#           ├─производство_препарат_лекарство_компания_производитель
#           │    ├─■──цена_сахар_магазин_товар_торговый ── Topic: 73
#           │    └─производство_препарат_лекарство_компания_импортозамещение
#           │         ├─препарат_производство_лекарство_компания_импортозамещение
#           │         │    ├─■──препарат_лекарство_лекарственный_производство_фармацевтический ── Topic: 43
#           │         │    └─■──производство_импортозамещение_компания_предприятие_завод ── Topic: 54
#           │         └─■──посевной_урожай_аграрий_зерно_хозяйство ── Topic: 57
#           └─выплата_рубль_мера_программа_до
#                ├─выплата_рубль_мера_программа_льгота
#                │    ├─выплата_рубль_мера_программа_льгота
#                │    │    ├─■──экономический_предприниматель_территория_донбасс_предлагать ── Topic: 71
#                │    │    └─выплата_рубль_мера_программа_льгота
#                │    │         ├─выплата_рубль_мера_программа_льгота
#                │    │         │    ├─■──туризм_туристический_турист_ростуризм_путешествие ── Topic: 56
#                │    │         │    └─выплата_рубль_мера_льгота_программа
#                │    │         │         ├─■──выплата_рубль_мера_льгота_семья ── Topic: 9
#                │    │         │         └─■──вуз_образование_программа_обучение_абитуриент ── Topic: 36
#                │    │         └─■──авиакомпания_самолет_аэропорт_пассажир_бронирование ── Topic: 69
#                │    └─■──коронавирус_вакцинация_коронавирусный_масочный_инфекция ── Topic: 85
#                └─■──штраф_наказание_лишение_до_уголовный ── Topic: 76

# %%
model.save("./drive/MyDrive/Hackathon/model_z_full_merged")

# %%
model = BERTopic.load("./drive/MyDrive/Hackathon/model_z_full_merged")

# %%
topics = model.topics_

# %%
new_topics = model.reduce_outliers(posts_clean, topics, threshold = 0.3)
# Out:
# 100%|██████████| 139/139 [01:52<00:00,  1.23it/s]

# %%
def find_indices(list_to_check, item_to_find):
    indices = []
    for idx, value in enumerate(list_to_check):
        if value == item_to_find:
            indices.append(idx)
    return indices

# %%
def remove_suspicious_users(topic_n, posts, topics = new_topics):
  users_ids = []
  inds = find_indices(topics, topic_n)
  users_ids = [posts[j]['owner_id'] for j in inds]
  u, c = np.unique(np.array(users_ids), return_counts=True)

  n_posts = len(inds)

  users_ok = []

  for i in range(len(c)):
    if c[i]/n_posts < 0.15:
      users_ok.append(u[i])

  inds_ok = []
  for ind in inds:
    if posts[ind]['owner_id'] in users_ok:
      inds_ok.append(ind)

  return inds_ok

# %%
posts_topic = []

for i in range(30):
  inds = remove_suspicious_users(i, posts)
  posts_topic.append(' '.join([posts_clean[j] for j in inds]))

additional_stop_words = ['украина', 'россия', 'российский', 'украинский']

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(stop_words=stop_words, ngram_range = (1,2))
tfidf_matrix = tfidf_vectorizer.fit_transform(posts_topic)
feature_names = tfidf_vectorizer.get_feature_names_out()

import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
def correct_phrase(phrase):
  words = phrase.split()
  nouns = [word for word in words if 'NOUN' in morph.parse(word)[0].tag]
  adjs = [word for word in words if 'ADJF' in morph.parse(word)[0].tag]
  nums = [word for word in words if 'NUMB' in morph.parse(word)[0].tag]
  if (len(nouns) == 1) and (len(adjs) == 1):
    try:
      parsed_noun = morph.parse(nouns[0])[0]
      gender = parsed_noun.tag.gender
      number = parsed_noun.tag.number
      case = 'nomn'
      parsed_adj = morph.parse(adjs[0])[0]
      corrected_adj = parsed_adj.inflect({case, number, gender}).word
      corrected_words = corrected_adj + ' ' + parsed_noun.word
      return corrected_words
    except:
      return phrase
  elif (len(nums) == 1) and (len(nouns) == 1):
    try:
      parsed_noun = morph.parse(nouns[0])[0]
      corrected_noun = parsed_noun.inflect({'gent', 'sing'}).word
      corrected_words = nums[0] + ' ' + corrected_noun
      return corrected_words
    except:
      return phrase
  elif (len(nouns) == 2):
    parsed_noun = morph.parse(nouns[1])[0]
    corrected_noun = parsed_noun.inflect({'gent', 'sing'}).word
    corrected_words = nouns[0] + ' ' + corrected_noun
    return corrected_words
  else:
    return phrase

def get_topic_keywords(topic_num, n_cut):
  tfidf_scores = zip(feature_names, tfidf_matrix.toarray()[topic_num])
  tfidf_scores = sorted(tfidf_scores, key=lambda x: x[1], reverse=True)
  top_tfidf_scores = tfidf_scores[:n_cut*2]
  words_initial = [top_tfidf_scores[i][0] for i in range(len(top_tfidf_scores))]
  scores = [top_tfidf_scores[i][1] for i in range(len(top_tfidf_scores))]
  # print(scores)
  words = words_initial[:2]
  for i in range(2,n_cut*2):
    if scores[i]>0.1:
      words.append(words_initial[i])

  words_remove = []

  for i in range(0,len(words)):
    if words[i] in additional_stop_words:
      words_remove.append(words[i])

  for i in range(len(words)):
    if ' ' in words[i]:
      w = words[i].split()
      for j in range(1,len(words)):
        if (words[j] in w):
          if not(words[j] in words_remove):
            words_remove.append(words[j])

  for w in words_remove:
    words.remove(w)


  words = words[:n_cut]

  for i in range(len(words)):
    if ' ' in words[i]:
      words[i] = correct_phrase(words[i])

  return words

def define_topic_params(topic_ind, topics = topics, n_cut = 6):
  # words = [item[0] for item in model.get_topic(topic_ind)]
  # words = [x for x in words if x not in stop_words]
  # if n_cut != -1:
  #   words = ' '.join(words[:n_cut])
  # else:
  #   words = ' '.join(words)
  words = get_topic_keywords(topic_ind, n_cut = n_cut)
  words = ', '.join(words)
  inds = remove_suspicious_users(topic_ind, posts)
  count_z = 0
  for i in inds:
    count_z += 1
  portion_z = total_popularity/len(posts_z_clean)
  return words, total_popularity

# %%
def get_random_post_topic(topic_ind, topics = topics, inds = None):
  if not inds:
    inds = remove_suspicious_users(topic_ind, posts)
  random.shuffle(inds)
  texts = []
  # text = str(posts[inds[0]]['owner_id']) + ' ' + posts[inds[0]]['initial_text']
  text = posts[inds[0]]['initial_text']
  return text, inds[0]

# %%
inds1 = remove_suspicious_users(0, posts)
random.shuffle(inds1)
texts = [posts[inds1[i]]['initial_text'] for i in range(len(inds1))]
s = 0
i = 0
while s<100:
  i += 1
  if len(texts[i])<300:
    s+=1
    print(texts[i])
    print('________________________________')
# Out:
# Мы сегодня являемся свидетелями исторического политического события. Наша страна даёт решительный отпор политике США и НАТО, пытающихся нагло и бесцеремонно ослабить Россию, диктовать ей свою волю!
# #ЕР34 #СталинградскаяБитва #ИсторическаяПамять #ИсторическаяПравда #СвоихНеБросаем #БратскаяУкраина #НетФашизму

# %%
total_pops = []
names = []
for i in range(30): 
  words, total_popularity = define_topic_params(i, new_topics)
  total_pops.append(total_popularity)
  names.append(words)
  print(i, words)
# Out:
# 0 президент, военный, русский, мир, война, путин
# 1 сталинградский, сталинградская битва, армия, битва посвящаться, война
# 2 помощь, гуманитарная помощь, житель, сбор, единая россия, центр
# 3 уничтожать, военный, противник, пункт, всу, район
# 4 референдум, житель, вхождение, территория, состав, херсонская область
# 5 солдат, ребята, поддерживать, победа, гордиться, военный
# 6 акция, житель, принимать участие, помощь, акция поддержки, военный
# 7 выплата, рубль, ребенок, поддержка, семья, получать
# 8 единая россия, помощь, донбасс, врач, медицинский, территория
# 9 крым, воссоединение крыма, крым россии, крымская весна, крым севастополя, 18 марта
# 10 мир, сила, жизнь, бог, знать, становиться
# 11 работа, восстановление, донбасс, строитель, помогать, строительный
# 12 санкция, газ, экономика, рубль, запад, европа
# 13 концерт, поддержка, песня, проходить, благотворительный концерт, военный
# 14 письмо, акция, поддержка, военный, ребята, слово
# 15 бабушка, флаг, топтать, знамя победы, украинская бабушка, старушка
# 16 нацизм, победа, мир, фашизм, военный
# 17 спорт, спортивный, соревнование, спортсмен, игра, турнир
# 18 проект, проект правда, конкурс, фирменный мерч, поддержка, получать фирменный
# 19 днр, народная республика, лнр, помощь, житель, донецкий
# 20 семья, помощь, поддержка, единая россия, семья мобилизовать, вопрос
# 21 единая россия, региональное отделение, помощь, житель, отделение партии, область
# 22 стихотворение, русский, патриотическое стихотворение, поэт, читать, стих
# 23 президент, поддерживать, решение, спецоперация, военный, поддержка
# 24 мир, родина, народ, любовь
# 25 мариуполь, город, центр
# 26 депутат, совет, вопрос, работа, единая россия, округ
# 27 новогодний, ребенок, новый, семья, праздник, новогодний подарок
# 28 пункт обогрева, россия readovka, единая россия, обогрев жителя, помощь, мариуполь
# 29 библиотека, акция, поддержка, присоединяться, сельская библиотека

# %%
results_z = []
for i in range(30):
  res = {}
  res['keywords'] = names[i]
  res['popularity'] = total_pops[i]
  res['example1'] = get_random_post_topic(i, topics = new_topics)
  res['example2'] = get_random_post_topic(i, topics = new_topics)
  res['example3'] = get_random_post_topic(i, topics = new_topics)
  results_z.append(res)

# %%
df = pd.DataFrame(data = results_z)
df.to_csv('./drive/MyDrive/Hackathon/posts_z.csv')

# %%
date_labels = ['Февраль 2022', 'Март 2022', 'Апрель 2022', 'Май 2022', 'Июнь 2022', 'Июль 2022', 
               'Август 2022', 'Сентябрь 2022', 'Октябрь 2022', 'Ноябрь 2022', 'Декабрь 2022', 
               'Январь 2023', 'Февраль 2023']

# %%
results_z = []
for label in date_labels:
  res = {}
  inds_date = np.nonzero([(posts[i]['date_label'] == label) for i in range(len(posts))])[0]
  for j in range(len(names)):
    name = names[j]
    print(label, name)
    inds_ok = remove_suspicious_users(j, posts)
    n_posts = 0
    for ind in inds_date:
      if new_topics[ind]!=-1 and new_topics[ind]<27:
        # print(new_topics[len(posts_nowar)+ind])
        if names[new_topics[ind]] == name:
          if ind in inds_ok:
            n_posts += 1
    frac = n_posts#/len(posts)
    res[name] = frac
  results_z.append(res)

# %%
df = pd.DataFrame(data = results_z)
df.to_csv('./drive/MyDrive/Hackathon/time_topics_z_full.csv')

# %% [markdown]
# # Topic modelling in 0 z-topic

# %%
def find_indices(list_to_check, item_to_find):
    indices = []
    for idx, value in enumerate(list_to_check):
        if value == item_to_find:
            indices.append(idx)
    return indices

# %%
inds = find_indices(new_topics, 0) + find_indices(new_topics, 16) + find_indices(new_topics, 23) + find_indices(new_topics, 24)

# %%
len(inds)
# Out:
# 38875

# %%
posts_0_z = []
for i in inds:
  posts_0_z.append(posts[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-f999c2632aaf> in <cell line: 2>()
#       1 posts_0_z = []
#       2 for i in inds:
# ----> 3   posts_0_z.append(posts[i])
#
# NameError: name 'posts' is not defined

# %%
len(posts_0_z)
# Out:
# 38875

# %%
f = open('./drive/MyDrive/Hackathon/posts_z_0.pkl', 'wb')
pickle.dump(posts_0_z, f)
f.close()

# %%
f = open('./drive/MyDrive/Hackathon/posts_z_0.pkl', 'rb')
posts_0_z = pickle.load(f)
f.close()

# %%
posts_clean = []

for post in posts_0_z:
    text = post['text']
    text.replace('\n','')
    posts_clean.append(text)

# %%
model = BERTopic(verbose=True, language = 'multilingual', min_topic_size = 30, low_memory = True)
topics, probabilities = model.fit_transform(posts_clean)
model.get_topic_info()[:10]
# Out:
# Batches:   0%|          | 0/1215 [00:00<?, ?it/s]
# 2023-04-01 18:10:57,154 - BERTopic - Transformed documents to Embeddings
# 2023-04-01 18:11:51,102 - BERTopic - Reduced dimensionality
# 2023-04-01 18:11:57,333 - BERTopic - Clustered reduced embeddings
#    Topic  Count                                       Name
# 0     -1  22585                            -1_на_мы_наш_не
# 1      0   1453                  0_нацизм_фашизм_вы_победа
# 2      1    956    1_путин_владимир_президент_владимирович
# 3      2    880       2_президент_наш_поддерживать_решение
# 4      3    748          3_запад_западный_санкция_общество
# 5      4    478  4_информация_фейк_информационный_источник
# 6      5    431                 5_мир_пусть_нужный_планета
# 7      6    399               6_видео_украинский_фейк_буча
# 8      7    391               7_день_праздник_акция_родина
# 9      8    333               8_помощь_спасибо_сбор_ребята

# %%
model.get_topic_info()
# Out:
#      Topic  Count                                               Name
# 0       -1  22585                                    -1_на_мы_наш_не
# 1        0   1453                          0_нацизм_фашизм_вы_победа
# 2        1    956            1_путин_владимир_президент_владимирович
# 3        2    880               2_президент_наш_поддерживать_решение
# 4        3    748                  3_запад_западный_санкция_общество
# ..     ...    ...                                                ...
# 153    152     32  152_отстаивать_сплачиваться_безопасность_заявлять
# 154    153     31                153_еремин_сильный_участвующий_юрий
# 155    154     31  154_бить_солдатымужчина_укомплектование_инвали...
# 156    155     31               155_меркель_минский_соглашение_ангел
# 157    156     31                 156_8летней_война_завершение_режим
#
# [158 rows x 3 columns]

# %%
model.save("./drive/MyDrive/Hackathon/model_0_z")
# Out:
# /usr/local/lib/python3.9/dist-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
model = BERTopic.load("./drive/MyDrive/Hackathon/model_0_z")

# %%
model.merge_topics(posts_clean, [[69,54,4,40,134],
                                 [10,2],
                                 [34,59,156,70],
                                 [0,47],
                                 [9,30],
                                 [18,19,152],
                                 [45,73],
                                 [82,13],
                                 [24,68],
                                 [12,17,32,22,26]
                                 ])

# %%
model.merge_topics(posts_clean, [[14,5],
                                 [21,7]
                                 ]) #

# %%
hierarchical_topics = model.hierarchical_topics(posts_clean)
tree = model.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# 100%|██████████| 135/135 [00:01<00:00, 123.93it/s]
# .
# ├─наш_быть_милосердие_оставлять_нацизм
# │    ├─справка_бедность_готовый_исключительно_эртель
# │    │    ├─суверенитет_ресурс_солдатосвободитель_оружие_вооружение
# │    │    │    ├─ресурс_солдатосвободитель_оружие_вооружение_суверенитет
# │    │    │    │    ├─солдатосвободитель_иначе_подряд_жарить_застреливать
# │    │    │    │    │    ├─■──расширение_счет_единственно_прямой_иначе ── Topic: 70
# │    │    │    │    │    └─■──солдатосвободитель_подряд_жарить_застреливать_ружье ── Topic: 43
# │    │    │    │    └─ресурс_вооружение_суверенитет_мощи_завистник
# │    │    │    │         ├─■──ресурс_вооружение_суверенитет_мощи_завистник ── Topic: 48
# │    │    │    │         └─■──внутри_обороноспособность_природный_традиция_богатство ── Topic: 79
# │    │    │    └─способный_окрепнуть_эффективно_однозначно_защищать
# │    │    │         ├─способный_безопасность_затрагивать_вооруженный_минобороны
# │    │    │         │    ├─■──безопасность_минобороны_твердо_zа_военнослужащий ── Topic: 77
# │    │    │         │    └─■──затрагивать_способный_интерес_показывать_безопасность ── Topic: 130
# │    │    │         └─■──окрепнуть_эффективно_однозначно_лавров_способный ── Topic: 113
# │    │    └─справка_бедность_эртель_грань_сборная
# │    │         ├─справка_бедность_эртель_грань_сборная
# │    │         │    ├─справка_бедность_эртель_грань_сборная
# │    │         │    │    ├─эртель_сборная_берлин_контракт_бедный
# │    │         │    │    │    ├─берлин_гогунский_мороз_конь_зимний
# │    │         │    │    │    │    ├─■──гогунский_мороз_конь_зимний_виталий ── Topic: 82
# │    │         │    │    │    │    └─берлин_балерина_станцевать_лебединый_брусчатка
# │    │         │    │    │    │         ├─■──берлин_балерина_станцевать_лебединый_брусчатка ── Topic: 108
# │    │         │    │    │    │         └─■──социальнореабилитационный_асго_мку_несовершеннолетний_воспитанник ── Topic: 128
# │    │         │    │    │    └─эртель_сборная_контракт_бедный_четыре
# │    │         │    │    │         ├─бедный_четыре_выбор_пожаловать_херсонщина
# │    │         │    │    │         │    ├─■──выбор_пожаловать_херсонщина_запорожье_предоставлять ── Topic: 49
# │    │         │    │    │         │    └─■──бедный_зерновые_послышаться_минсельхоз_безвозмездно ── Topic: 122
# │    │         │    │    │         └─■──эртель_сборная_контракт_баскетболист_сюта ── Topic: 109
# │    │         │    │    └─справка_бедность_госслужба_психический_поступление
# │    │         │    │         ├─■──бедность_запущенный_германоязычный_twitter_сегмент ── Topic: 78
# │    │         │    │         └─■──справка_госслужба_психический_поступление_адекватность ── Topic: 47
# │    │         │    └─эмоциональный_крымчанин_состояние_сомнение_букин
# │    │         │         ├─крымчанин_состояние_подрывать_переселенец_изолировать
# │    │         │         │    ├─■──изолировать_невозможный_состояние_никто_картинка ── Topic: 66
# │    │         │         │    └─■──крымчанин_подрывать_переселенец_эмоциональный_исторически ── Topic: 129
# │    │         │         └─сомнение_букин_мма_одержимый_сочи
# │    │         │              ├─■──букин_мма_сочи_турнир_яков ── Topic: 131
# │    │         │              └─■──одержимый_счастие_сомнение_наступать_патриот ── Topic: 125
# │    │         └─яр_путем_байден_исключительно_154
# │    │              ├─путем_водить_нос_выясняться_приводить
# │    │              │    ├─■──недоброжелатель_критиковать_срок_путем_короткий ── Topic: 92
# │    │              │    └─■──водить_нос_выясняться_обманывать_путем ── Topic: 94
# │    │              └─яр_байден_исключительно_154_жилой
# │    │                   ├─яр_исключительно_154_жилой_бить
# │    │                   │    ├─■──яр_часов_часы_рюкзак_внаглый ── Topic: 95
# │    │                   │    └─исключительно_154_бить_наноситься_поверживать
# │    │                   │         ├─■──154_наноситься_поверживать_град_13 ── Topic: 87
# │    │                   │         └─■──бить_солдатымужчина_укомплектование_инвалидность_неадекватный ── Topic: 134
# │    │                   └─байден_телеоператор_бицепс_оаэ_индонезия
# │    │                        ├─■──отсталый_умственный_трамп_физически_победитель ── Topic: 101
# │    │                        └─■──байден_телеоператор_бицепс_оаэ_индонезия ── Topic: 69
# │    └─милосердие_отечественный_дед_оставлять_великий
# │         ├─нация_нацист_переосмысливать_граничить_против
# │         │    ├─■──нация_против_бороться_нацист_свой ── Topic: 127
# │         │    └─■──переосмысливать_граничить_беспрепятственно_красноармеец_крушить ── Topic: 50
# │         └─милосердие_оставлять_страница_полагать_закрывать
# │              ├─оставлять_дед_навсегда_полагать_прадед
# │              │    ├─■──хлюпать_мужик_ныть_кузбасс_вставать ── Topic: 111
# │              │    └─оставлять_навсегда_полагать_прадед_заключаться
# │              │         ├─■──внучка_красилов_чекоданова_тамара_ас ── Topic: 97
# │              │         └─■──оставлять_заключаться_окончательно_черный_спокойный ── Topic: 26
# │              └─милосердие_кулак_кто_георгиевский_артист
# │                   ├─артист_музыкант_эфир_кунис_мила
# │                   │    ├─■──эфир_патриотически_нтв_петиция_возмущать ── Topic: 132
# │                   │    └─музыкант_артист_кунис_мила_ткаченко
# │                   │         ├─■──ткаченко_звание_адекватный_артист_музыкант ── Topic: 44
# │                   │         └─■──кунис_мила_добасс_актриса_истребление ── Topic: 110
# │                   └─милосердие_кулак_кто_георгиевский_проявлять
# │                        ├─милосердие_кулак_георгиевский_кто_проявлять
# │                        │    ├─милосердие_кулак_георгиевский_кто_проявлять
# │                        │    │    ├─■──милосердие_кулак_проявлять_кто_нереально ── Topic: 55
# │                        │    │    └─георгиевский_лента_тогда_сс_эмблема
# │                        │    │         ├─эмблема_тогда_мертвый_дивизия_почему
# │                        │    │         │    ├─■──реформироваться_самодостаточность_скептик_очищение_савельев ── Topic: 73
# │                        │    │         │    └─■──эмблема_тогда_мертвый_дивизия_почему ── Topic: 45
# │                        │    │         └─■──георгиевский_лента_символ_ленточка_законопроект ── Topic: 85
# │                        │    └─арктика_северный_кавказ_еремин_спиридонов
# │                        │         ├─кавказ_еремин_спиридонов_северный_сильный
# │                        │         │    ├─■──спиридонов_украшать_кабинет_дверь_александр ── Topic: 112
# │                        │         │    └─■──еремин_сильный_участвующий_юрий_кавказ ── Topic: 133
# │                        │         └─■──арктика_крюкова_погнушаться_промышленновский_фикция ── Topic: 76
# │                        └─шахтер_пообещать_кодуэлл_отапливать_поклясться
# │                             ├─пообещать_кодуэлл_поклясться_отапливать_казна
# │                             │    ├─кодуэлл_отапливать_поклясться_особняк_казна
# │                             │    │    ├─■──совершенствовать_прислушиваться_взаимодействие_поблагодарить_оказывать ── Topic: 107
# │                             │    │    └─■──кодуэлл_поклясться_отапливать_особняк_казна ── Topic: 106
# │                             │    └─шахтер_привет_кузбасс_гребенщикова_аквариум
# │                             │         ├─■──световой_vсё_артобъект_магнитогорск_мэрия ── Topic: 123
# │                             │         └─■──шахтер_кузбасс_аквариум_гребенщикова_дружба ── Topic: 119
# │                             └─любовь_черта_немалый_акимов_битва
# │                                  ├─■──акимов_шахтер_дк_вытеснять_радовать ── Topic: 65
# │                                  └─■──немалый_любовь_черта_степень_основа ── Topic: 117
# └─не_на_наш_мы_что
#      ├─на_не_что_украина_по
#      │    ├─украинский_фейк_информация_донецк_по
#      │    │    ├─азовсталь_они_еда_профсоюз_продукт
#      │    │    │    ├─азовсталь_еда_продукт_они_мариуполь
#      │    │    │    │    ├─■──азовсталь_продукт_еда_заложник_медикамент ── Topic: 38
#      │    │    │    │    └─мариуполь_эвакуировать_житель_стрелять_укронацист
#      │    │    │    │         ├─■──укронацист_мариуполь_расстреливать_житель_нацист ── Topic: 88
#      │    │    │    │         └─■──эвакуировать_мариуполь_жительница_стрелять_вылечивать ── Topic: 83
#      │    │    │    └─■──профсоюз_одесса_май_заживо_сжигать ── Topic: 93
#      │    │    └─фейк_украинский_информация_донецк_по
#      │    │         ├─фейк_украинский_информация_донецк_по
#      │    │         │    ├─фейк_информация_информационный_видео_украинский
#      │    │         │    │    ├─■──видео_военнопленный_украинский_пленный_нацист ── Topic: 86
#      │    │         │    │    └─фейк_информация_информационный_видео_правда
#      │    │         │    │         ├─■──видео_украинский_фейк_буча_тело ── Topic: 8
#      │    │         │    │         └─■──информация_информационный_фейк_источник_правда ── Topic: 3
#      │    │         │    └─донецк_обстрел_удар_украинский_всу
#      │    │         │         ├─донецк_обстрел_удар_всу_украинский
#      │    │         │         │    ├─украинский_всу_по_военный_преступление
#      │    │         │         │    │    ├─■──этап_шойгу_основной_войско_снижать ── Topic: 33
#      │    │         │         │    │    └─украинский_всу_суд_преступление_плен
#      │    │         │         │    │         ├─■──плен_сдаваться_всу_украинский_военнослужащий ── Topic: 36
#      │    │         │         │    │         └─■──суд_преступление_уголовный_задерживать_украинский ── Topic: 17
#      │    │         │         │    └─донецк_обстрел_удар_центр_погибать
#      │    │         │         │         ├─■──донецк_обстрел_удар_центр_погибать ── Topic: 7
#      │    │         │         │         └─■──школа_националист_мирный_жилой_украинский ── Topic: 40
#      │    │         │         └─■──минобороны_архив_зверство_документ_08042022 ── Topic: 102
#      │    │         └─■──прилагать_избежание_замечание_вовсе_выводить ── Topic: 71
#      │    └─наш_мир_не_президент_на
#      │         ├─запад_путин_россия_владимир_страна
#      │         │    ├─переговоры_соглашение_неизменный_требование_минский
#      │         │    │    ├─■──меркель_минский_соглашение_ангел_япония ── Topic: 135
#      │         │    │    └─■──переговоры_неизменный_требование_позиция_переговорный ── Topic: 22
#      │         │    └─путин_запад_россия_владимир_страна
#      │         │         ├─путин_запад_владимир_россия_президент
#      │         │         │    ├─оружие_сша_вооружение_поставка_украина
#      │         │         │    │    ├─■──ядерный_оружие_создание_химический_сша ── Topic: 53
#      │         │         │    │    └─■──вооружение_сша_поставка_оружие_доллар ── Topic: 19
#      │         │         │    └─путин_запад_владимир_россия_президент
#      │         │         │         ├─путин_запад_владимир_россия_президент
#      │         │         │         │    ├─путин_запад_владимир_россия_президент
#      │         │         │         │    │    ├─■──путин_владимир_президент_владимирович_поддерживать ── Topic: 2
#      │         │         │         │    │    └─■──запад_западный_санкция_общество_россия ── Topic: 4
#      │         │         │         │    └─украина_запад_сша_европа_переговоры
#      │         │         │         │         ├─■──украина_россия_глава_мид_путин ── Topic: 20
#      │         │         │         │         └─■──запад_украина_переговоры_европа_чтобы ── Topic: 23
#      │         │         │         └─■──зеленский_он_визит_украина_сша ── Topic: 15
#      │         │         └─■──матвиенко_валентина_межпарламентский_комфорт_переходить ── Topic: 62
#      │         └─мир_наш_мы_нацизм_за
#      │              ├─мир_наш_мы_нацизм_за
#      │              │    ├─наш_нацизм_мы_президент_фашизм
#      │              │    │    ├─■──взятие_спаситель_восьмилетний_существенный_обдуманный ── Topic: 121
#      │              │    │    └─наш_нацизм_мы_фашизм_президент
#      │              │    │         ├─наш_нацизм_мы_фашизм_президент
#      │              │    │         │    ├─наш_нацизм_фашизм_мы_вы
#      │              │    │         │    │    ├─■──переживать_сплачивать_довольно_период_сложный ── Topic: 120
#      │              │    │         │    │    └─наш_нацизм_фашизм_мы_вы
#      │              │    │         │    │         ├─■──вы_не_мой_как_что ── Topic: 74
#      │              │    │         │    │         └─наш_нацизм_фашизм_мы_президент
#      │              │    │         │    │              ├─наш_нацизм_фашизм_мы_президент
#      │              │    │         │    │              │    ├─■──нацизм_фашизм_вы_победа_мы ── Topic: 0
#      │              │    │         │    │              │    └─президент_наш_поддерживать_решение_мы
#      │              │    │         │    │              │         ├─■──война_донбасс_год_не_заканчивать ── Topic: 12
#      │              │    │         │    │              │         └─■──президент_наш_поддерживать_решение_армия ── Topic: 1
#      │              │    │         │    │              └─■──человек_год_не_происходить_донбасс ── Topic: 104
#      │              │    │         │    └─операция_февраль_украина_24_специальный
#      │              │    │         │         ├─операция_февраль_украина_24_специальный
#      │              │    │         │         │    ├─■──земляк_украина_сила_происходить_оставаться ── Topic: 21
#      │              │    │         │         │    └─февраль_24_операция_специальный_донбасс
#      │              │    │         │         │         ├─■──февраль_24_2022_операция_год ── Topic: 16
#      │              │    │         │         │         └─■──район_житель_следить_межевской_костромской ── Topic: 31
#      │              │    │         │         └─■──каждый_необходимый_паниковать_решение_поддержка ── Topic: 58
#      │              │    │         └─цепенеть_элементарный_градус_голодный_кадры
#      │              │    │              ├─■──солдат_zov_армия_произвол_задача ── Topic: 116
#      │              │    │              └─■──цепенеть_элементарный_градус_голодный_кадры ── Topic: 24
#      │              │    └─мир_за_пусть_нужный_небо
#      │              │         ├─■──созидательный_война_год_налаживать_справедливость ── Topic: 81
#      │              │         └─■──мир_пусть_за_нужный_планета ── Topic: 6
#      │              └─язык_ленин_состав_народ_усср
#      │                   ├─ленин_усср_украина_состав_1917
#      │                   │    ├─■──ленин_усср_1917_автономия_лднр ── Topic: 54
#      │                   │    └─■──переезжать_язык_украинец_народ_проект ── Topic: 80
#      │                   └─■──язык_русский_культура_народ_словом ── Topic: 67
#      └─родина_мы_свой_наш_страна
#           ├─русский_ты_вы_душа_не
#           │    ├─■──русский_называться_душа_чей_ль ── Topic: 56
#           │    └─ты_русский_вы_не_мой
#           │         ├─русский_ты_вы_не_бог
#           │         │    ├─русский_вы_ты_не_бог
#           │         │    │    ├─■──русский_улыбаться_деникин_антон_фамилия ── Topic: 37
#           │         │    │    └─русский_ты_вы_бог_не
#           │         │    │         ├─■──мой_русский_любить_душа_синий ── Topic: 114
#           │         │    │         └─вы_русский_ты_бог_не
#           │         │    │              ├─■──русский_ты_бог_вы_мы ── Topic: 39
#           │         │    │              └─■──вы_ты_пусть_враг_русский ── Topic: 18
#           │         │    └─■──ты_пятый_твой_впадать_легендарный ── Topic: 91
#           │         └─■──ты_причал_мой_родной_река ── Topic: 96
#           └─родина_наш_свой_страна_мы
#                ├─родина_патриотизм_страна_свой_наш
#                │    ├─угрожать_подымать_своевременность_бесконтрольный_позволять
#                │    │    ├─■──бесконтрольный_удивительно_явно_накачивать_своевременность ── Topic: 29
#                │    │    └─позволять_диктовать_напрямую_брать_гордость
#                │    │         ├─■──позволять_вольно_рассекречивать_защищать_масть ── Topic: 59
#                │    │         └─■──позволять_диктовать_напрямую_брать_гордость ── Topic: 63
#                │    └─родина_патриотизм_свой_страна_мы
#                │         ├─решение_принимать_президент_шаг_обдумывать
#                │         │    ├─принимать_решение_сильный_духовно_зависимый
#                │         │    │    ├─духовно_зависимый_богатый_физически_важность
#                │         │    │    │    ├─■──странызащитница_розовский_сход_доброжелательный_конструктивный ── Topic: 118
#                │         │    │    │    └─■──духовно_зависимый_богатый_физически_важность ── Topic: 68
#                │         │    │    └─относительно_верный_принимать_серьезный_качество
#                │         │    │         ├─качество_улучшение_неуверенность_стабилизировать_большинство
#                │         │    │         │    ├─■──гордиться_президент_целиком_стыдно_он ── Topic: 100
#                │         │    │         │    └─■──качество_улучшение_неуверенность_стабилизировать_большинство ── Topic: 64
#                │         │    │         └─■──относительно_верный_серьезный_смелый_недружественный ── Topic: 57
#                │         │    └─обдумывать_ответственный_крайний_шаг_защита
#                │         │         ├─обдумывать_интерес_ответственный_рубеж_защита
#                │         │         │    ├─■──всецело_исключительно_интерес_решение_внешний ── Topic: 72
#                │         │         │    └─■──обдумывать_рубеж_ответственный_крайний_шаг ── Topic: 34
#                │         │         └─■──кадыйский_взаимоотношение_провокационный_сплоченный_паниковать ── Topic: 126
#                │         └─патриотизм_родина_свой_страна_мы
#                │              ├─патриотизм_родина_свой_страна_мы
#                │              │    ├─переживать_существование_давление_сегодня_добро
#                │              │    │    ├─переживать_существование_давление_сложный_вскоре
#                │              │    │    │    ├─■──переживать_существование_вскоре_полномасштабный_период ── Topic: 51
#                │              │    │    │    └─■──стойкость_уверенность_экономический_условие_давление ── Topic: 103
#                │              │    │    └─меч_право_обычай_праведный_традиция
#                │              │    │         ├─меч_обычай_праведный_традиция_подымать
#                │              │    │         │    ├─■──бросать_произвол_завладевать_раз_людской ── Topic: 46
#                │              │    │         │    └─■──обычай_праведный_меч_вера_возвращаться ── Topic: 115
#                │              │    │         └─■──выдерживать_сражаться_неонацист_простой_трудность ── Topic: 98
#                │              │    └─патриотизм_родина_свой_страна_мы
#                │              │         ├─патриотизм_родина_свой_любовь_страна
#                │              │         │    ├─патриотизм_родина_любовь_гордиться_свой
#                │              │         │    │    ├─■──патриотизм_родина_любовь_гордиться_любить ── Topic: 5
#                │              │         │    │    └─■──мы_единый_вместе_страна_народ ── Topic: 10
#                │              │         │    └─■──готовый_враг_никто_сильный_рекомендовать ── Topic: 25
#                │              │         └─информационный_преднамеренный_негативный_недовольство_война
#                │              │              ├─■──друг_преднамеренный_дань_негативный_будущий ── Topic: 75
#                │              │              └─■──информационный_преднамеренный_война_негативный_против ── Topic: 30
#                │              └─вместе_победа_ребята_участвовать_малый
#                │                   ├─участвовать_малый_вместе_ребята_трудный
#                │                   │    ├─■──малый_трудный_участвовать_объединяться_время ── Topic: 89
#                │                   │    └─■──пожелать_всколыхивать_исповедовать_одерживать_победа ── Topic: 61
#                │                   └─победа_zа_бог_побеждать_мы
#                │                        ├─■──победа_побеждать_zа_сила_вперед ── Topic: 41
#                │                        └─■──бог_гроза_вы_слава_ребята ── Topic: 32
#                └─мобилизация_частичный_поддержка_акция_наш
#                     ├─мобилизация_частичный_поддержка_акция_наш
#                     │    ├─поддержка_акция_поддерживать_наш_ребята
#                     │    │    ├─городской_совет_округ_банда_депутат
#                     │    │    │    ├─■──ленинсккузнецкий_будяковская_федерация_округ_городской ── Topic: 105
#                     │    │    │    └─■──банда_городской_депутат_феодосийский_совет ── Topic: 28
#                     │    │    └─акция_поддержка_наш_поддерживать_ребята
#                     │    │         ├─поддержка_акция_наш_поддерживать_ребята
#                     │    │         │    ├─■──zа_армия_россиянин_поддерживать_говорить ── Topic: 42
#                     │    │         │    └─акция_поддержка_наш_помощь_поддерживать
#                     │    │         │         ├─■──акция_поддержка_флешмоб_патриотический_российский ── Topic: 13
#                     │    │         │         └─помощь_ребята_наш_день_спасибо
#                     │    │         │              ├─■──день_праздник_акция_родина_за ── Topic: 9
#                     │    │         │              └─■──помощь_спасибо_сбор_ребята_помогать ── Topic: 11
#                     │    │         └─■──молодежь_движение_инициатива_школьник_молодой ── Topic: 60
#                     │    └─мобилизация_частичный_служба_специальность_указ
#                     │         ├─■──мобилизация_частичный_служба_специальность_опыт ── Topic: 14
#                     │         └─совещание_регион_совет_безопасность_владимир
#                     │              ├─■──указ_регион_уровень_объект_введение ── Topic: 99
#                     │              └─■──совещание_совет_встреча_владимир_путин ── Topic: 52
#                     └─социальный_сеть_сайт_instagram_meta
#                          ├─сайт_instagram_meta_одноклассник_facebook
#                          │    ├─сайт_объясняемрф_портал_контент_информация
#                          │    │    ├─объясняемрф_портал_информация_сайт_вопрос
#                          │    │    │    ├─■──хакер_взламывать_сайт_anonymous_killnet ── Topic: 84
#                          │    │    │    └─■──объясняемрф_портал_информация_вопрос_актуальный ── Topic: 35
#                          │    │    └─■──контент_пользовательский_сайт_неравнодушный_патриотический ── Topic: 90
#                          │    └─■──instagram_meta_facebook_компания_насилие ── Topic: 27
#                          └─■──социальный_72_сфабриковать_множиться_почва ── Topic: 124

# %%
model.merge_topics(posts_clean, [[9,13]])

# %%
model.save("./drive/MyDrive/Hackathon/model_0_z_merged")

# %%
model = BERTopic.load("./drive/MyDrive/Hackathon/model_0_z_merged")

# %%
model.merge_topics(posts_clean, [[1,2]])

# %%
model.get_topic_info()[:20]
# Out:
#     Topic  Count                                           Name
# 0      -1  22585                                -1_на_мы_наш_не
# 1       0   2102             0_президент_путин_поддерживать_наш
# 2       1   1532                      1_нацизм_фашизм_вы_победа
# 3       2    955      2_информация_информационный_фейк_источник
# 4       3    748              3_запад_западный_санкция_общество
# 5       4    747           4_патриотизм_родина_любовь_гордиться
# 6       5    632            5_акция_поддержка_день_поддерживать
# 7       6    567                          6_мир_пусть_за_нужный
# 8       7    432                    7_донецк_обстрел_удар_центр
# 9       8    399                   8_видео_украинский_фейк_буча
# 10      9    355                      9_мы_единый_вместе_страна
# 11     10    333                  10_помощь_спасибо_сбор_ребята
# 12     11    260                        11_война_донбасс_год_не
# 13     12    184  12_мобилизация_частичный_служба_специальность
# 14     13    184                  13_зеленский_он_визит_украина
# 15     14    180                    14_февраль_24_2022_операция
# 16     15    177      15_суд_преступление_уголовный_задерживать
# 17     16    152                            16_вы_ты_пусть_враг
# 18     17    145              17_вооружение_сша_поставка_оружие
# 19     18    129                  18_украина_россия_глава_путин

# %%
topics = model.topics_

# %%
new_topics = model.reduce_outliers(posts_clean, topics, threshold = 0.3)
# Out:
# 100%|██████████| 23/23 [00:22<00:00,  1.03it/s]

# %%
f = open("./drive/MyDrive/Hackathon/stop_words_russian.txt", "r", encoding="utf-8")
stop_words = f.read()
f.close()
stop_words = stop_words.split("\n")

# %%
def remove_suspicious_users(topic_n, posts, topics = new_topics):
  users_ids = []
  inds = find_indices(topics, topic_n)
  users_ids = [posts[j]['owner_id'] for j in inds]
  u, c = np.unique(np.array(users_ids), return_counts=True)

  n_posts = len(inds)

  users_ok = []

  for i in range(len(c)):
    if c[i]/n_posts < 0.15:
      users_ok.append(u[i])

  inds_ok = []
  for ind in inds:
    if posts[ind]['owner_id'] in users_ok:
      inds_ok.append(ind)

  return inds_ok

# %%
def define_topic_params(topic_ind, topics = topics):
  words = [item[0] for item in model.get_topic(topic_ind)][:10]
  for word in words:
    if word in stop_words:
      words.remove(word)

  words = words[:5]
  words = ', '.join(words)
  inds = remove_suspicious_users(topic_ind, posts_0_z, topics = topics)
  count_z = 0
  for i in inds:
      count_z += 1
  total_popularity = count_z/len(posts_clean)
  return words, total_popularity, count_z

# %%
def get_random_post_topic(topic_ind, topics = topics):
  inds = remove_suspicious_users(topic_ind, posts_0_z)
  random.shuffle(inds)
  texts = []
  # text = str(inds[0])+' '+str(posts_0_z[inds[0]]['owner_id']) + ' ' + posts_0_z[inds[0]]['initial_text']
  text = posts_0_z[inds[0]]['initial_text']
  return text, inds[0]

# %%
total_pops = []
count = []
names = []
for i in range(19): 
  words, total_popularity, count_z = define_topic_params(i, new_topics)
  total_pops.append(total_popularity)
  count.append(count_z)
  names.append(words)
  print(i, words)
# Out:
# 0 президент, путин, поддерживать, решение, владимир
# 1 нацизм, фашизм, победа, наш, дед
# 2 информация, информационный, фейк, источник, правда
# 3 запад, западный, санкция, общество, россия
# 4 патриотизм, родина, любовь, гордиться, любить
# 5 акция, поддержка, поддерживать, проходить, участие
# 6 мир, пусть, нужный, планета, небо
# 7 донецк, обстрел, удар, центр, погибать
# 8 видео, украинский, фейк, буча, тело
# 9 единый, вместе, народ, единство, друг
# 10 помощь, спасибо, сбор, ребята, помогать
# 11 война, донбасс, не, заканчивать, житель
# 12 мобилизация, частичный, служба, специальность, опыт
# 13 зеленский, визит, украина, сша, западный
# 14 февраль, 24, 2022, операция, владимир
# 15 суд, преступление, уголовный, задерживать, украинский
# 16 ты, пусть, враг, русский, хранить
# 17 вооружение, сша, поставка, оружие, доллар
# 18 украина, россия, глава, путин, мид

# %%
get_random_post_topic(6, topics = new_topics)
# Out:
# ('Росию покорить всегда пытались,\nФрацузы, Немцы, Шведы, Турки, Итальянцы и Японцы.\nНо лишь вступив за Русские границы все получали по зубам!\n\nИ Вас история не учит, не надо с нами воевать!\n\n🇷🇺Россия мира хочет, и за себя готова постоять!\n\n#ZV\n#ZаРоссию #ZаНаших #СвоихНеБросаем',
#  12503)

# %%
inds = []

for i in range(100):
  text, ind = get_random_post_topic(6, topics = new_topics)
  while (ind in inds) or len(text)>300:
    text, ind = get_random_post_topic(1, topics = new_topics)
  inds.append(ind)
  print(text)
  print('________________________________')
# Out:
# #ZаРоссию
# #ZаМирБезНацизма
# #СвоихНеБросаем
# У России историческая миссия - мир спасать.
# ________________________________
# 03.03.2022 г.
#
# МЫ за МИР на ЗЕМЛЕ!
# #СвоихНеБросаем
# #ДавайЗаМир
# #МыВместе
# #ВремяПомогать
# ________________________________
# ________________________________
# #ZаНаших#ZаМир#ZаПрезидента#ZаПобеду
# Во все времена сила нашего народа была в единстве и сплочённости.
# Мы за мир, за справедливость для всех, за чистое небо над головой!
# ________________________________
# Мужества и отваги пожелаем сегодня нашим солдатам, которые оберегают наши границы от настоящего фашизма.
# #ZаРоссию #ZаНаших #ZаПутина #СвоихНеБросаем
# ________________________________
# Я поддерживаю спец операцию! Потому что 8 лет от нацисткой власти страдали невинные люди!!! Мы за мир! За мир без нацизма! Спасибо героям нашим за их неоценимый труд! За освобождение мирного населения от гнёта бандеровцев!!!!!!!! #своихнебросаем
# ________________________________
# Сейчас как и 77 лет назад ведется борьба с фашизмом!
# В этот переломный для всего мира год важно быть вместе!
# Вместе за мир!
#
# #Своихнебросаем
# #Замир
# ________________________________
# Алексей Шереметьев: «Главная задача – защита мирного населения» https://gazeta-schekino.ru/news/aleksey-sheremetev-glavnaya-za/ #СвоихНеБросаем и #СвоихНеБросаем71
# ________________________________
# Мы за МИР  во всем МИРЕ!
#
# #ZAМИР#ЗаПрезидента#СвоихНеБросаем#мненестыдно#русскаявесна
# ________________________________
# Ребята! Родные! Держитесь! Мы - с вами!
# И пусть вас Всевышний и ангел хранит!
# Фашизм не пройдёт! И Победа за нами!
# А павших героев запомнит гранит.
#
# #СвоихНеБросаем #zaПутина #РоссияzaПутина
# #ZаМир #ZаРоссию #ZаПрезидента
# ________________________________
# Пока жива память - жив и человек. Так говорили всегда. Наша память живёт и помнит подвиги нашей армии, которая в годы ВОВ победила фашизм. Сегодня снова наши солдаты сражаются против фашизма.
#
# Сохраним наш род, будем помнить его всегда?
#
# #СвоихНеБросаем, #ЗаНамиПраVда.
# ________________________________
# Мы - Великий народ! Мы должны об этом помнить всегда. У нас есть историческая память, культура и традиции, которые мы должны помнить, чтить и уважать. Россия никогда не давала в обиду своих. Мы, россияне, за мир во всём мире!!!
# #БольшаяШатура
# #СвоихНеБросаем
# #Zамир
# #ZаРоссию
# #мывместе
# ________________________________
# Герои Z. Вы достойны памяти своих дедов, освободивших мир от фашизма! #Своихнебросаем#ZAМИР#БольшаяШатура
# ________________________________
# Полина Гагарина - Кукушка(Концерт-митинг Za мир без нацизма в Лужниках)
# #Zапобеду #ZадачаБудетВыполнена #силаVПравде #своихНеБросаем #ZaНаших #ZаРоссию
# ________________________________

# %% [markdown]
# ## Check threshold

# %%
thresholds = np.linspace(0.05,1,20)

# %%
size_1 = []
totals = []
percents = []

for t in thresholds:
  new_topics = model.reduce_outliers(posts_clean, topics, threshold = t)
  total = []
  for i in range(-1,18):
    _,_,count = define_topic_params(i, topics = new_topics)
    if i!=-1:
      total.append(count)
    else:
      size_1.append(count)
  totals.append(total)
  percents.append(np.array(total)/np.sum(total))
# Out:
# 100%|██████████| 23/23 [00:20<00:00,  1.12it/s]
# 100%|██████████| 23/23 [00:22<00:00,  1.02it/s]
# 100%|██████████| 23/23 [00:19<00:00,  1.16it/s]
# 100%|██████████| 23/23 [00:22<00:00,  1.03it/s]
# 100%|██████████| 23/23 [00:20<00:00,  1.12it/s]
# 100%|██████████| 23/23 [00:21<00:00,  1.07it/s]
# 100%|██████████| 23/23 [00:21<00:00,  1.07it/s]
# 100%|██████████| 23/23 [00:20<00:00,  1.10it/s]
# 100%|██████████| 23/23 [00:21<00:00,  1.08it/s]
# 100%|██████████| 23/23 [00:21<00:00,  1.06it/s]
# 100%|██████████| 23/23 [00:19<00:00,  1.17it/s]
# 100%|██████████| 23/23 [00:20<00:00,  1.15it/s]
# 100%|██████████| 23/23 [00:22<00:00,  1.04it/s]
# 100%|██████████| 23/23 [00:19<00:00,  1.17it/s]
# 100%|██████████| 23/23 [00:21<00:00,  1.06it/s]
# 100%|██████████| 23/23 [00:19<00:00,  1.15it/s]
# 100%|██████████| 23/23 [00:19<00:00,  1.17it/s]
# 100%|██████████| 23/23 [00:20<00:00,  1.10it/s]
# 100%|██████████| 23/23 [00:19<00:00,  1.15it/s]
# 100%|██████████| 23/23 [00:21<00:00,  1.06it/s]

# %%
plt.figure()
plt.plot(thresholds, size_1)

# %%
plt.figure()
plt.plot(thresholds, totals)
plt.legend([str(i) for i in range(18)])

# %%
plt.figure()
plt.plot(thresholds, percents)
plt.legend([str(i) for i in range(18)])

# %%
plt.figure()
plt.plot(thresholds, [p[11]+p[6] for p in percents])

# %%
new_topics = model.reduce_outliers(posts_clean, topics, threshold = 0.3)
# Out:
# 100%|██████████| 23/23 [00:27<00:00,  1.21s/it]

# %%
define_topic_params(7, new_topics)
# Out:
# ('мир, пусть, нужный, планета, небо', 0.04362700964630225, 1696)

# %%
define_topic_params(1, new_topics)
# Out:
# ('президент, поддерживать, решение, армия, принимать',
#  0.06510610932475884,
#  2531)

# %%
define_topic_params(6, new_topics)
# Out:
# ('мир, пусть, нужный, планета, небо', 0.04573633440514469, 1778)

# %%
def get_repr_docs(topic):
  representative_docs = model.get_representative_docs(topic)
  posts = []
  for doc in representative_docs:
    ind = np.nonzero([post == doc for post in posts_clean])[0][0]
    posts.append(posts_0_z[ind]['initial_text'])
  return posts

# %%
docs = get_repr_docs(3)

# %%
docs[2]
# Out:
# 'Сегодня мы видим невероятную сплоченность страны вокруг нашего Президента Путина. В ответ на все попытки Запада информационного, экономического, психологического и гуманитарного давления российский народ объединился. Произошла консолидация общества. Такого сплочения страны давно не было. \n \nВсе ведущие социологические структуры России фиксируют высочайший рейтинг (электоральный и доверия) Путина и его поддержку гражданами. На прямой вопрос о доверии Владимиру Путину положительно ответили 81,0% опрошенных россиян, одобряют его работу на посту Президента РФ: 79%. Цифры одобрения деятельности Путина на посту главы государства превышают цифры его поддержки на выборах три года назад – в марте 2018-го.\n \nЭтому способствовали решения, принятые Президентом за последние полтора месяца, начиная от признания ЛНР и ДНР, проведения специальной военной операции на Украине и заканчивая точечными социальными и экономическими поручениями Правительству. А также заявления и предложения Президента по противостоянию санкционному давлению Запада, давно переросшему в полномасштабную экономическую войну с Россией. \n \n     Мы – народ победитель! \n\nМы гордимся тем, что восстанавливаем справедливость на Донбассе, боремся с нацизмом, тем, что отстаиваем свои ценности и нет для этого ни экономической ни военной мощи способной нас остановить. Это уже стало очевидно для всех граждан нашей страны. \n\nРоссияне объединяются вокруг Путина не впервые, так было в самом начале в 2000-ом, когда в Россию вторглись полчища террористов, так было во времена Крымской весны – восемь лет назад, и после, когда на Россию обрушился шквал санкций, так происходит и сейчас. И раз за разом граждане поддерживают решения Президента в самые сложные для России времена.\n\nДанные ВЦИОМ показывают, что российское общество солидаризировано: 76% населения считают правильным решение о проведении военной операции, доверяют Российской армии 89% наших граждан (опрос 30 - 31 марта). \n\nЗапад в очередной раз в нас ошибся. Уже многие западные эксперты признают невиданный для них факт консолидации России. Никакие их попытки, на раскол общества, предательство элит, протест не оправдался. Все информационно-санкционные усилия тщетны. \n\nТолько сейчас до них доходит, что такое российский народ, который в экстремальные моменты только становится сильнее и вместе с Президентом идёт к победе. Они не верили историческим примерам (в самые трудные времена россияне всегда сплачивались вокруг сильного и независимого лидера, будь то Александр Невский, призвавший под знамена борьбы с Ливонским орденом, или объединение всех слоев и сословий вокруг Александра I в борьбе с Наполеоном) – сейчас ощущают это «на своей шкуре».\n\n#ZаРоссию\n\n#ЗаНаших\n\n#СвоихНеБросаем\n\n#ВетеранскоеБратство\n\n#СоюзПатриотов\n\n#ВоиныДобра\n\n#ЗаРоссию'

# %%
results_z = []
for i in range(19):
  res = {}
  res['keywords'] = names[i]
  res['example1'] = get_random_post_topic(i, topics = new_topics)
  res['example2'] = get_random_post_topic(i, topics = new_topics)
  res['example3'] = get_random_post_topic(i, topics = new_topics)
  results_z.append(res)

# %%
df = pd.DataFrame(data = results_z)
df.to_csv('./drive/MyDrive/Hackathon/posts_z_0.csv')

# %%
date_labels = ['Февраль 2022', 'Март 2022', 'Апрель 2022', 'Май 2022', 'Июнь 2022', 'Июль 2022', 
               'Август 2022', 'Сентябрь 2022', 'Октябрь 2022', 'Ноябрь 2022', 'Декабрь 2022', 
               'Январь 2023', 'Февраль 2023']

# %%
results_z = []
for label in date_labels:
  res = {}
  inds_date = np.nonzero([(posts_0_z[i]['date_label'] == label) for i in range(len(posts_0_z))])[0]
  for j in range(len(names)):
    name = names[j]
    inds_ok = remove_suspicious_users(j, posts_0_z)

    n_posts = 0
    for ind in inds_date:
      if new_topics[ind]!=-1 and new_topics[ind]<19:
        # print(new_topics[len(posts_nowar)+ind])
        if names[new_topics[ind]] == name:
          if ind in inds_ok:
            n_posts += 1
          else:
            print('!')
    frac = n_posts#/len(posts)
    res[name] = frac
  results_z.append(res)

# %%
df = pd.DataFrame(data = results_z)
df.to_csv('./drive/MyDrive/Hackathon/time_topics_z_0.csv')

# %%
new_topics = model.reduce_outliers(posts_clean, topics, threshold = 0.3)
# Out:
# 100%|██████████| 23/23 [00:21<00:00,  1.05it/s]

# %%
from IPython.display import clear_output

# %%
wrong = 0
correct = 0
total = 0
inds = []

# %%
while 1:
  clear_output()
  try:
    print(total,'\n New text:\n')
  except:
    pass
  text, ind = get_random_post_topic(1, topics = new_topics)
  while (ind in inds):
    text, ind = get_random_post_topic(1, topics = new_topics)
  inds.append(ind)
  print(text)
  guess = input()
  total += 1
  if guess == '1':
    correct += 1
  else:
    wrong += 1
# Out:
# 38
#  New text:
#
# Мы - народ победитель!!! Мы гордимся тем, что не бросаем своих граждан на Донбассе, что боремся с нацизмом, тем, что отстаиваем свои интересы и ценности!!!
#
# #СвоихНеБросаем #МыВместе #ВремяПомогать #ZaМир
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-7f5e176694f6> in <cell line: 2>()
#      10   inds.append(ind)
#      11   print(text)
# ---> 12   guess = input()
#      13   total += 1
#      14   if guess == '1':
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#threshold = 0.3 - точность про фашизм
correct/total
# Out:
# 0.9736842105263158

# %%
#threshold = 0.5 - точность про фашизм
correct/total
# Out:
# 0.9607843137254902

# %%
#threshold = 0.5 (без фашизма)
correct/total
# Out:
# 0.38

# %%
#threshold = 0.3 (без фашизма)
correct/total
# Out:
# 0.54

# %%
#threshold = 0.15
correct/total
# Out:
# 0.693069306930693

# %%
#threshold = 0.5
correct/total
# Out:
# 0.7326732673267327

# %%
#threshold = 0.3
correct/total
# Out:
# 0.7524752475247525

# %%
total_pops = []
count = []
names = []
for i in range(18): 
  words, total_popularity, count_z = define_topic_params(i, new_topics)
  total_pops.append(total_popularity)
  count.append(count_z)
  names.append(words)

# %%
for i in range(18):
  print(names[i], ';', count[i])
# Out:
# президент, путин, поддерживать, решение, владимир ; 3461
# нацизм, фашизм, победа, наш, дед ; 1595
# информация, информационный, фейк, источник, правда ; 964
# запад, западный, санкция, общество, россия ; 801
# патриотизм, родина, любовь, гордиться, любить ; 1087
# акция, поддержка, поддерживать, проходить, участие ; 632
# мир, пусть, нужный, планета, небо ; 1778
# донецк, обстрел, удар, центр, погибать ; 620
# видео, украинский, фейк, буча, тело ; 410
# единый, вместе, народ, единство, друг ; 402
# помощь, спасибо, сбор, ребята, помогать ; 333
# война, донбасс, не, заканчивать, житель ; 260
# мобилизация, частичный, служба, специальность, опыт ; 415
# зеленский, визит, украина, сша, западный ; 540
# февраль, 24, 2022, операция, владимир ; 369
# суд, преступление, уголовный, задерживать, украинский ; 177
# ты, пусть, враг, русский, хранить ; 153
# вооружение, сша, поставка, оружие, доллар ; 183

# %% [markdown]
# # Antiwar posts

# %%
f = open('./drive/MyDrive/Hackathon/posts_nowar_users_russia_clean.pkl', 'rb')
posts_nowar = pickle.load(f)
f.close()

posts_clean = []

for post in posts_nowar:
    text = post['text']
    text.replace('\n','')
    posts_clean.append(text)

len(posts_clean)
# Out:
# 20448

# %%
model = BERTopic(verbose=True, language = 'multilingual', min_topic_size = 10, low_memory = True)
topics, probabilities = model.fit_transform(posts_clean)
model.get_topic_info()[:10]
# Out:
# Batches:   0%|          | 0/639 [00:00<?, ?it/s]
# 2023-03-29 19:51:25,005 - BERTopic - Transformed documents to Embeddings
# 2023-03-29 19:51:44,256 - BERTopic - Reduced dimensionality
# 2023-03-29 19:51:45,633 - BERTopic - Clustered reduced embeddings
#    Topic  Count                                Name
# 0     -1  13169                   -1_не_что_быть_на
# 1      0    617         0_путин_он_президент_россия
# 2      1    222                  1_война_это_нет_не
# 3      2    212  2_дрон_ракета_беспилотник_вертолет
# 4      3    150           3_лидер_очевидец_че_очева
# 5      4    148  4_украина_слава_ukraine_украинский
# 6      5    114           5_доллар_рубль_санкция_цб
# 7      6    103         6_суд_уголовный_штраф_судья
# 8      7    103        7_пожар_взрыв_сообщать_город
# 9      8     96             8_песня_музыка_ты_спеть

# %%
model.save("./drive/MyDrive/Hackathon/model_nowar")
# Out:
# /usr/local/lib/python3.9/dist-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
model.get_topic_info()
# Out:
#      Topic  Count                                Name
# 0       -1  13169                   -1_не_что_быть_на
# 1        0    617         0_путин_он_президент_россия
# 2        1    222                  1_война_это_нет_не
# 3        2    212  2_дрон_ракета_беспилотник_вертолет
# 4        3    150           3_лидер_очевидец_че_очева
# ..     ...    ...                                 ...
# 190    189     10    189_ирландский_хе_роза_городнаши
# 191    190     10    190_луганский_991_сергеев_гайдай
# 192    191     10        191_рядовой_гр_разбор_монгуш
# 193    192     10       192_ну_дурдом_путин_нравиться
# 194    193     10  193_g7_пограничный_хейнс_ринкевичс
#
# [195 rows x 3 columns]

# %%
model.merge_topics(posts_clean, [[-1,57,54,116,82,71,31,95,3,169,59,117,97,120,26,91,186,38,75,132,87,136,90],
                                 [162,15,55],
                                 [142,51,65,125],
                                 [6,56],
                                 [92,121],
                                 [179,85,147],
                                 [182,137],
                                 [66,135],
                                 [40,41],
                                 [99,183],
                                 [45,70,9],
                                 [100,86,122,144,7,112],
                                 [53,111],
                                 [150,67,115],
                                 [22,34],
                                 [20,69,155],
                                 [8,32]])

# %%
model.get_topic_info()[:17]
# Out:
#     Topic  Count                                       Name
# 0      -1  14014                          -1_не_что_на_быть
# 1       0    617                0_путин_он_россия_президент
# 2       1    421                          1_война_мир_не_мы
# 3       2    212         2_ракета_дрон_беспилотник_вертолет
# 4       3    205               3_район_сообщать_пожар_взрыв
# 5       4    171               4_погибать_потеря_раненый_по
# 6       5    155                     5_мать_ребенок_сын_они
# 7       6    152                  6_песня_музыка_концерт_ты
# 8       7    148         7_украина_слава_ukraine_украинский
# 9       8    140                 8_суд_судья_дело_уголовный
# 10      9    132        9_антивоенный_акция_митинг_активист
# 11     10    126             10_фашист_фашизм_нацист_нацизм
# 12     11    114                 11_доллар_рубль_санкция_цб
# 13     12    105      12_петиция_подписывать_подпись_против
# 14     13     93         13_видео_телеведущий_ролик_манекен
# 15     14     90  14_передавать_германия_оборона_вооружение
# 16     15     89              15_газ_нефть_санкция_поставка

# %%
model.merge_topics(posts_clean, [#[-1],
                                 [0,137], #путин
                                 [1,109,56,27,60], #война это ужасно
                                 [2,24,26,91], #ракеты, оружие, перемещения войск
                                #  [3], #обстрел, пожар, взрыв
                                 [4,48], #потери
                                 [5,107,59,72,110,50,102,94], #дети, родители
                                 [6], #музыка
                                 [7,111,46,61,16,17,33], #поддержка Украины
                                 [8], #задержания, штрафы, преследования
                                 [9], #митинги
                                 [10,25], #фашизм
                                 [11,15,37], #доллар, рубль, санкции
                                 [12], #петиции
                                 [13,22,84], #видео, медиа, пропаганда, фейки
                                 [14,35], #помощь Украине от других стран
                                 ])

# %%
hierarchical_topics = model.hierarchical_topics(posts_clean)
tree = model.get_topic_tree(hierarchical_topics)
print(tree)
# Out:
# 100%|██████████| 138/138 [00:01<00:00, 129.57it/s]
# .
# ├─не_что_на_это_мы
# │    ├─ты_песня_не_мир_все
# │    │    ├─ты_песня_быть_мы_не
# │    │    │    ├─весна_обийми_зима_день_мена
# │    │    │    │    ├─■──сон_просыпаться_сниться_кошмар_мой ── Topic: 109
# │    │    │    │    └─весна_обийми_зима_мена_грач
# │    │    │    │         ├─■──обийми_мена_обнимать_весна_заставать ── Topic: 93
# │    │    │    │         └─■──весна_зима_грач_природа_день ── Topic: 30
# │    │    │    └─ты_песня_быть_не_бог
# │    │    │         ├─песня_ты_что_мой_не
# │    │    │         │    ├─■──год_2023_2022_желать_звучать ── Topic: 90
# │    │    │         │    └─песня_ты_мой_что_не
# │    │    │         │         ├─песня_ты_музыка_мой_мы
# │    │    │         │         │    ├─■──песня_музыка_концерт_ты_петь ── Topic: 6
# │    │    │         │         │    └─покаяние_небо_день_поздравлять_праздник
# │    │    │         │         │         ├─покаяние_мама_не_слеза_жизнь
# │    │    │         │         │         │    ├─■──помнить_девочка_стихотворение_вы_осколок ── Topic: 107
# │    │    │         │         │         │    └─■──покаяние_слеза_мама_не_плакать ── Topic: 59
# │    │    │         │         │         └─■──поздравлять_небо_рад_праздник_день ── Topic: 18
# │    │    │         │         └─себя_помогать_страх_мочь_тревога
# │    │    │         │              ├─себя_тревога_страх_помогать_мочь
# │    │    │         │              │    ├─■──сейчас_себя_страшно_мир_но ── Topic: 56
# │    │    │         │              │    └─■──тревога_помогать_психолог_мочь_стресс ── Topic: 27
# │    │    │         │              └─■──спектакль_оборудование_папа_пьяный_абхазия ── Topic: 98
# │    │    │         └─церковь_бог_православный_патриарх_святой
# │    │    │              ├─церковь_православный_бог_патриарх_святой
# │    │    │              │    ├─■──братть_ще_ми_слава_the ── Topic: 111
# │    │    │              │    └─церковь_православный_бог_патриарх_святой
# │    │    │              │         ├─церковь_православный_бог_патриарх_святой
# │    │    │              │         │    ├─■──церковь_православный_патриарх_кирилл_бог ── Topic: 29
# │    │    │              │         │    └─■──бог_цветок_он_ты_да ── Topic: 63
# │    │    │              │         └─■──твой_пусть_энергия_предмет_небо ── Topic: 112
# │    │    │              └─■──ад_воскресать_че_гореть_христос ── Topic: 100
# │    │    └─оскорблять_дурак_сложный_высказывать_ты
# │    │         ├─оскорблять_дурак_высказывать_сложный_ты
# │    │         │    ├─■──оскорблять_дурак_высказывать_сложный_высказываться ── Topic: 82
# │    │         │    └─■──очень_мир_ты_сложный_все ── Topic: 97
# │    │         └─мир_мужчина_затевать_бы_доставаться
# │    │              ├─мир_мужчина_затевать_бы_доставаться
# │    │              │    ├─мужчина_затевать_бы_доставаться_мир
# │    │              │    │    ├─■──затевать_мужчина_бы_доставаться_даваться ── Topic: 95
# │         │         └─забор_ребенок_родитель_детский_сад
# │         │              ├─ваш_ребенок_путин_убивать_спасать
# │         │              │    ├─■──ваш_вы_бедняк_сидеть_ребенок ── Topic: 102
# │         │              │    └─■──путин_ребенок_мать_убивать_спасать ── Topic: 83
# │         │              └─■──забор_родитель_ребенок_детский_сад ── Topic: 94
# │         └─во_на_украина_государство_власть
# │              ├─во_буква_государство_власть_действующий
# │              │    ├─во_власть_действующий_вы_мифический
# │              │    │    ├─■──ребенок_закон_либо_воспитание_тайга ── Topic: 103
# │              │    │    └─во_власть_вы_действующий_мифический
# │              │    │         ├─■──во_власть_лес_действующий_вы ── Topic: 79
# │              │    │         └─■──буква_во_мифический_замир_zамир ── Topic: 113
# │              │    └─во_германия_нато_государство_чужой
# │              │         ├─■──во_германия_нато_либо_государство ── Topic: 92
# │              │         └─■──германия_во_нато_государство_мобилизация ── Topic: 101
# │              └─суд_петиция_антивоенный_против_на
# │                   ├─суд_петиция_антивоенный_против_на
# │                   │    ├─антивоенный_акция_митинг_протест_активист
# │                   │    │    ├─■──антивоенный_акция_митинг_активист_протест ── Topic: 9
# │                   │    │    └─■──инстаграм_meta_экстремистский_лого_просто ── Topic: 116
# │                   │    └─суд_петиция_подписывать_на_подпись
# │                   │         ├─суд_видео_на_дело_судья
# │                   │         │    ├─видео_канал_журналист_российский_дождь
# │                   │         │    │    ├─■──видео_телеведущий_ролик_манекен_манизать ── Topic: 13
# │                   │         │    │    └─■──канал_заблокировать_дождь_журналист_блокировка ── Topic: 22
# │                   │         │    └─■──суд_судья_дело_уголовный_адвокат ── Topic: 8
# │                   │         └─петиция_подписывать_подпись_служба_письмо
# │                   │              ├─■──петиция_подписывать_подпись_против_война ── Topic: 12
# │                   │              └─■──служба_военный_письмо_альтернативный_убеждение ── Topic: 32
# │                   └─instagram_информационный_хакер_долл_кибератака
# │                        ├─■──информационный_хакер_долл_кибератака_убитый ── Topic: 114
# │                        └─■──instagram_youtube_леттерман_ройзман_пользователь ── Topic: 84
# └─ода_украина_по_российский_сообщать
#      ├─российский_сообщать_по_украина_россия
#      │    ├─украина_сша_россия_ес_санкция
#      │    │    ├─ссср_государство_украина_государственность_сша
#      │    │    │    ├─украина_переговоры_зеленский_ядерный_сша
#      │    │    │    │    ├─ядерный_китай_оружие_сша_биологический
#      │    │    │    │    │    ├─■──биологический_лаборатория_биолаборатория_metabiota_исследование ── Topic: 71
#      │    │    │    │    │    └─ядерный_китай_оружие_сша_си
#      │    │    │    │    │         ├─■──ядерный_оружие_применение_сдерживание_подлодка ── Topic: 65
#      │    │    │    │    │         └─■──китай_си_цзиньпина_китайский_сша ── Topic: 47
#      │    │    │    │    └─переговоры_зеленский_украина_ес_президент
#      │    │    │    │         ├─зеленский_переговоры_украина_ес_президент
#      │    │    │    │         │    ├─■──g7_украина_пограничный_хейнс_ринкевичс ── Topic: 138
#      │    │    │    │         │    └─переговоры_зеленский_ес_украина_президент
#      │    │    │    │         │         ├─■──зеленский_ес_президент_украина_вступление ── Topic: 17
#      │    │    │    │         │         └─■──переговоры_заявлять_украина_миротворец_переговорный ── Topic: 36
#      │    │    │    │         └─■──беларусь_лукашенко_белорусский_латушка_арестович ── Topic: 77
#      │    │    │    └─ссср_государственность_1918_независимость_состав
#      │    │    │         ├─референдум_зерно_тонна_область_голосование
#      │    │    │         │    ├─референдум_зерно_тонна_область_республиканец
#      │    │    │         │    │    ├─■──зерно_тонна_порт_вывозить_продовольственный ── Topic: 55
#      │    │    │         │    │    └─■──референдум_республиканец_присоединение_голосование_область ── Topic: 49
#      │    │    │         │    └─■──резолюция_эритрея_проголосовать_оон_воздерживаться ── Topic: 122
#      │    │    │         └─ссср_государственность_1918_независимость_воз
#      │    │    │              ├─■──ссср_государственность_1918_независимость_государство ── Topic: 123
#      │    │    │              └─■──воз_выход_организация_здравоохранение_медведев ── Topic: 66
#      │    │    └─санкция_компания_доллар_газ_россия
#      │    │         ├─санкция_компания_доллар_газ_россия
#      │    │         │    ├─санкция_компания_газ_россия_доллар
#      │    │         │    │    ├─■──компания_бренд_cocacola_карта_приостанавливать ── Topic: 37
#      │    │         │    │    └─санкция_газ_нефть_доллар_рубль
#      │    │         │    │         ├─■──актив_fife_миллиард_замораживать_деньги ── Topic: 104
#      │    │         │    │         └─санкция_газ_нефть_доллар_рубль
#      │    │         │    │              ├─санкция_газ_нефть_доллар_рубль
#      │    │         │    │              │    ├─■──газ_нефть_санкция_поставка_ес ── Topic: 15
#      │    │         │    │              │    └─■──доллар_рубль_санкция_цб_банк ── Topic: 11
#      │    │         │    │              └─■──виза_рейс_болгария_закрывать_билет ── Topic: 52
#      │    │         │    └─передавать_помощь_млн_украина_оборона
#      │    │         │         ├─■──помощь_млн_пакет_млрд_гуманитарный ── Topic: 35
#      │    │         │         └─■──передавать_германия_оборона_вооружение_боеприпасы ── Topic: 14
#      │    │         └─венгрия_беженец_ес_европа_орбан
#      │    │              ├─■──беженец_европа_убежище_нидерланды_оон ── Topic: 73
#      │    │              └─■──венгрия_ес_орбан_сийярто_энергетика ── Topic: 126
#      │    └─сообщать_область_ракета_оккупант_российский
#      │         ├─ракета_дрон_беспилотник_вертолет_сбивать
#      │         │    ├─■──ода_ворог_враг_железнодорожный_our ── Topic: 130
#      │         │    └─ракета_дрон_беспилотник_вертолет_сбивать
#      │         │         ├─уничтожать_всу_направление_войско_бригада
#      │         │         │    ├─■──уничтожать_вражеский_бригада_склад_всу ── Topic: 24
#      │         │         │    └─■──направление_войско_российский_всу_область ── Topic: 26
#      │         │         └─■──ракета_дрон_беспилотник_вертолет_сбивать ── Topic: 2
#      │         └─сообщать_город_погибать_по_оккупант
#      │              ├─город_сообщать_погибать_оккупант_по
#      │              │    ├─■──мэр_оккупант_российский_похищать_солдат ── Topic: 28
#      │              │    └─сообщать_погибать_город_по_обстрел
#      │              │         ├─■──эвакуация_мариуполь_андрющенко_населенный_донецкий ── Topic: 40
#      │              │         └─погибать_сообщать_обстрел_по_город
#      │              │              ├─погибать_сообщать_потеря_по_обстрел
#      │              │              │    ├─■──погибать_потеря_раненый_по_данные ── Topic: 4
#      │              │              │    └─■──район_сообщать_пожар_взрыв_обстрел ── Topic: 3
#      │              │              └─■──область_город_киевский_местный_российский ── Topic: 54
#      │              └─■──захоронение_могила_снимок_кладбище_тело ── Topic: 48
#      └─ода_мост_the_украина_tanks
#           ├─ода_мост_the_tanks_systems
#           │    ├─ода_мост_tanks_the_systems
#           │    │    ├─ода_tanks_systems_were_2402
#           │    │    │    ├─■──ода_tanks_systems_were_2402 ── Topic: 38
#           │    │    │    └─■──ед_ббм_цистерна_пмм_2402 ── Topic: 64
#           │    │    └─мост_украина_пенсионер_на_русский
#           │    │         ├─мост_украина_пенсионер_флаг_победа
#           │    │         │    ├─мост_флаг_антоновский_крымский_всу
#           │    │         │    │    ├─флаг_украинский_область_поселок_подымать
#           │    │         │    │    │    ├─■──ирландский_хе_роза_мильен_доманаши ── Topic: 134
#           │    │         │    │    │    └─флаг_область_украинский_подымать_поселок
#           │    │         │    │    │         ├─■──флаг_подымать_украинский_область_поселок ── Topic: 33
#           │    │         │    │    │         └─■──луганский_991_сергеев_гайдай_kyiv ── Topic: 135
#           │    │         │    │    └─мост_антоновский_крымский_по_всу
#           │    │         │    │         ├─мост_антоновский_крымский_всу_по
#           │    │         │    │         │    ├─мост_антоновский_крымский_всу_по
#           │    │         │    │         │    │    ├─■──мост_антоновский_крымский_переправа_всу ── Topic: 19
#           │    │         │    │         │    │    └─чибрин_арестович_андреевка_оккупант_они
#           │    │         │    │         │    │         ├─■──арестович_перебрасывать_оп_алексей_советник ── Topic: 124
#           │    │         │    │         │    │         └─■──чибрин_андреевка_каска_липовка_рыбак ── Topic: 74
#           │    │         │    │         │    └─■──мяч_путин_обзываться_ой_финал ── Topic: 85
#           │    │         │    │         └─як_що_окупант_родичів_телебаченний
#           │    │         │    │              ├─■──що_як_родичів_їдемо_телебаченний ── Topic: 86
#           │    │         │    │              └─■──курский_старовойт_сбу_пособие_герб ── Topic: 129
#           │    │         │    └─украина_пенсионер_победа_юрист_русский
#           │    │         │         ├─корабль_русский_нахуй_идти_яхта
#           │    │         │         │    ├─корабль_русский_нахуй_яхта_марка
#           │    │         │         │    │    ├─■──грузин_спасибо_помощь_загранник_пытаетсязащищать ── Topic: 119
#           │    │         │         │    │    └─■──корабль_нахуй_яхта_русский_марка ── Topic: 75
#           │    │         │         │    └─■──обращение_русский_арнольд_нормальный_русня ── Topic: 62
#           │    │         │         └─украина_пенсионер_победа_юрист_фашизм
#           │    │         │              ├─украина_пенсионер_юрист_стыдно_елена
#           │    │         │              │    ├─пенсионер_юрист_стыдно_елена_ольга
#           │    │         │              │    │    ├─■──агрэсіі_тэрыторыі_беларусь_супраць_рэспублікі ── Topic: 20
#           │    │         │              │    │    └─пенсионер_юрист_стыдно_елена_ольга
#           │    │         │              │    │         ├─■──пенсионер_юрист_стыдно_елена_ольга ── Topic: 57
#           │    │         │              │    │         └─украина_собака_you_ukraine_the
#           │    │         │              │    │              ├─украина_ukraine_you_слава_to
#           │    │         │              │    │              │    ├─■──you_ангрон_to_долг_лизистрат ── Topic: 76
#           │    │         │              │    │              │    └─украина_ukraine_слава_ja_the
#           │    │         │              │    │              │         ├─■──ja_war_друг_of_myös ── Topic: 80
#           │    │         │              │    │              │         └─■──украина_слава_ukraine_украинский_украинец ── Topic: 7
#           │    │         │              │    │              └─■──собака_кот_пес_кошка_котик ── Topic: 41
#           │    │         │              │    └─украина_эфир_прямой_война_телемарафон
#           │    │         │              │         ├─эфир_украина_прямой_война_телемарафон
#           │    │         │              │         │    ├─■──французский_украина_война_сопостельник_франко ── Topic: 44
#           │    │         │              │         │    └─■──эфир_прямой_телемарафон_день_вторжение ── Topic: 53
#           │    │         │              │         └─■──русский_прозвище_шарие_мясник_кацап ── Topic: 67
#           │    │         │              └─фашизм_путь_победа_над_руzzким
#           │    │         │                   ├─■──фашизм_путь_победа_над_руzzким ── Topic: 25
#           │    │         │                   └─■──самораспад_уничтожение_воссоединение_неповинный_прогнивать ── Topic: 81
#           │    │         └─вакцина_петровна_прогулка_covid19_агрессивный
#           │    │              ├─агрессивный_наказываться_лишение_развязывание_планирование
#           │    │              │    ├─■──отбывание_предел_гражданство_рф_бессрочный ── Topic: 88
#           │    │              │    └─■──агрессивный_наказываться_развязывание_планирование_лишение ── Topic: 108
#           │    │              └─вакцина_петровна_прогулка_covid19_check
#           │    │                   ├─прогулка_памятник_поддержка_центр_часть
#           │    │                   │    ├─■──полк_тероборона_батальон_азы_totenkopf ── Topic: 91
#           │    │                   │    └─прогулка_памятник_поддержка_центр_часть
#           │    │                   │         ├─памятник_демонтировать_пушкин_монумент_скульптура
#           │    │                   │         │    ├─■──рядовой_гр_разбор_ооржак_монгуш ── Topic: 136
#           │    │                   │         │    └─■──памятник_демонтировать_пушкин_монумент_скульптура ── Topic: 96
#           │    │                   │         └─■──прогулка_поддержка_часть_плленин_центр ── Topic: 39
#           │    │                   └─вакцина_петровна_covid19_check_фильм
#           │    │                        ├─вакцина_петровна_covid19_check_фильм
#           │    │                        │    ├─глазатолько_поколениюболее_родственникамособенно_телевидениеоткрывать_хештег
#           │    │                        │    │    ├─■──поколениюболее_глазатолько_родственникамособенно_телевидениеоткрывать_телепропаганда ── Topic: 106
#           │    │                        │    │    └─■──хештег_ждемс_блогер_прижимать_переобуваться ── Topic: 115
#           │    │                        │    └─вакцина_петровна_covid19_check_фильм
#           │    │                        │         ├─вакцина_петровна_covid19_check_фильм
#           │    │                        │         │    ├─■──вакцина_covid19_check_вакцинация_pfizer ── Topic: 68
#           │    │                        │         │    └─петровна_фильм_вера_роль_хороший
#           │    │                        │         │         ├─фильм_роль_хороший_оскар_номинация
#           │    │                        │         │         │    ├─■──лукария_райя_троцо_таблетница_сальск ── Topic: 31
#           │    │                        │         │         │    └─■──фильм_роль_хороший_оскар_номинация ── Topic: 131
#           │    │                        │         │         └─■──петровна_вера_завтрак_человечинка_ессентуки ── Topic: 133
#           │    │                        │         └─■──граффити_цветок_flowers_bullets_better ── Topic: 128
#           │    │                        └─■──новинка_supernovasuperstar_supernova_extended_стенка ── Topic: 127
#           │    └─видео_растаивать_ледник_youtube_кадр
#           │         ├─видео_растаивать_ледник_канал_youtube
#           │         │    ├─■──видео_украина_документальный_дудаев_армянин ── Topic: 70
#           │         │    └─■──видео_растаивать_ледник_канал_youtube ── Topic: 21
#           │         └─видео_пулеметчик_процедура_опубликовывать_плен
#           │              ├─■──видео_пулеметчик_процедура_плен_орк ── Topic: 43
#           │              └─■──видео_опубликовывать_жестянка_стоянка_появляться ── Topic: 125
#           └─донецк_террорист_артобстрел_2014_восемь
#                ├─донецк_ukraine_авг_артобстрел_последствие
#                │    ├─■──ukraine_авг_донецк_жилой_последствие ── Topic: 69
#                │    └─■──донецк_артобстрел_11022015_автостанция_23082014 ── Topic: 105
#                └─донецк_террорист_восемь_год_убивать
#                     ├─■──донецк_пацифист_путиловский_луганск_29072014 ── Topic: 117
#                     └─■──террорист_хватить_восемь_донецк_порошенко ── Topic: 99

# %%
model.save("./drive/MyDrive/Hackathon/model_nowar_merged")

# %%
model = BERTopic.load("./drive/MyDrive/Hackathon/model_nowar_merged")

# %%
topics = model.topics_

# %%
new_topics = model.reduce_outliers(posts_clean, topics, threshold = 0.3)
# Out:
# 100%|██████████| 15/15 [00:17<00:00,  1.14s/it]

# %%
f = open("./drive/MyDrive/Hackathon/stop_words_russian.txt", "r", encoding="utf-8")
stop_words = f.read()
f.close()
stop_words = stop_words.split("\n")

# %%
def find_indices(list_to_check, item_to_find):
    indices = []
    for idx, value in enumerate(list_to_check):
        if value == item_to_find:
            indices.append(idx)
    return indices

# %%
def remove_suspicious_users(topic_n, posts, topics = new_topics):
  users_ids = []
  inds = find_indices(topics, topic_n)
  users_ids = [posts[j]['owner_id'] for j in inds]
  u, c = np.unique(np.array(users_ids), return_counts=True)

  n_posts = len(inds)

  users_ok = []

  for i in range(len(c)):
    if c[i]/n_posts < 0.15:
      users_ok.append(u[i])

  inds_ok = []
  for ind in inds:
    if posts[ind]['owner_id'] in users_ok:
      inds_ok.append(ind)

  return inds_ok

# %%
def define_topic_params(topic_ind, topics = topics):
  words = [item[0] for item in model.get_topic(topic_ind)][:10]
  inds_remove = []
  for i in range(len(words)):
    word = words[i]
    if word in stop_words:
      inds_remove.append(i)

  for i in inds_remove[::-1]:
    words.remove(words[i])

  words = words[:5]
  words = ', '.join(words)
  inds = remove_suspicious_users(topic_ind, posts_nowar, topics = topics)
  count_z = 0
  for i in inds:
      count_z += 1
  total_popularity = count_z/len(posts_clean)
  return words, total_popularity, count_z

# %%
def get_random_post_topic(topic_ind, topics = topics):
  inds = remove_suspicious_users(topic_ind, posts_nowar)
  random.shuffle(inds)
  texts = []
  # text = str(posts_nowar[inds[0]]['owner_id']) + ' ' + posts_nowar[inds[0]]['initial_text']
  text = posts_nowar[inds[0]]['initial_text']
  return text

# %%
total_pops = []
names = []
for i in range(15): 
  words, total_popularity, count = define_topic_params(i, new_topics)
  total_pops.append(count)
  names.append(words)
  print(i,words)
# Out:
# 0 путин, россия, президент, война
# 1 война, мир
# 2 украина, украинский, флаг, украинец, зеленский
# 3 ракета, дрон, беспилотник, вертолет, сбивать
# 4 ребенок, мать, забор, мама, родитель
# 5 санкция, компания, газ, нефть, россия
# 6 погибать, потеря, погибший, раненый, российский
# 7 район, сообщать, пожар, взрыв, обстрел
# 8 фашизм, победа, путь, фашист, нацист
# 9 видео, канал, российский, журналист, заблокировать
# 10 песня, музыка, концерт, петь, гимн
# 11 суд, судья, дело, уголовный, адвокат
# 12 передавать, помощь, украина, млн, оборона
# 13 антивоенный, акция, митинг, активист, протест
# 14 петиция, подписывать, подпись, война, останавливать

# %%
for i in range(15):
  print(names[i], ',', total_pops[i])
# Out:
# путин, россия, президент, война , 1066
# война, мир , 555
# украина, украинский, флаг, украинец, зеленский , 316
# ракета, дрон, беспилотник, вертолет, сбивать , 161
# ребенок, мать, забор, мама, родитель , 297
# санкция, компания, газ, нефть, россия , 181
# погибать, потеря, погибший, раненый, российский , 150
# район, сообщать, пожар, взрыв, обстрел , 115
# фашизм, победа, путь, фашист, нацист , 178
# видео, канал, российский, журналист, заблокировать , 180
# песня, музыка, концерт, петь, гимн , 257
# суд, судья, дело, уголовный, адвокат , 131
# передавать, помощь, украина, млн, оборона , 44
# антивоенный, акция, митинг, активист, протест , 241
# петиция, подписывать, подпись, война, останавливать , 225

# %%
for i in range(15):
  print(names[i], ',', total_pops[i])
# Out:
# путин, война, мир, страшно бессильный, прикасаться душа, тропа , 1200
# война, мир, друг, жизнь, жить, происходить , 879
# украина, война, мир, украинец, жить, друг , 392
# российский, ракета, вертолет, уничтожать, сбивать, самолет , 188
# ребенок, война, мир, забор, мать, русский , 355
# россия, санкция, компания, банк, газ, доллар , 249
# погибать, война, военный, ребенок, потеря, город , 230
# дом, район, обстрел, город, ракета, жилой дом , 166
# фашизм, война, мир, русский, украинский фашизм, фашист , 272
# россия, видео, война, канал, журналист, телеведущий , 180
# песня, война, мир, петь, музыка, спасибо , 268
# суд, дело, война, судья, говорить, прокурор , 164
# украина, передавать украина, военный, оружие, норвегия, млн , 58
# война, митинг, антивоенный, выходить, акция протеста, мир , 440
# петиция, война, учитель, подпись, петиция требования, подписывать петиция , 249

# %%
results_nowar = []
for i in range(15):
  res = {}
  res['keywords'] = names[i]
  # res['popularity'] = total_pops[i]
  res['example1'] = get_random_post_topic(i, topics = new_topics)
  res['example2'] = get_random_post_topic(i, topics = new_topics)
  res['example3'] = get_random_post_topic(i, topics = new_topics)
  results_nowar.append(res)

# %%
df = pd.DataFrame(data = results_nowar)
df.to_csv('./drive/MyDrive/Hackathon/posts_nowar.csv')

# %%
model.get_topic_info()[:16]
# Out:
#     Topic  Count                                   Name
# 0      -1  14014                      -1_не_что_на_быть
# 1       0    627                  0_путин_он_россия_что
# 2       1    555                     1_война_мир_не_это
# 3       2    442          2_украина_украинский_мой_флаг
# 4       3    355     3_ракета_дрон_беспилотник_вертолет
# 5       4    297              4_ребенок_мать_забор_мама
# 6       5    250           5_санкция_компания_газ_нефть
# 7       6    207          6_погибать_потеря_погибший_по
# 8       7    205           7_район_сообщать_пожар_взрыв
# 9       8    188               8_фашизм_победа_путь_над
# 10      9    180     9_видео_канал_российский_журналист
# 11     10    152             10_песня_музыка_концерт_ты
# 12     11    140            11_суд_судья_дело_уголовный
# 13     12    139       12_передавать_помощь_украина_млн
# 14     13    132   13_антивоенный_акция_митинг_активист
# 15     14    105  14_петиция_подписывать_подпись_против

# %%
define_topic_params(1, topics = new_topics)
# Out:
# ('война, мир, друг, жизнь, жить, происходить', 0.004887459807073955, 879)

# %%
print(get_random_post_topic(-1, topics = new_topics))
# Out:
# 162974162 НИ ФЭЙК! НИ ФОТОШОП!
#
# #НЕТВОЙНЕ!
#
# ПРИКИНЬТЕ НАРОД! САЙТ РОСКОМНАДЗОРА ЛЁГ!
# Хотел ради прикола зайти на него и посмотреть что он творит вообще. А он ЗАБЛОКИРОВАН! ВОТ ГДЕ РОСКОМНАДЗОР КОГДА ОН ТАК НУЖЕН?😊 Если не верите, то сами тогда попробуйте зайти на сайт. И небольшая поправочка! Он даже если и включается каким-то чудом. То очень жутко тормозит.
#
# https://rkn.gov.ru

# %%
date_labels = ['Февраль 2022', 'Март 2022', 'Апрель 2022', 'Май 2022', 'Июнь 2022', 'Июль 2022', 
               'Август 2022', 'Сентябрь 2022', 'Октябрь 2022', 'Ноябрь 2022', 'Декабрь 2022', 
               'Январь 2023', 'Февраль 2023']

# %%
results_nowar = []
for label in date_labels:
  res = {}
  inds_date = np.nonzero([(posts_nowar[i]['date_label'] == label) for i in range(len(posts_nowar))])[0]
  for j in range(len(names)):
    name = names[j]
    n_posts = 0
    inds_ok = remove_suspicious_users(j, posts_nowar)
    for ind in inds_date:
      if new_topics[ind]!=-1 and new_topics[ind]<15:
        # print(new_topics[len(posts_nowar)+ind])
        if names[new_topics[ind]] == name:
          if ind in inds_ok:
            n_posts += 1
    frac = n_posts#/len(posts_nowar)
    res[name] = frac
  results_nowar.append(res)

# %%
df = pd.DataFrame(data = results_nowar)
df.to_csv('./drive/MyDrive/Hackathon/time_topics_nowar_full.csv')

# %%
model = BERTopic(verbose=True, language = 'multilingual', nr_topics=20, low_memory = True)
topics, probabilities = model.fit_transform(posts_clean)
model.get_topic_info()[:10]
# Out:
# Batches:   0%|          | 0/639 [00:00<?, ?it/s]
# 2023-03-29 21:43:59,705 - BERTopic - Transformed documents to Embeddings
# 2023-03-29 21:44:17,989 - BERTopic - Reduced dimensionality
# 2023-03-29 21:44:23,592 - BERTopic - Clustered reduced embeddings
# 2023-03-29 21:44:30,381 - BERTopic - Reduced number of topics from 182 to 20
#    Topic  Count                                  Name
# 0     -1  13121                     -1_не_на_что_быть
# 1      0   5427                        0_не_на_что_мы
# 2      1    768                     1_путин_не_что_он
# 3      2    154                  2_суд_на_адвокат_что
# 4      3    132   3_дрон_беспилотник_вертолет_сбивать
# 5      4    125                       4_что_не_они_вы
# 6      5    108             5_на_санкция_россия_рубль
# 7      6     90  6_петиция_подписывать_подпись_против
# 8      7     77        7_мост_антоновский_крымский_по
# 9      8     58       8_газ_нефть_российский_поставка
